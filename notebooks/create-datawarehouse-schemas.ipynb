# %%
import sqlalchemy as sa
import pandas as pd

from dbcp.helpers import get_sql_engine

engine = get_sql_engine()
# Out:
# /app/.local/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.0-CAPI-1.16.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
with engine.connect() as con:
    co2_dashboard = pd.read_sql_table("co2_dashboard", con, schema="data_mart")
    counties_long_format = pd.read_sql_table("counties_long_format", con, schema="data_mart")
    counties_wide_format = pd.read_sql_table("counties_wide_format", con, schema="data_mart")
    existing_plants = pd.read_sql_table("existing_plants", con, schema="data_mart")
    fossil_infrastructure_projects = pd.read_sql_table("fossil_infrastructure_projects", con, schema="data_mart")
    iso_projects_long_format = pd.read_sql_table("iso_projects_long_format", con, schema="data_mart")
    iso_projects_wide_format = pd.read_sql_table("iso_projects_wide_format", con, schema="data_mart")
    proposed_power_dash_local_opp = pd.read_sql_table("proposed_power_dash_local_opp", con, schema="data_mart")
    proposed_power_dash_existing_plants = pd.read_sql_table("proposed_power_dash_existing_plants", con, schema="data_mart")
    proposed_power_dash_proposed_plants = pd.read_sql_table("proposed_power_dash_proposed_plants", con, schema="data_mart")

# %%
counties_wide_format.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3236 entries, 0 to 3235
# Data columns (total 79 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   state_id_fips                                                    3236 non-null   object
#  1   county_id_fips                                                   3236 non-null   object
#  2   state                                                            3235 non-null   object
#  3   county                                                           3236 non-null   object
#  4   has_ordinance                                                    3236 non-null   bool
#  5   state_permitting_type                                            3079 non-null   object
#  6   county_total_co2e_tonnes_per_year                                2241 non-null   float64
#  7   fossil_existing_capacity_mw                                      2241 non-null   float64
#  8   fossil_existing_co2e_tonnes_per_year                             2241 non-null   float64
#  9   fossil_existing_facility_count                                   2241 non-null   float64
#  10  fossil_proposed_capacity_mw                                      2241 non-null   float64
#  11  fossil_proposed_co2e_tonnes_per_year                             2241 non-null   float64
#  12  fossil_proposed_facility_count                                   2241 non-null   float64
#  13  renewable_and_battery_existing_capacity_mw                       2241 non-null   float64
#  14  renewable_and_battery_existing_co2e_tonnes_per_year              2241 non-null   float64
#  15  renewable_and_battery_existing_facility_count                    2241 non-null   float64
#  16  renewable_and_battery_proposed_capacity_mw                       2241 non-null   float64
#  17  renewable_and_battery_proposed_facility_count                    2241 non-null   float64
#  18  infra_total_proposed_co2e_tonnes_per_year                        2241 non-null   float64
#  19  infra_total_proposed_facility_count                              2241 non-null   float64
#  20  infra_total_proposed_nox_tonnes_per_year                         2241 non-null   float64
#  21  infra_total_proposed_pm2_5_tonnes_per_year                       2241 non-null   float64
#  22  battery_storage_existing_capacity_mw                             72 non-null     float64
#  23  battery_storage_existing_facility_count                          72 non-null     float64
#  24  battery_storage_proposed_capacity_mw                             951 non-null    float64
#  25  battery_storage_proposed_facility_count                          951 non-null    float64
#  26  coal_existing_capacity_mw                                        225 non-null    float64
#  27  coal_existing_co2e_tonnes_per_year                               219 non-null    float64
#  28  coal_existing_facility_count                                     225 non-null    float64
#  29  coal_proposed_capacity_mw                                        4 non-null      float64
#  30  coal_proposed_co2e_tonnes_per_year                               4 non-null      float64
#  31  coal_proposed_facility_count                                     4 non-null      float64
#  32  gas_existing_capacity_mw                                         771 non-null    float64
#  33  gas_existing_co2e_tonnes_per_year                                760 non-null    float64
#  34  gas_existing_facility_count                                      771 non-null    float64
#  35  gas_proposed_capacity_mw                                         180 non-null    float64
#  36  gas_proposed_co2e_tonnes_per_year                                173 non-null    float64
#  37  gas_proposed_facility_count                                      180 non-null    float64
#  38  offshore_wind_existing_capacity_mw                               1 non-null      float64
#  39  offshore_wind_existing_facility_count                            1 non-null      float64
#  40  offshore_wind_proposed_capacity_mw                               16 non-null     float64
#  41  offshore_wind_proposed_facility_count                            16 non-null     float64
#  42  oil_existing_capacity_mw                                         423 non-null    float64
#  43  oil_existing_co2e_tonnes_per_year                                376 non-null    float64
#  44  oil_existing_facility_count                                      423 non-null    float64
#  45  onshore_wind_existing_capacity_mw                                454 non-null    float64
#  46  onshore_wind_existing_facility_count                             454 non-null    float64
#  47  onshore_wind_proposed_capacity_mw                                408 non-null    float64
#  48  onshore_wind_proposed_facility_count                             408 non-null    float64
#  49  solar_existing_capacity_mw                                       803 non-null    float64
#  50  solar_existing_co2e_tonnes_per_year                              10 non-null     float64
#  51  solar_existing_facility_count                                    803 non-null    float64
#  52  solar_proposed_capacity_mw                                       1334 non-null   float64
#  53  solar_proposed_facility_count                                    1334 non-null   float64
#  54  infra_gas_proposed_co2e_tonnes_per_year                          55 non-null     float64
#  55  infra_gas_proposed_facility_count                                67 non-null     float64
#  56  infra_gas_proposed_nox_tonnes_per_year                           67 non-null     float64
#  57  infra_gas_proposed_pm2_5_tonnes_per_year                         67 non-null     float64
#  58  infra_lng_proposed_co2e_tonnes_per_year                          12 non-null     float64
#  59  infra_lng_proposed_facility_count                                15 non-null     float64
#  60  infra_lng_proposed_nox_tonnes_per_year                           15 non-null     float64
#  61  infra_lng_proposed_pm2_5_tonnes_per_year                         15 non-null     float64
#  62  infra_oil_proposed_co2e_tonnes_per_year                          12 non-null     float64
#  63  infra_oil_proposed_facility_count                                20 non-null     float64
#  64  infra_oil_proposed_nox_tonnes_per_year                           20 non-null     float64
#  65  infra_oil_proposed_pm2_5_tonnes_per_year                         20 non-null     float64
#  66  infra_petrochemicals_and_plastics_proposed_co2e_tonnes_per_year  21 non-null     float64
#  67  infra_petrochemicals_and_plastics_proposed_facility_count        37 non-null     float64
#  68  infra_petrochemicals_and_plastics_proposed_nox_tonnes_per_year   37 non-null     float64
#  69  infra_petrochemicals_and_plastics_proposed_pm2_5_tonnes_per_yea  37 non-null     float64
#  70  infra_synthetic_fertilizers_proposed_co2e_tonnes_per_year        7 non-null      float64
#  71  infra_synthetic_fertilizers_proposed_facility_count              15 non-null     float64
#  72  infra_synthetic_fertilizers_proposed_nox_tonnes_per_year         15 non-null     float64
#  73  infra_synthetic_fertilizers_proposed_pm2_5_tonnes_per_year       15 non-null     float64
#  74  ordinance                                                        109 non-null    object
#  75  ordinance_earliest_year_mentioned                                97 non-null     float64
#  76  ordinance_jurisdiction_name                                      109 non-null    object
#  77  ordinance_jurisdiction_type                                      109 non-null    object
#  78  state_permitting_text                                            3144 non-null   object
# dtypes: bool(1), float64(69), object(9)
# memory usage: 1.9+ MB

# %%
def dtypes_and_nulls(df):
    return pd.concat([df.dtypes, df.isna().any()], axis=1)

def convert_to_schema(df):
    type_mapping = {"int64": "Integer", "float64": "Float", "object": "String", "datetime64[ns]": "DateTime", "bool": "Boolean"}
    
    dtypes = dtypes_and_nulls(df)
    
    final_str = ""
    
    for _, row in dtypes.iterrows():
        if row[1]:
            final_str += f"Column(\"{row.name}\", {type_mapping[str(row[0])]}, nullable=True),\n"
        else:
            final_str += f"Column(\"{row.name}\", {type_mapping[str(row[0])]}),\n"
    print(final_str)

# %%
convert_to_schema(counties_long_format)
# Out:
# Column("state_id_fips", String),
# Column("county_id_fips", String),
# Column("state", String),
# Column("county", String),
# Column("facility_type", String),
# Column("resource_or_sector", String),
# Column("status", String),
# Column("facility_count", Integer),
# Column("capacity_mw", Float, nullable=True),
# Column("co2e_tonnes_per_year", Float, nullable=True),
# Column("pm2_5_tonnes_per_year", Float, nullable=True),
# Column("nox_tonnes_per_year", Float, nullable=True),
# Column("has_ordinance", Boolean),
# Column("ordinance_jurisdiction_name", String, nullable=True),
# Column("ordinance_jurisdiction_type", String, nullable=True),
# Column("ordinance", String, nullable=True),
# Column("ordinance_earliest_year_mentioned", Float, nullable=True),
# Column("state_permitting_type", String, nullable=True),
# Column("state_permitting_text", String),

# %% [markdown]
# ## `proposed_power_dash_existing_plants` issues

# %%
proposed_power_dash_existing_plants.county_id_fips.isna().value_counts()
# Out:
# False    4041
# True        9
# Name: county_id_fips, dtype: int64

# %%
proposed_power_dash_existing_plants[proposed_power_dash_existing_plants.county_id_fips.isna()]
# Out:
#      state county state_id_fips county_id_fips         resource  capacity_mw permitting_type  has_ordinance
# 4041  None   None          None           None  Battery Storage        128.8            None          False
# 4042  None   None          None           None             Coal       9224.9            None          False
# 4043  None   None          None           None      Natural Gas      22893.6            None          False
# 4044  None   None          None           None            Hydro       3115.4            None          False
# 4045  None   None          None           None          Nuclear       9487.3            None          False
# 4046  None   None          None           None              Oil       1340.7            None          False
# 4047  None   None          None           None            Other       1197.5            None          False
# 4048  None   None          None           None            Solar       1274.0            None          False
# 4049  None   None          None           None     Onshore Wind       5361.1            None          False

# %%
proposed_power_dash_existing_plants.resource.isna().value_counts()
# Out:
# False    4050
# Name: resource, dtype: int64

# %% [markdown]
# ## `proposed_power_dash_proposed_plants` issues

# %%
proposed_power_dash_proposed_plants.county_id_fips.isna().value_counts()
# Out:
# False    3098
# True        9
# Name: county_id_fips, dtype: int64

# %%
proposed_power_dash_proposed_plants.resource.isna().value_counts()
# Out:
# False    3098
# True        9
# Name: resource, dtype: int64

# %%
proposed_power_dash_proposed_plants[proposed_power_dash_proposed_plants.resource.isna()]
# Out:
#               state             county state_id_fips county_id_fips resource  capacity_mw  project_count permitting_type  has_ordinance
# 556        Illinois  Livingston County            17          17105     None          NaN              1           Local          False
# 1920           Ohio     Madison County            39          39097     None          NaN              1          Hybrid          False
# 2155   Pennsylvania  Clearfield County            42          42033     None          NaN              1           Local          False
# 2239   Pennsylvania       Tioga County            42          42117     None          NaN              1           Local          False
# 2254   Pennsylvania        York County            42          42133     None          NaN              1           Local          False
# 2779       Virginia    Campbell County            51          51031     None          NaN              2          Hybrid          False
# 2996  West Virginia   Jefferson County            54          54037     None          NaN              1           State           True
# 3013  West Virginia     Preston County            54          54077     None          NaN              1           State          False
# 3106           None               None          None           None     None          NaN              3            None          False

# %%
proposed_power_dash_proposed_plants[proposed_power_dash_proposed_plants.county_id_fips.isna()]
# Out:
#      state county state_id_fips county_id_fips         resource  capacity_mw  project_count permitting_type  has_ordinance
# 3098  None   None          None           None  Battery Storage      6629.50             38            None          False
# 3099  None   None          None           None            Hydro        53.00              2            None          False
# 3100  None   None          None           None      Natural Gas      5529.00              9            None          False
# 3101  None   None          None           None    Offshore Wind     16043.00             25            None          False
# 3102  None   None          None           None     Onshore Wind      3859.00             11            None          False
# 3103  None   None          None           None            Other        86.00              6            None          False
# 3104  None   None          None           None            Solar     13565.13            133            None          False
# 3105  None   None          None           None          Unknown        34.20              4            None          False
# 3106  None   None          None           None             None          NaN              3            None          False

# %% [markdown]
# ## `co2_dashboard` Issues

# %%
co2_dashboard[["id", "county_id_fips"]].duplicated().value_counts()
# Out:
# False    3888
# dtype: int64

# %%
co2_dashboard[["id"]].duplicated().value_counts()
# Out:
# False    3784
# True      104
# dtype: int64

# %%
co2_dashboard[co2_dashboard.id.duplicated(keep=False)].sort_values(by="id")
# Out:
#                state              county state_id_fips      id county_id_fips  co2e_tonnes_per_year   facility_type
# 0         California  Santa Clara County            06     7.0          06085          6.610619e+04  proposed_power
# 566          Alabama       Etowah County            01     7.0          01055          3.325334e+04  existing_power
# 1         California       Fresno County            06   130.0          06019          1.972065e+05  proposed_power
# 601   South Carolina     Berkeley County            45   130.0          45015          6.158802e+06  existing_power
# 4        Connecticut     Hartford County            09   624.0          09003          6.260524e+04  proposed_power
# ...              ...                 ...           ...     ...            ...                   ...             ...
# 1819       Minnesota       Martin County            27  7925.0          27091          2.812435e+04  existing_power
# 282             None                None          None  8013.0           None          1.404757e+05  proposed_power
# 1865       Wisconsin       Sawyer County            55  8013.0          55113          6.656400e+00  existing_power
# 275        Tennessee       Shelby County            47  8056.0          47157          7.199602e+04  proposed_power
# 1885       Louisiana  St. Charles Parish            22  8056.0          22089          7.740225e+04  existing_power
#
# [208 rows x 7 columns]

# %%
co2_dashboard[["id", "facility_type"]].duplicated().value_counts()
# Out:
# False    3888
# dtype: int64

# %%
co2_dashboard[["id", "facility_type"]].isna().value_counts()
# Out:
# id     facility_type
# False  False            3887
# True   False               1
# dtype: int64

# %%
co2_dashboard[co2_dashboard.id.isna()]
# Out:
#     state county state_id_fips  id county_id_fips  co2e_tonnes_per_year            facility_type
# 564  None   None          None NaN           None          14190.686722  proposed_infrastructure

# %%
co2_dashboard.facility_type.value_counts()
# Out:
# existing_power             3323
# proposed_power              284
# proposed_infrastructure     281
# Name: facility_type, dtype: int64

# %% [markdown]
# co2_dashboard merges proposed and existing fossil plants and facilities. They all have ids that come from different datasets which is why there are duplicates. co2_dashboard is missing one id :(

# %% [markdown]
# ## `counties_long_format` issues

# %%
counties_long_format[["county_id_fips", "facility_type", "resource_or_sector", "status"]].duplicated().value_counts()
# Out:
# False    7087
# dtype: int64

# %%
counties_long_format[["county_id_fips", "facility_type", "resource_or_sector", "status"]].isna().value_counts()
# Out:
# county_id_fips  facility_type  resource_or_sector  status
# False           False          False               False     7087
# dtype: int64

# %%
counties_long_format
# Out:
#      state_id_fips county_id_fips          state            county          facility_type           resource_or_sector    status  facility_count  capacity_mw  co2e_tonnes_per_year  pm2_5_tonnes_per_year  nox_tonnes_per_year  has_ordinance ordinance_jurisdiction_name ordinance_jurisdiction_type                                          ordinance  ordinance_earliest_year_mentioned state_permitting_type                              state_permitting_text
# 0               01          01001        Alabama    Autauga County            power plant              Battery Storage  proposed               1         80.0                   NaN                    NaN                  NaN          False                        None                        None                                               None                                NaN                 Local  According to the Wind Energy Technology Office...
# 1               01          01001        Alabama    Autauga County            power plant                        Solar  proposed               1         80.0                   NaN                    NaN                  NaN          False                        None                        None                                               None                                NaN                 Local  According to the Wind Energy Technology Office...
# 2               01          01003        Alabama    Baldwin County            power plant              Battery Storage  proposed               3        160.0                   NaN                    NaN                  NaN           True              Baldwin County                      county  Large wind energy conversion systems (WECS), U...                                NaN                 Local  According to the Wind Energy Technology Office...
# 3               01          01003        Alabama    Baldwin County            power plant                        Solar  proposed               3        240.0                   NaN                    NaN                  NaN           True              Baldwin County                      county  Large wind energy conversion systems (WECS), U...                                NaN                 Local  According to the Wind Energy Technology Office...
# 4               01          01011        Alabama    Bullock County            power plant                        Solar  proposed               1         79.0                   NaN                    NaN                  NaN          False                        None                        None                                               None                                NaN                 Local  According to the Wind Energy Technology Office...
# ...            ...            ...            ...               ...                    ...                          ...       ...             ...          ...                   ...                    ...                  ...            ...                         ...                         ...                                                ...                                ...                   ...                                                ...
# 7082            54          54051  West Virginia   Marshall County  fossil infrastructure  Petrochemicals and Plastics  proposed               2          NaN          1.364022e+06              70.702824           162.032766          False                        None                        None                                               None                                NaN                 State  The West Virginia Public Service Commission ha...
# 7083            54          54073  West Virginia  Pleasants County  fossil infrastructure  Petrochemicals and Plastics  proposed               1          NaN                   NaN              13.617754            71.697552          False                        None                        None                                               None                                NaN                 State  The West Virginia Public Service Commission ha...
# 7084            54          54095  West Virginia      Tyler County  fossil infrastructure                  Natural Gas  proposed               1          NaN          1.342706e+05               7.919271           124.610932          False                        None                        None                                               None                                NaN                 State  The West Virginia Public Service Commission ha...
# 7085            54          54103  West Virginia     Wetzel County  fossil infrastructure                  Natural Gas  proposed               1          NaN          1.211047e+05               0.000000            41.701480          False                        None                        None                                               None                                NaN                 State  The West Virginia Public Service Commission ha...
# 7086            56          56005        Wyoming   Campbell County  fossil infrastructure                  Natural Gas  proposed               2          NaN          6.706397e+04               6.608389            65.467006          False                        None                        None                                               None                                NaN                Hybrid  State law requires project developers to obtai...
#
# [7087 rows x 19 columns]

# %% [markdown]
# ## Sorting out dtypes issues

# %%
from dbcp.models.data_mart import metadata

with engine.connect() as con:
    counties_long_format = pd.read_sql_query("select * from data_mart.counties_long_format", con)

# %%
counties_long_format.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7087 entries, 0 to 7086
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   state_id_fips                      7087 non-null   object
#  1   county_id_fips                     7087 non-null   object
#  2   state                              7087 non-null   object
#  3   county                             7087 non-null   object
#  4   facility_type                      7087 non-null   object
#  5   resource_or_sector                 7087 non-null   object
#  6   status                             7087 non-null   object
#  7   facility_count                     7087 non-null   int64
#  8   capacity_mw                        6909 non-null   float64
#  9   co2e_tonnes_per_year               1887 non-null   float64
#  10  pm2_5_tonnes_per_year              178 non-null    float64
#  11  nox_tonnes_per_year                178 non-null    float64
#  12  has_ordinance                      7087 non-null   bool
#  13  ordinance_jurisdiction_name        379 non-null    object
#  14  ordinance_jurisdiction_type        379 non-null    object
#  15  ordinance                          379 non-null    object
#  16  ordinance_earliest_year_mentioned  339 non-null    float64
#  17  state_permitting_type              6951 non-null   object
#  18  state_permitting_text              7087 non-null   object
# dtypes: bool(1), float64(5), int64(1), object(12)
# memory usage: 1003.7+ KB

# %%
counties_long_format.convert_dtypes().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7087 entries, 0 to 7086
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   state_id_fips                      7087 non-null   string
#  1   county_id_fips                     7087 non-null   string
#  2   state                              7087 non-null   string
#  3   county                             7087 non-null   string
#  4   facility_type                      7087 non-null   string
#  5   resource_or_sector                 7087 non-null   string
#  6   status                             7087 non-null   string
#  7   facility_count                     7087 non-null   Int64
#  8   capacity_mw                        6909 non-null   Float64
#  9   co2e_tonnes_per_year               1887 non-null   Float64
#  10  pm2_5_tonnes_per_year              178 non-null    Float64
#  11  nox_tonnes_per_year                178 non-null    Float64
#  12  has_ordinance                      7087 non-null   boolean
#  13  ordinance_jurisdiction_name        379 non-null    string
#  14  ordinance_jurisdiction_type        379 non-null    string
#  15  ordinance                          379 non-null    string
#  16  ordinance_earliest_year_mentioned  339 non-null    Int64
#  17  state_permitting_type              6951 non-null   string
#  18  state_permitting_text              7087 non-null   string
# dtypes: Float64(4), Int64(2), boolean(1), string(12)
# memory usage: 1.0 MB

# %%
str(metadata.tables["data_mart.counties_long_format"].columns[0].type)
# Out:
# 'VARCHAR'

# %%
sa_to_pd_types = {"VARCHAR": "string", "INTEGER": "Int64", "FLOAT": "float", "BOOLEAN": "bool"}

def get_dtypes_from_schema(table_name, schema):
    table_name = f"{schema}.{table_name}"
    return {column.name: sa_to_pd_types[str(column.type)] for column in metadata.tables[table_name].columns}


get_dtypes_from_schema("counties_long_format", "data_mart")
# Out:
# {'state_id_fips': 'string',
#  'county_id_fips': 'string',
#  'state': 'string',
#  'county': 'string',
#  'facility_type': 'string',
#  'resource_or_sector': 'string',
#  'status': 'string',
#  'facility_count': 'Int64',
#  'capacity_mw': 'float',
#  'co2e_tonnes_per_year': 'float',
#  'pm2_5_tonnes_per_year': 'float',
#  'nox_tonnes_per_year': 'float',
#  'has_ordinance': 'bool',
#  'ordinance_jurisdiction_name': 'string',
#  'ordinance_jurisdiction_type': 'string',
#  'ordinance': 'string',
#  'ordinance_earliest_year_mentioned': 'Int64',
#  'state_permitting_type': 'string',
#  'state_permitting_text': 'string'}

# %%
# table_name = "data_mart.counties_long_format"
# # table_name = "counties_long_format"

# with engine.connect() as con:
#     counties_long_format = pd.read_sql_query("select * from %s", con, params=[table_name], dtype=get_dtypes_from_schema("counties_long_format", "data_mart"))
# counties_long_format.info()

# %% [markdown]
# ## SA to BQ schema

# %%
metadata.tables["data_mart.counties_long_format"].columns[0].nullable
# Out:
# False

# %%
sa_to_bq_types = {"VARCHAR": "STRING", "INTEGER": "INTEGER", "FLOAT": "FLOAT", "BOOLEAN": "BOOL"}
sa_to_bq_modes = {True: "NULLABLE", False: "REQUIRED"}

def get_dtypes_from_schema(table_name, schema):
    table_name = f"{schema}.{table_name}"
    bq_schema = []
    for column in metadata.tables[table_name].columns:
        col_schema = {}
        col_schema["name"] = column.name
        col_schema["type"] = sa_to_bq_types[str(column.type)]
        col_schema["mode"] = sa_to_bq_modes[column.nullable]
        bq_schema.append(col_schema)   
    return bq_schema


get_dtypes_from_schema("counties_long_format", "data_mart")
# Out:
# [{'name': 'state_id_fips', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'county_id_fips', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'state', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'county', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'facility_type', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'resource_or_sector', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'status', 'type': 'STRING', 'mode': 'REQUIRED'},
#  {'name': 'facility_count', 'type': 'INTEGER', 'mode': 'REQUIRED'},
#  {'name': 'capacity_mw', 'type': 'FLOAT', 'mode': 'NULLABLE'},
#  {'name': 'co2e_tonnes_per_year', 'type': 'FLOAT', 'mode': 'NULLABLE'},
#  {'name': 'pm2_5_tonnes_per_year', 'type': 'FLOAT', 'mode': 'NULLABLE'},
#  {'name': 'nox_tonnes_per_year', 'type': 'FLOAT', 'mode': 'NULLABLE'},
#  {'name': 'has_ordinance', 'type': 'BOOL', 'mode': 'REQUIRED'},
#  {'name': 'ordinance_jurisdiction_name', 'type': 'STRING', 'mode': 'NULLABLE'},
#  {'name': 'ordinance_jurisdiction_type', 'type': 'STRING', 'mode': 'NULLABLE'},
#  {'name': 'ordinance', 'type': 'STRING', 'mode': 'NULLABLE'},
#  {'name': 'ordinance_earliest_year_mentioned',
#   'type': 'INTEGER',
#   'mode': 'NULLABLE'},
#  {'name': 'state_permitting_type', 'type': 'STRING', 'mode': 'NULLABLE'},
#  {'name': 'state_permitting_text', 'type': 'STRING', 'mode': 'REQUIRED'}]

# %%
from sqlalchemy import (
    Boolean,
    Column,
    DateTime,
    Float,
    Integer,
    MetaData,
    String,
    Table,
)

c = Column("state_id_fips", String, nullable=False, doc="Description", info={"source": "NREL"})
c.doc
# Out:
# 'Description'

# %%
c.info
# Out:
# {'source': 'NREL'}

# %% [markdown]
# ## Data Type issues after dropping pandera validation calls

# %%
import dbcp
pudl_tables = dbcp.etl.etl_pudl_tables()
# Out:
# /app/.local/lib/python3.9/site-packages/pudl/analysis/allocate_net_gen.py:784: UserWarning: Ooopsies. You got 8 records where the 'frac' column isn't adding up to 1 for each 'IDX_PM_FUEL' group. Check 'make_allocation_frac()'
#   warnings.warn(

# %%
mcoe = pudl_tables["mcoe"]
# mcoe.query("fuel_cost_from_eiaapi == False")
print((mcoe.fuel_cost_from_eiaapi == False).value_counts())
print((mcoe.fuel_cost_from_eiaapi == 0.0).value_counts())
mcoe[(mcoe.fuel_cost_from_eiaapi == False)]
# Out:
# False    27627
# True      2426
# Name: fuel_cost_from_eiaapi, dtype: int64
# False    27627
# True      2426
# Name: fuel_cost_from_eiaapi, dtype: int64
#        plant_id_eia generator_id report_date  unit_id_pudl  plant_id_pudl                       plant_name_eia  utility_id_eia  utility_id_pudl                  utility_name_eia  associated_combined_heat_power balancing_authority_code_eia                       balancing_authority_name_eia   bga_source  bypass_heat_recovery  capacity_factor  capacity_mw  carbon_capture              city  cofire_fuels  county current_planned_operating_date data_source  deliver_power_transgrid  distributed_generation  duct_burners energy_source_1_transport_1 energy_source_1_transport_2 energy_source_1_transport_3 energy_source_2_transport_1 energy_source_2_transport_2 energy_source_2_transport_3 energy_source_code_1 energy_source_code_2 energy_source_code_3 energy_source_code_4 energy_source_code_5 energy_source_code_6  ferc_cogen_status  ferc_exempt_wholesale_generator  ferc_small_power_producer  fluidized_bed_tech  fuel_cost_from_eiaapi  fuel_cost_per_mmbtu  fuel_cost_per_mwh fuel_type_code_pudl  \
# 7                 3            1  2020-01-01             1             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.057793        153.1            <NA>             Bucks         False  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             2.365169                NaN                 gas
# 8                 3            2  2020-01-01             2             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.057793        153.1            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             2.365169                NaN                 gas
# 10                3            4  2020-01-01             4             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.250678        403.7            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                  BIT                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             3.228131                NaN                coal
# 11                3            5  2020-01-01             5             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.250678        788.8            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                  BIT                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             3.228131                NaN                coal
# 12                3         A1CT  2020-01-01             6             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans  string_assn                 False         0.850705        170.1            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             2.365169                NaN                 gas
# ...             ...          ...         ...           ...            ...                                  ...             ...              ...                               ...                             ...                          ...                                                ...          ...                   ...              ...          ...             ...               ...           ...     ...                            ...         ...                      ...                     ...           ...                         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...                  ...                ...                              ...                        ...                 ...                    ...                  ...                ...                 ...
# 26681         62116           1B  2020-01-01             1           1388  AES Huntington Beach Energy Project           61670             6988  AES Huntington Beach Energy, LLC                           False                         CISO             California Independent System Operator  string_assn                 False         0.210276        231.0           False  Huntington Beach         False  Orange                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0                  NaN                NaN                 gas
# 26682         62116           1S  2020-01-01             1           1388  AES Huntington Beach Energy Project           61670             6988  AES Huntington Beach Energy, LLC                           False                         CISO             California Independent System Operator   eia860_org                 False         0.207252        237.2           False  Huntington Beach         False  Orange                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0                  NaN                NaN                 gas
# 28999         64020         CTG3  2020-01-01             1          14737         West Riverside Energy Center           20856              364        Wisconsin Power & Light Co                           False                         MISO  Midcontinent Independent Transmission System O...  string_assn                 False         0.306569        232.9           False            Beloit          <NA>    Rock                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             3.304203                NaN                 gas
# 29000         64020         CTG4  2020-01-01             1          14737         West Riverside Energy Center           20856              364        Wisconsin Power & Light Co                           False                         MISO  Midcontinent Independent Transmission System O...  string_assn                 False         0.306569        232.9           False            Beloit          <NA>    Rock                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             3.304203                NaN                 gas
# 29002         64020         STG2  2020-01-01             1          14737         West Riverside Energy Center           20856              364        Wisconsin Power & Light Co                           False                         MISO  Midcontinent Independent Transmission System O...   eia860_org                 False         0.301686        257.4           False            Beloit          <NA>    Rock                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                    0.0             3.304203                NaN                 gas
#
#        fuel_type_count  grid_voltage_2_kv  grid_voltage_3_kv  grid_voltage_kv  heat_rate_mmbtu_mwh iso_rto_code   latitude   longitude  minimum_load_mw  multiple_fuels  nameplate_power_factor  net_generation_mwh operating_date operating_switch operational_status operational_status_code original_planned_operating_date  other_combustion_tech other_modifications_date  other_planned_modifications  owned_by_non_utility ownership_code planned_derate_date planned_energy_source_code_1  planned_modifications  planned_net_summer_capacity_derate_mw  planned_net_summer_capacity_uprate_mw  planned_net_winter_capacity_derate_mw  planned_net_winter_capacity_uprate_mw  planned_new_capacity_mw planned_new_prime_mover_code planned_repower_date planned_retirement_date planned_uprate_date  previously_canceled  primary_purpose_id_naics prime_mover_code  pulverized_coal_tech  reactive_power_output_mvar retirement_date rto_iso_lmp_node_id rto_iso_location_wholesale_reporting_id  sector_id_eia  \
# 7                    2                NaN                NaN            230.0                  NaN         <NA>  31.006900  -88.010300             55.0           False                    0.85        7.772224e+04     1954-02-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                         NaN             NaT                <NA>                                    <NA>              1
# 8                    2                NaN                NaN            230.0                  NaN         <NA>  31.006900  -88.010300             55.0           False                    0.85        7.772224e+04     1954-07-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                         NaN             NaT                <NA>                                    <NA>              1
# 10                   2                NaN                NaN            230.0                  NaN         <NA>  31.006900  -88.010300            200.0           False                    0.85        8.889303e+05     1969-12-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                         NaN             NaT                <NA>                                    <NA>              1
# 11                   2                NaN                NaN            230.0                  NaN         <NA>  31.006900  -88.010300            465.0           False                    0.85        1.736904e+06     1971-10-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                         NaN             NaT                <NA>                                    <NA>              1
# 12                   2                NaN                NaN            230.0                  NaN         <NA>  31.006900  -88.010300            104.0           False                    0.85        1.271088e+06     2000-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CT                  <NA>                         NaN             NaT                <NA>                                    <NA>              1
# ...                ...                ...                ...              ...                  ...          ...        ...         ...              ...             ...                     ...                 ...            ...              ...                ...                     ...                             ...                    ...                      ...                          ...                   ...            ...                 ...                          ...                    ...                                    ...                                    ...                                    ...                                    ...                      ...                          ...                  ...                     ...                 ...                  ...                       ...              ...                   ...                         ...             ...                 ...                                     ...            ...
# 26681                1                NaN                NaN            230.0                  NaN         <NA>  33.645618 -117.979372             85.0           False                    0.85        4.266725e+05     2020-02-01             <NA>           existing                      OP                      2020-03-01                   <NA>                      NaT                         <NA>                  <NA>              J                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                False                        22               CT                  <NA>                         NaN             NaT         hunt ctg 1b                             hunt ctg 1b              2
# 26682                1                NaN                NaN            230.0                  NaN         <NA>  33.645618 -117.979372             60.0           False                    0.85        4.318220e+05     2020-02-01             <NA>           existing                      OP                      2020-03-01                   <NA>                      NaT                         <NA>                  <NA>              J                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                False                        22               CA                  <NA>                         NaN             NaT         hunt stg 1s                             hunt stg 1s              2
# 28999                2              138.0                NaN            345.0                  NaN         <NA>  42.582051  -89.041214            115.0           False                    0.85        6.271770e+05     2020-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                        False                  <NA>              J                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CT                  <NA>                         NaN             NaT      alte.cc.wrivs1                          alte.cc.wrivs1              1
# 29000                2              138.0                NaN            345.0                  NaN         <NA>  42.582051  -89.041214            115.0           False                    0.85        6.271770e+05     2020-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                        False                  <NA>              J                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CT                  <NA>                         NaN             NaT      alte.cc.wrivs2                          alte.cc.wrivs2              1
# 29002                2              138.0                NaN            345.0                  NaN         <NA>  42.582051  -89.041214             75.0           False                    0.85        6.821130e+05     2020-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                        False                  <NA>              J                 NaT                         <NA>                   <NA>                                    NaN                                    NaN                                    NaN                                    NaN                      NaN                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CA                  <NA>                         NaN             NaT                <NA>                                    <NA>              1
#
#         sector_name_eia  solid_fuel_gasification startup_source_code_1 startup_source_code_2 startup_source_code_3 startup_source_code_4 state  stoker_tech        street_address  subcritical_tech  summer_capacity_estimate  summer_capacity_mw  summer_estimated_capability_mw  supercritical_tech  switch_oil_gas  syncronized_transmission_grid            technology_description time_cold_shutdown_full_load_code             timezone topping_bottoming_code  total_fuel_cost  total_mmbtu  turbines_inverters_hydrokinetics  turbines_num  ultrasupercritical_tech uprate_derate_completed_date  uprate_derate_during_year  winter_capacity_estimate  winter_capacity_mw  winter_estimated_capability_mw  zip_code state_id_fips county_id_fips
# 7      Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              True                      <NA>                80.0                             NaN                <NA>            <NA>                          False         Natural Gas Steam Turbine                              OVER      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>                80.0                             NaN     36512            01          01097
# 8      Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              True                      <NA>                80.0                             NaN                <NA>            <NA>                          False         Natural Gas Steam Turbine                              OVER      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>                80.0                             NaN     36512            01          01097
# 10     Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              True                      <NA>               362.0                             NaN                <NA>            <NA>                          False           Conventional Steam Coal                              OVER      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               362.0                             NaN     36512            01          01097
# 11     Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              <NA>                      <NA>               756.5                             NaN                True            <NA>                          False           Conventional Steam Coal                              OVER      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               756.5                             NaN     36512            01          01097
# 12     Electric Utility                     <NA>                  <NA>                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              <NA>                      <NA>               175.6                             NaN                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               184.5                             NaN     36512            01          01097
# ...                 ...                      ...                   ...                   ...                   ...                   ...   ...          ...                   ...               ...                       ...                 ...                             ...                 ...             ...                            ...                               ...                               ...                  ...                    ...              ...          ...                               ...           ...                      ...                          ...                        ...                       ...                 ...                             ...       ...           ...            ...
# 26681       IPP Non-CHP                    False                  <NA>                  <NA>                  <NA>                  <NA>    CA         <NA>  21730 Newland Street              <NA>                      <NA>               194.0                             NaN                <NA>           False                          False  Natural Gas Fired Combined Cycle                               12H  America/Los_Angeles                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               227.0                             NaN     92646            06          06059
# 26682       IPP Non-CHP                    False                  <NA>                  <NA>                  <NA>                  <NA>    CA         <NA>  21730 Newland Street              <NA>                      <NA>               215.0                             NaN                <NA>           False                          False  Natural Gas Fired Combined Cycle                               12H  America/Los_Angeles                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               236.0                             NaN     92646            06          06059
# 28999  Electric Utility                    False                  <NA>                  <NA>                  <NA>                  <NA>    WI         <NA>    4201 S. Walters Rd              <NA>                      <NA>               229.5                             NaN                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               238.5                             NaN     53511            55          55105
# 29000  Electric Utility                    False                  <NA>                  <NA>                  <NA>                  <NA>    WI         <NA>    4201 S. Walters Rd              <NA>                      <NA>               229.4                             NaN                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               238.1                             NaN     53511            55          55105
# 29002  Electric Utility                    False                  <NA>                  <NA>                  <NA>                  <NA>    WI         <NA>    4201 S. Walters Rd              <NA>                      <NA>               255.2                             NaN                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X              NaN          NaN                               NaN          <NA>                     <NA>                          NaT                      False                      <NA>               258.7                             NaN     53511            55          55105
#
# [2426 rows x 121 columns]

# %%
dtyped_mcoe = mcoe.convert_dtypes()
dtyped_mcoe[dtyped_mcoe.fuel_cost_from_eiaapi == False]
# Out:
#        plant_id_eia generator_id report_date  unit_id_pudl  plant_id_pudl                       plant_name_eia  utility_id_eia  utility_id_pudl                  utility_name_eia  associated_combined_heat_power balancing_authority_code_eia                       balancing_authority_name_eia   bga_source  bypass_heat_recovery  capacity_factor  capacity_mw  carbon_capture              city  cofire_fuels  county current_planned_operating_date data_source  deliver_power_transgrid  distributed_generation  duct_burners energy_source_1_transport_1 energy_source_1_transport_2 energy_source_1_transport_3 energy_source_2_transport_1 energy_source_2_transport_2 energy_source_2_transport_3 energy_source_code_1 energy_source_code_2 energy_source_code_3 energy_source_code_4 energy_source_code_5 energy_source_code_6  ferc_cogen_status  ferc_exempt_wholesale_generator  ferc_small_power_producer  fluidized_bed_tech  fuel_cost_from_eiaapi  fuel_cost_per_mmbtu  fuel_cost_per_mwh fuel_type_code_pudl  \
# 7                 3            1  2020-01-01             1             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.057793        153.1            <NA>             Bucks         False  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             2.365169               <NA>                 gas
# 8                 3            2  2020-01-01             2             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.057793        153.1            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             2.365169               <NA>                 gas
# 10                3            4  2020-01-01             4             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.250678        403.7            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                  BIT                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             3.228131               <NA>                coal
# 11                3            5  2020-01-01             5             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans   eia860_org                 False         0.250678        788.8            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                  BIT                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             3.228131               <NA>                coal
# 12                3         A1CT  2020-01-01             6             32                                Barry             195               18                  Alabama Power Co                           False                         SOCO            Southern Company Services, Inc. - Trans  string_assn                 False         0.850705        170.1            <NA>             Bucks          <NA>  Mobile                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             2.365169               <NA>                 gas
# ...             ...          ...         ...           ...            ...                                  ...             ...              ...                               ...                             ...                          ...                                                ...          ...                   ...              ...          ...             ...               ...           ...     ...                            ...         ...                      ...                     ...           ...                         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...                  ...                ...                              ...                        ...                 ...                    ...                  ...                ...                 ...
# 26681         62116           1B  2020-01-01             1           1388  AES Huntington Beach Energy Project           61670             6988  AES Huntington Beach Energy, LLC                           False                         CISO             California Independent System Operator  string_assn                 False         0.210276        231.0           False  Huntington Beach         False  Orange                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0                 <NA>               <NA>                 gas
# 26682         62116           1S  2020-01-01             1           1388  AES Huntington Beach Energy Project           61670             6988  AES Huntington Beach Energy, LLC                           False                         CISO             California Independent System Operator   eia860_org                 False         0.207252        237.2           False  Huntington Beach         False  Orange                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0                 <NA>               <NA>                 gas
# 28999         64020         CTG3  2020-01-01             1          14737         West Riverside Energy Center           20856              364        Wisconsin Power & Light Co                           False                         MISO  Midcontinent Independent Transmission System O...  string_assn                 False         0.306569        232.9           False            Beloit          <NA>    Rock                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             3.304203               <NA>                 gas
# 29000         64020         CTG4  2020-01-01             1          14737         West Riverside Energy Center           20856              364        Wisconsin Power & Light Co                           False                         MISO  Midcontinent Independent Transmission System O...  string_assn                 False         0.306569        232.9           False            Beloit          <NA>    Rock                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             3.304203               <NA>                 gas
# 29002         64020         STG2  2020-01-01             1          14737         West Riverside Energy Center           20856              364        Wisconsin Power & Light Co                           False                         MISO  Midcontinent Independent Transmission System O...   eia860_org                 False         0.301686        257.4           False            Beloit          <NA>    Rock                            NaT      eia860                     <NA>                    <NA>         False                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                        <NA>                   NG                 <NA>                 <NA>                 <NA>                 <NA>                 <NA>              False                            False                      False                <NA>                      0             3.304203               <NA>                 gas
#
#        fuel_type_count  grid_voltage_2_kv  grid_voltage_3_kv  grid_voltage_kv  heat_rate_mmbtu_mwh iso_rto_code   latitude   longitude  minimum_load_mw  multiple_fuels  nameplate_power_factor  net_generation_mwh operating_date operating_switch operational_status operational_status_code original_planned_operating_date  other_combustion_tech other_modifications_date  other_planned_modifications  owned_by_non_utility ownership_code planned_derate_date planned_energy_source_code_1  planned_modifications  planned_net_summer_capacity_derate_mw  planned_net_summer_capacity_uprate_mw  planned_net_winter_capacity_derate_mw  planned_net_winter_capacity_uprate_mw  planned_new_capacity_mw planned_new_prime_mover_code planned_repower_date planned_retirement_date planned_uprate_date  previously_canceled  primary_purpose_id_naics prime_mover_code  pulverized_coal_tech  reactive_power_output_mvar retirement_date rto_iso_lmp_node_id rto_iso_location_wholesale_reporting_id  sector_id_eia  \
# 7                    2               <NA>               <NA>            230.0                 <NA>         <NA>    31.0069    -88.0103             55.0           False                    0.85           77722.235     1954-02-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                        <NA>             NaT                <NA>                                    <NA>              1
# 8                    2               <NA>               <NA>            230.0                 <NA>         <NA>    31.0069    -88.0103             55.0           False                    0.85           77722.235     1954-07-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                        <NA>             NaT                <NA>                                    <NA>              1
# 10                   2               <NA>               <NA>            230.0                 <NA>         <NA>    31.0069    -88.0103            200.0           False                    0.85       888930.317989     1969-12-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                        <NA>             NaT                <NA>                                    <NA>              1
# 11                   2               <NA>               <NA>            230.0                 <NA>         <NA>    31.0069    -88.0103            465.0           False                    0.85      1736904.223011     1971-10-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               ST                  True                        <NA>             NaT                <NA>                                    <NA>              1
# 12                   2               <NA>               <NA>            230.0                 <NA>         <NA>    31.0069    -88.0103            104.0           False                    0.85           1271087.5     2000-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                         <NA>                  <NA>              S                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CT                  <NA>                        <NA>             NaT                <NA>                                    <NA>              1
# ...                ...                ...                ...              ...                  ...          ...        ...         ...              ...             ...                     ...                 ...            ...              ...                ...                     ...                             ...                    ...                      ...                          ...                   ...            ...                 ...                          ...                    ...                                    ...                                    ...                                    ...                                    ...                      ...                          ...                  ...                     ...                 ...                  ...                       ...              ...                   ...                         ...             ...                 ...                                     ...            ...
# 26681                1               <NA>               <NA>            230.0                 <NA>         <NA>  33.645618 -117.979372             85.0           False                    0.85            426672.5     2020-02-01             <NA>           existing                      OP                      2020-03-01                   <NA>                      NaT                         <NA>                  <NA>              J                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                False                        22               CT                  <NA>                        <NA>             NaT         hunt ctg 1b                             hunt ctg 1b              2
# 26682                1               <NA>               <NA>            230.0                 <NA>         <NA>  33.645618 -117.979372             60.0           False                    0.85            431822.0     2020-02-01             <NA>           existing                      OP                      2020-03-01                   <NA>                      NaT                         <NA>                  <NA>              J                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                False                        22               CA                  <NA>                        <NA>             NaT         hunt stg 1s                             hunt stg 1s              2
# 28999                2              138.0               <NA>            345.0                 <NA>         <NA>  42.582051  -89.041214            115.0           False                    0.85            627177.0     2020-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                        False                  <NA>              J                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CT                  <NA>                        <NA>             NaT      alte.cc.wrivs1                          alte.cc.wrivs1              1
# 29000                2              138.0               <NA>            345.0                 <NA>         <NA>  42.582051  -89.041214            115.0           False                    0.85            627177.0     2020-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                        False                  <NA>              J                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CT                  <NA>                        <NA>             NaT      alte.cc.wrivs2                          alte.cc.wrivs2              1
# 29002                2              138.0               <NA>            345.0                 <NA>         <NA>  42.582051  -89.041214             75.0           False                    0.85            682113.0     2020-05-01             <NA>           existing                      OP                             NaT                   <NA>                      NaT                        False                  <NA>              J                 NaT                         <NA>                   <NA>                                   <NA>                                   <NA>                                   <NA>                                   <NA>                     <NA>                         <NA>                  NaT                     NaT                 NaT                 <NA>                        22               CA                  <NA>                        <NA>             NaT                <NA>                                    <NA>              1
#
#         sector_name_eia  solid_fuel_gasification startup_source_code_1 startup_source_code_2 startup_source_code_3 startup_source_code_4 state  stoker_tech        street_address  subcritical_tech  summer_capacity_estimate  summer_capacity_mw  summer_estimated_capability_mw  supercritical_tech  switch_oil_gas  syncronized_transmission_grid            technology_description time_cold_shutdown_full_load_code             timezone topping_bottoming_code  total_fuel_cost  total_mmbtu  turbines_inverters_hydrokinetics  turbines_num  ultrasupercritical_tech uprate_derate_completed_date  uprate_derate_during_year  winter_capacity_estimate  winter_capacity_mw  winter_estimated_capability_mw  zip_code state_id_fips county_id_fips
# 7      Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              True                      <NA>                80.0                            <NA>                <NA>            <NA>                          False         Natural Gas Steam Turbine                              OVER      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>                80.0                            <NA>     36512            01          01097
# 8      Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              True                      <NA>                80.0                            <NA>                <NA>            <NA>                          False         Natural Gas Steam Turbine                              OVER      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>                80.0                            <NA>     36512            01          01097
# 10     Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              True                      <NA>               362.0                            <NA>                <NA>            <NA>                          False           Conventional Steam Coal                              OVER      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               362.0                            <NA>     36512            01          01097
# 11     Electric Utility                     <NA>                    NG                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              <NA>                      <NA>               756.5                            <NA>                True            <NA>                          False           Conventional Steam Coal                              OVER      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               756.5                            <NA>     36512            01          01097
# 12     Electric Utility                     <NA>                  <NA>                  <NA>                  <NA>                  <NA>    AL         <NA>      North Highway 43              <NA>                      <NA>               175.6                            <NA>                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               184.5                            <NA>     36512            01          01097
# ...                 ...                      ...                   ...                   ...                   ...                   ...   ...          ...                   ...               ...                       ...                 ...                             ...                 ...             ...                            ...                               ...                               ...                  ...                    ...              ...          ...                               ...           ...                      ...                          ...                        ...                       ...                 ...                             ...       ...           ...            ...
# 26681       IPP Non-CHP                    False                  <NA>                  <NA>                  <NA>                  <NA>    CA         <NA>  21730 Newland Street              <NA>                      <NA>               194.0                            <NA>                <NA>           False                          False  Natural Gas Fired Combined Cycle                               12H  America/Los_Angeles                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               227.0                            <NA>     92646            06          06059
# 26682       IPP Non-CHP                    False                  <NA>                  <NA>                  <NA>                  <NA>    CA         <NA>  21730 Newland Street              <NA>                      <NA>               215.0                            <NA>                <NA>           False                          False  Natural Gas Fired Combined Cycle                               12H  America/Los_Angeles                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               236.0                            <NA>     92646            06          06059
# 28999  Electric Utility                    False                  <NA>                  <NA>                  <NA>                  <NA>    WI         <NA>    4201 S. Walters Rd              <NA>                      <NA>               229.5                            <NA>                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               238.5                            <NA>     53511            55          55105
# 29000  Electric Utility                    False                  <NA>                  <NA>                  <NA>                  <NA>    WI         <NA>    4201 S. Walters Rd              <NA>                      <NA>               229.4                            <NA>                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               238.1                            <NA>     53511            55          55105
# 29002  Electric Utility                    False                  <NA>                  <NA>                  <NA>                  <NA>    WI         <NA>    4201 S. Walters Rd              <NA>                      <NA>               255.2                            <NA>                <NA>            <NA>                          False  Natural Gas Fired Combined Cycle                               12H      America/Chicago                      X             <NA>         <NA>                              <NA>          <NA>                     <NA>                          NaT                      False                      <NA>               258.7                            <NA>     53511            55          55105
#
# [2426 rows x 121 columns]

# %%
dtyped_mcoe.fluidized_bed_tech.value_counts()
# Out:
# True     134
# False     96
# Name: fluidized_bed_tech, dtype: Int64

# %%
pd.set_option('display.max_rows', 200)
dtyped_mcoe.dtypes
# Out:
# plant_id_eia                                        Int64
# generator_id                                       string
# report_date                                datetime64[ns]
# unit_id_pudl                                        Int64
# plant_id_pudl                                       Int64
# plant_name_eia                                     string
# utility_id_eia                                      Int64
# utility_id_pudl                                     Int64
# utility_name_eia                                   string
# associated_combined_heat_power                    boolean
# balancing_authority_code_eia                       string
# balancing_authority_name_eia                       string
# bga_source                                         string
# bypass_heat_recovery                              boolean
# capacity_factor                                   Float64
# capacity_mw                                       Float64
# carbon_capture                                    boolean
# city                                               string
# cofire_fuels                                      boolean
# county                                             string
# current_planned_operating_date             datetime64[ns]
# data_source                                        string
# deliver_power_transgrid                           boolean
# distributed_generation                            boolean
# duct_burners                                      boolean
# energy_source_1_transport_1                        string
# energy_source_1_transport_2                        string
# energy_source_1_transport_3                        string
# energy_source_2_transport_1                        string
# energy_source_2_transport_2                        string
# energy_source_2_transport_3                        string
# energy_source_code_1                               string
# energy_source_code_2                               string
# energy_source_code_3                               string
# energy_source_code_4                               string
# energy_source_code_5                               string
# energy_source_code_6                               string
# ferc_cogen_status                                 boolean
# ferc_exempt_wholesale_generator                   boolean
# ferc_small_power_producer                         boolean
# fluidized_bed_tech                                boolean
# fuel_cost_from_eiaapi                               Int64
# fuel_cost_per_mmbtu                               Float64
# fuel_cost_per_mwh                                 Float64
# fuel_type_code_pudl                                string
# fuel_type_count                                     Int64
# grid_voltage_2_kv                                 Float64
# grid_voltage_3_kv                                 Float64
# grid_voltage_kv                                   Float64
# heat_rate_mmbtu_mwh                               Float64
# iso_rto_code                                       string
# latitude                                          Float64
# longitude                                         Float64
# minimum_load_mw                                   Float64
# multiple_fuels                                    boolean
# nameplate_power_factor                            Float64
# net_generation_mwh                                Float64
# operating_date                             datetime64[ns]
# operating_switch                                   string
# operational_status                                 string
# operational_status_code                            string
# original_planned_operating_date            datetime64[ns]
# other_combustion_tech                             boolean
# other_modifications_date                   datetime64[ns]
# other_planned_modifications                       boolean
# owned_by_non_utility                              boolean
# ownership_code                                     string
# planned_derate_date                        datetime64[ns]
# planned_energy_source_code_1                       string
# planned_modifications                             boolean
# planned_net_summer_capacity_derate_mw               Int64
# planned_net_summer_capacity_uprate_mw             Float64
# planned_net_winter_capacity_derate_mw               Int64
# planned_net_winter_capacity_uprate_mw             Float64
# planned_new_capacity_mw                           Float64
# planned_new_prime_mover_code                       string
# planned_repower_date                       datetime64[ns]
# planned_retirement_date                    datetime64[ns]
# planned_uprate_date                        datetime64[ns]
# previously_canceled                               boolean
# primary_purpose_id_naics                            Int64
# prime_mover_code                                   string
# pulverized_coal_tech                              boolean
# reactive_power_output_mvar                          Int64
# retirement_date                            datetime64[ns]
# rto_iso_lmp_node_id                                string
# rto_iso_location_wholesale_reporting_id            string
# sector_id_eia                                       Int64
# sector_name_eia                                    string
# solid_fuel_gasification                           boolean
# startup_source_code_1                              string
# startup_source_code_2                              string
# startup_source_code_3                              string
# startup_source_code_4                              string
# state                                              string
# stoker_tech                                       boolean
# street_address                                     string
# subcritical_tech                                  boolean
# summer_capacity_estimate                          boolean
# summer_capacity_mw                                Float64
# summer_estimated_capability_mw                      Int64
# supercritical_tech                                boolean
# switch_oil_gas                                    boolean
# syncronized_transmission_grid                     boolean
# technology_description                             string
# time_cold_shutdown_full_load_code                  string
# timezone                                           string
# topping_bottoming_code                             string
# total_fuel_cost                                   Float64
# total_mmbtu                                       Float64
# turbines_inverters_hydrokinetics                    Int64
# turbines_num                                        Int64
# ultrasupercritical_tech                           boolean
# uprate_derate_completed_date               datetime64[ns]
# uprate_derate_during_year                         boolean
# winter_capacity_estimate                          boolean
# winter_capacity_mw                                Float64
# winter_estimated_capability_mw                      Int64
# zip_code                                            Int64
# state_id_fips                                      string
# county_id_fips                                     string
# dtype: object

# %%
boolean_dtyped_mcoe = dtyped_mcoe.select_dtypes("boolean")
display(boolean_dtyped_mcoe)
display(mcoe[boolean_dtyped_mcoe.columns])
# Out:
#        associated_combined_heat_power  bypass_heat_recovery  carbon_capture  cofire_fuels  deliver_power_transgrid  distributed_generation  duct_burners  ferc_cogen_status  ferc_exempt_wholesale_generator  ferc_small_power_producer  fluidized_bed_tech  multiple_fuels  other_combustion_tech  other_planned_modifications  owned_by_non_utility  planned_modifications  previously_canceled  pulverized_coal_tech  solid_fuel_gasification  stoker_tech  subcritical_tech  summer_capacity_estimate  supercritical_tech  switch_oil_gas  syncronized_transmission_grid  ultrasupercritical_tech  uprate_derate_during_year  winter_capacity_estimate
# 0                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 1                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 2                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 3                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 4                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# ...                               ...                   ...             ...           ...                      ...                     ...           ...                ...                              ...                        ...                 ...             ...                    ...                          ...                   ...                    ...                  ...                   ...                      ...          ...               ...                       ...                 ...             ...                            ...                      ...                        ...                       ...
# 30048                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30049                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30050                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30051                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30052                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                       True                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
#
# [30053 rows x 28 columns]
#        associated_combined_heat_power  bypass_heat_recovery  carbon_capture  cofire_fuels  deliver_power_transgrid  distributed_generation  duct_burners  ferc_cogen_status  ferc_exempt_wholesale_generator  ferc_small_power_producer  fluidized_bed_tech  multiple_fuels  other_combustion_tech  other_planned_modifications  owned_by_non_utility  planned_modifications  previously_canceled  pulverized_coal_tech  solid_fuel_gasification  stoker_tech  subcritical_tech  summer_capacity_estimate  supercritical_tech  switch_oil_gas  syncronized_transmission_grid  ultrasupercritical_tech  uprate_derate_during_year  winter_capacity_estimate
# 0                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 1                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 2                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 3                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>           False                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# 4                               False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                 <NA>                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                      False                      <NA>
# ...                               ...                   ...             ...           ...                      ...                     ...           ...                ...                              ...                        ...                 ...             ...                    ...                          ...                   ...                    ...                  ...                   ...                      ...          ...               ...                       ...                 ...             ...                            ...                      ...                        ...                       ...
# 30048                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30049                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30050                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30051                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                      False                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
# 30052                           False                 False            <NA>          <NA>                     <NA>                    <NA>         False              False                            False                       True                <NA>            <NA>                   <NA>                         <NA>                  <NA>                   <NA>                False                  <NA>                     <NA>         <NA>              <NA>                      <NA>                <NA>            <NA>                          False                     <NA>                       <NA>                      <NA>
#
# [30053 rows x 28 columns]
