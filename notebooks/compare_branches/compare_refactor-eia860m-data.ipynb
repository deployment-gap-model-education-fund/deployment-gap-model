# %% [markdown]
# # Compare output from new branch to base branch
#
# This can be done by running `make all` on the base branch, copying the output to a temporary folder, and doing the same for the new branch.

# %%
import os
import pandas as pd
from pprint import pprint

# %%
BASE_BRANCH = "dev"
NEW_BRANCH = "refactor-eia860m-data"
PATH_ROOT = "../../data/tmp"

# %%
base_branch_files = os.listdir(os.path.join(PATH_ROOT, BASE_BRANCH))
new_branch_files = os.listdir(os.path.join(PATH_ROOT, NEW_BRANCH))

print("base:")
pprint(base_branch_files)
print("new:")
pprint(new_branch_files)
# Out:
# base:
# ['pudl_eia860m_status_codes.parquet',
#  'pudl_eia860m_changelog.parquet',
#  'projects_history_860m.parquet',
#  'projects_status_codes_860m.parquet',
#  'projects_current_860m.parquet',
#  'pudl_generators.parquet',
#  'projects_transition_dates_860m.parquet']
# new:
# ['projects_current_eia860m.parquet',
#  'projects_status_yearly_eia860m.parquet',
#  'pudl_eia860m_status_codes.parquet',
#  'projects_status_quarterly_eia860m.parquet',
#  'pudl_eia860m_changelog.parquet',
#  'projects_status_transition_dates_eia860m.parquet',
#  'pudl_generators.parquet',
#  'projects_status_codes_eia860m.parquet']

# %% [markdown]
# # Compare similar tables before and after

# %% [markdown]
# ## Changelog

# %%
changelog_base = pd.read_parquet(os.path.join(PATH_ROOT, BASE_BRANCH, "pudl_eia860m_changelog.parquet"))
changelog_new = pd.read_parquet(os.path.join(PATH_ROOT, NEW_BRANCH, "pudl_eia860m_changelog.parquet"))

# %%
print("columns removed:", [col for col in changelog_base if col not in changelog_new])
print("columns added:", [col for col in changelog_new if col not in changelog_base])
# Out:
# columns removed: ['county', 'operational_status', 'state']
# columns added: ['raw_county', 'operational_status_category', 'raw_state', 'iso_region']

# %%
changelog_base_compare = (
    changelog_base.rename(
        columns={"county": "raw_county", "state": "raw_state", "operational_status": "operational_status_category"}
    )
)

# %%
changelog_base_compare.compare(changelog_new[[c for c in changelog_base_compare]])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
changelog_base_compare.equals(changelog_new[[c for c in changelog_base_compare]])
# Out:
# True

# %% [markdown]
# ## EIA860M current

# %%
current_base = pd.read_parquet(os.path.join(PATH_ROOT, BASE_BRANCH, "projects_current_860m.parquet"))
current_new = pd.read_parquet(os.path.join(PATH_ROOT, NEW_BRANCH, "projects_current_eia860m.parquet"))

# %%
current_base.head()
# Out:
#   report_date                   plant_name_eia  plant_id_eia generator_id  \
# 0  2024-12-01                        Cow Creek           229            1
# 1  2024-12-01                        Cow Creek           229            2
# 2  2024-12-01                           Kilarc           253            1
# 3  2024-12-01  Indian River Generating Station           594            4
# 4  2024-12-01                         Big Bend           645          ST4
#
#         state        county  utility_id_eia             utility_name_eia  \
# 0  California        Shasta           14328   Pacific Gas & Electric Co.
# 1  California        Shasta           14328   Pacific Gas & Electric Co.
# 2  California        Shasta           14328   Pacific Gas & Electric Co.
# 3    Delaware        Sussex            9332  Indian River Operations Inc
# 4     Florida  Hillsborough           18454            Tampa Electric Co
#
#    operational_status_code operational_status_category  ...  \
# 0                        8                     retired  ...
# 1                        8                     retired  ...
# 2                        8                     retired  ...
# 3                        7                    existing  ...
# 4                        7                    existing  ...
#
#   planned_derate_date planned_generator_retirement_date  \
# 0                 NaT                               NaT
# 1                 NaT                               NaT
# 2                 NaT                               NaT
# 3                 NaT                        2025-02-01
# 4                 NaT                               NaT
#
#    planned_net_summer_capacity_derate_mw  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                   37.0
#
#   planned_net_summer_capacity_uprate_mw planned_uprate_date  \
# 0                                   NaN                 NaT
# 1                                   NaN                 NaT
# 2                                   NaN                 NaT
# 3                                   NaN                 NaT
# 4                                   NaN                 NaT
#
#        technology_description  state_id_fips county_id_fips  raw_state  \
# 0  Conventional Hydroelectric             06          06089         CA
# 1  Conventional Hydroelectric             06          06089         CA
# 2  Conventional Hydroelectric             06          06089         CA
# 3     Conventional Steam Coal             10          10005         DE
# 4     Conventional Steam Coal             12          12057         FL
#
#      raw_county
# 0        Shasta
# 1        Shasta
# 2        Shasta
# 3        Sussex
# 4  Hillsborough
#
# [5 rows x 32 columns]

# %%
current_new.head()
# Out:
#   report_date                   plant_name_eia  plant_id_eia generator_id  \
# 0  2024-12-01                        Cow Creek           229            1
# 1  2024-12-01                        Cow Creek           229            2
# 2  2024-12-01                           Kilarc           253            1
# 3  2024-12-01  Indian River Generating Station           594            4
# 4  2024-12-01                         Big Bend           645          ST4
#
#         state        county  utility_id_eia             utility_name_eia  \
# 0  California        Shasta           14328   Pacific Gas & Electric Co.
# 1  California        Shasta           14328   Pacific Gas & Electric Co.
# 2  California        Shasta           14328   Pacific Gas & Electric Co.
# 3    Delaware        Sussex            9332  Indian River Operations Inc
# 4     Florida  Hillsborough           18454            Tampa Electric Co
#
#    operational_status_code operational_status_category  ...  \
# 0                        8                     retired  ...
# 1                        8                     retired  ...
# 2                        8                     retired  ...
# 3                        7                    existing  ...
# 4                        7                    existing  ...
#
#   planned_derate_date planned_generator_retirement_date  \
# 0                 NaT                               NaT
# 1                 NaT                               NaT
# 2                 NaT                               NaT
# 3                 NaT                        2025-02-01
# 4                 NaT                               NaT
#
#    planned_net_summer_capacity_derate_mw  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                   37.0
#
#   planned_net_summer_capacity_uprate_mw planned_uprate_date  \
# 0                                   NaN                 NaT
# 1                                   NaN                 NaT
# 2                                   NaN                 NaT
# 3                                   NaN                 NaT
# 4                                   NaN                 NaT
#
#        technology_description  state_id_fips county_id_fips  raw_state  \
# 0  Conventional Hydroelectric             06          06089         CA
# 1  Conventional Hydroelectric             06          06089         CA
# 2  Conventional Hydroelectric             06          06089         CA
# 3     Conventional Steam Coal             10          10005         DE
# 4     Conventional Steam Coal             12          12057         FL
#
#      raw_county
# 0        Shasta
# 1        Shasta
# 2        Shasta
# 3        Sussex
# 4  Hillsborough
#
# [5 rows x 32 columns]

# %%
current_base.equals(current_new)
# Out:
# True

# %% [markdown]
# ## Quarterly project status

# %%
projects_quarterly_base = pd.read_parquet(os.path.join(PATH_ROOT, BASE_BRANCH, "projects_history_860m.parquet"))
projects_quarterly_new = pd.read_parquet(os.path.join(PATH_ROOT, NEW_BRANCH, "projects_status_quarterly_eia860m.parquet"))

# %%
projects_quarterly_base.head()
# Out:
#   plant_name_eia  plant_id_eia generator_id quarter_end  \
# 0     Sand Point             1            1  2022-03-31
# 1     Sand Point             1            1  2022-06-30
# 2     Sand Point             1            1  2022-09-30
# 3     Sand Point             1            1  2022-12-31
# 4     Sand Point             1            1  2023-03-31
#
#    operational_status_code
# 0                        7
# 1                        7
# 2                        7
# 3                        7
# 4                        7

# %%
projects_quarterly_new.head()
# Out:
#   plant_name_eia  plant_id_eia generator_id quarter_start quarter_end  \
# 0     Sand Point             1            1    2022-01-01  2022-03-31
# 1     Sand Point             1            1    2022-04-01  2022-06-30
# 2     Sand Point             1            1    2022-07-01  2022-09-30
# 3     Sand Point             1            1    2022-10-01  2022-12-31
# 4     Sand Point             1            1    2023-01-01  2023-03-31
#
#    operational_status_code
# 0                        7
# 1                        7
# 2                        7
# 3                        7
# 4                        7

# %%
projects_quarterly_base.dtypes
# Out:
# plant_name_eia                     string
# plant_id_eia                        Int64
# generator_id                       string
# quarter_end                datetime64[ns]
# operational_status_code             Int64
# dtype: object

# %%
projects_quarterly_new.dtypes
# Out:
# plant_name_eia                     string
# plant_id_eia                        Int64
# generator_id                       string
# quarter_start              datetime64[ns]
# quarter_end                datetime64[ns]
# operational_status_code             Int64
# dtype: object

# %%
projects_quarterly_base.shape, projects_quarterly_new.shape
# Out:
# ((429828, 5), (429828, 6))

# %%
projects_quarterly_base.head()
# Out:
#   plant_name_eia  plant_id_eia generator_id quarter_end  \
# 0     Sand Point             1            1  2022-03-31
# 1     Sand Point             1            1  2022-06-30
# 2     Sand Point             1            1  2022-09-30
# 3     Sand Point             1            1  2022-12-31
# 4     Sand Point             1            1  2023-03-31
#
#    operational_status_code
# 0                        7
# 1                        7
# 2                        7
# 3                        7
# 4                        7

# %%
projects_quarterly_new.head()
# Out:
#   plant_name_eia  plant_id_eia generator_id quarter_start quarter_end  \
# 0     Sand Point             1            1    2022-01-01  2022-03-31
# 1     Sand Point             1            1    2022-04-01  2022-06-30
# 2     Sand Point             1            1    2022-07-01  2022-09-30
# 3     Sand Point             1            1    2022-10-01  2022-12-31
# 4     Sand Point             1            1    2023-01-01  2023-03-31
#
#    operational_status_code
# 0                        7
# 1                        7
# 2                        7
# 3                        7
# 4                        7

# %%
projects_quarterly_base.equals(projects_quarterly_new[[c for c in projects_quarterly_base]])
# Out:
# True

# %% [markdown]
# # New tables: yearly and monthly

# %%
projects_yearly_new = pd.read_parquet(os.path.join(PATH_ROOT, NEW_BRANCH, "projects_status_yearly_eia860m.parquet"))
projects_monthly_new = pd.read_parquet(os.path.join(PATH_ROOT, NEW_BRANCH, "projects_status_monthly_eia860m.parquet"))

# %%
projects_yearly_new.head()
# Out:
#   plant_name_eia  plant_id_eia generator_id year_start   year_end  \
# 0     Sand Point             1            1 2022-01-01 2022-12-31
# 1     Sand Point             1            1 2023-01-01 2023-12-31
# 2     Sand Point             1            1 2024-01-01 2024-12-31
# 3     Sand Point             1            2 2022-01-01 2022-12-31
# 4     Sand Point             1            2 2023-01-01 2023-12-31
#
#    operational_status_code
# 0                        7
# 1                        7
# 2                        7
# 3                        7
# 4                        7

# %%
projects_monthly_new.head()
# Out:
#   plant_name_eia  plant_id_eia generator_id month_start  month_end  \
# 0     Sand Point             1            1  2022-02-01 2022-02-28
# 1     Sand Point             1            1  2022-03-01 2022-03-31
# 2     Sand Point             1            1  2022-04-01 2022-04-30
# 3     Sand Point             1            1  2022-05-01 2022-05-31
# 4     Sand Point             1            1  2022-06-01 2022-06-30
#
#    operational_status_code
# 0                        7
# 1                        7
# 2                        7
# 3                        7
# 4                        7

# %%
changelog_base.query("plant_name_eia == 'Sand Point' and plant_id_eia == 1 and generator_id == '1'")[["report_date", "operational_status_code"]]
# Out:
#        report_date  operational_status_code
# 153186  2020-07-01                        7
# 178803  2022-07-01                        7
# 196797  2024-04-01                        7
