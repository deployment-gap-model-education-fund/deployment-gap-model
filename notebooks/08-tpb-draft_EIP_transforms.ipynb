# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path = Path('/app/data/raw/2022.03.22OGW.xlsx')
assert path.exists()

# %%
# eip = dbcp.extract.eip_infrastructure.extract(path)
# hardcode the extract function so this notebook can be easily rerun in the future without maintenance
sheets_to_read = [
    'Facility',
    'Company',
    'Project',
    'Air Construction',  # permit status is key to identifying actionable projects
    'Pipelines',
]
eip = pd.read_excel(path, sheet_name=sheets_to_read)
rename_dict = {
    'Facility': 'eip_facilities',
    'Company': 'eip_companies',
    'Project': 'eip_projects',
    'Air Construction': 'eip_air_constr_permits',
    'Pipelines': 'eip_pipelines',
}
eip = {rename_dict[key]: df for key, df in eip.items()}

# %%
eip.keys()
# Out:
# dict_keys(['eip_facilities', 'eip_companies', 'eip_projects', 'eip_air_constr_permits', 'eip_pipelines'])

# %%
{k: df.shape for k, df in eip.items()}
# Out:
# {'eip_facilities': (563, 59),
#  'eip_companies': (439, 16),
#  'eip_projects': (672, 47),
#  'eip_air_constr_permits': (836, 26),
#  'eip_pipelines': (176, 64)}

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
fac = eip['eip_facilities']
cos = eip['eip_companies']
proj = eip['eip_projects']
air = eip['eip_air_constr_permits']
pipe = eip['eip_pipelines']

# %% [markdown]
# Outline of work
# Two parts: data cleaning and data normalization/structuring
# # Structuring and Normalizaing
# **5 entities and 5 many:many relationships means 10 tables...** But utting both pipelines and companies drops the total tables in half to 5.
#
# The *only* purpose of bringing in the companies table is to add one column with ownership info. But the marginal cost is 3 tables (2 if cutting pipelines), or 30% of tables. I'll confirm with DBCP that this is OK.
#
# Pipelines are approved at the federal level so I'm not sure they are actionable for Down Ballot people. They also have only very coarse location information (state). We punted on them last time so I would like to do so again. Marginal cost is also 3 tables, or 2 additional if cutting companies.
#
# ## Entity Relationships
# ### Entities
# * facilities
# * companies
# * projects
# * permits (air construction permits. there are many other permit types that I didn't integrate)
# * pipelines
#
# ### Relationships
# many : many
# * facilities : companies
# * facilities : projects
# * facilities : pipelines
# * companies : pipelines
# * projects : permits
#
# one : many
# * none
#
# one : one
# * none
#
# no direct relationship
# * facilities : permits (air construction permits are mediated through projects. Other permits not considered here do have direct relationships)
# * companies : projects (mediated through facilities)
# * companies : permits (mediated through projects then through facilities)
# * projects : pipelines (mediated through facilities)
# * permits : pipelines (mediated through projects then through facilities)
#
# # Cleaning
# Need to clean facilities, projects, and permits via the usual checklist. But I can ignore many unecessary columns and prefix them 'raw_' to discourage use.
# ## Facilities Cleaning
# - [x] Accuracy
# - [x] Atomicity
# - [ ] Consistency
# - [x] Completeness
# - [ ] Uniformity
# - [ ] Validity
#     - [ ] Range Validation
#     - [ ] Uniqueness Validation
#     - [ ] Set Membership Validation
#     - [ ] Type Validation
#     - [ ] Cross-Field Validation
#
# ### Accuracy
# I'm mostly using this table for location information, so I'll focus on the "street address" and "coordinates" columns. I don't have "golden data" to compare against, but I can at least spot check some items by googling them. \[Update: 3/3 spot checks of location are good. Obviously this is far from comprehensive but gives a small measure of confidence.]

# %%
fac.sample(3, random_state=42)
# Out:
#        id                         name            created_by  \
# 250   996          Oak Grove Gas Plant      EIP Test Account
# 521  4478     MarkWest Houston Complex  Alexandra Shaykevich
# 268  1015  Formosa Point Comfort Plant      EIP Test Account
#
#                      created_on           modified_by  \
# 250  2021-05-20T19:13:45.411472  Alexandra Shaykevich
# 521  2021-11-07T23:16:48.953992    Courtney Bernhardt
# 268  2021-05-20T19:13:45.411472  Alexandra Shaykevich
#
#                     modified_on  private CCS/CCUS Company (ID)  \
# 250  2022-03-07T15:31:46.717963    False      NaN         2716
# 521  2021-11-18T14:23:26.340753    False      NaN         2592
# 268  2022-01-12T21:52:21.032416    False      NaN         2545
#
#                                                Company  \
# 250          Williams Ohio Valley Midstream, LLC[2716]
# 521  MarkWest Liberty Midstream & Resources, LLC[2592]
# 268                 Formosa Plastics Corporation[2545]
#
#                Project (ID)  \
# 250                    3003
# 521                    4477
# 268  3028, 3029, 3030, 3573
#
#                                                Project State  \
# 250   Oak Grove Gas Plant - Initial Construction[3003]    WV
# 521  Houston Gas Plant No. 4 and De-ethanizer Proje...    PA
# 268  Point Comfort EDC/VCM Reactor[3028], Point Com...    TX
#
#                              Completeness Review Notes Final Review  \
# 250  QAQC Flag - 3 permits marked private - need to...          NaN
# 521                                                NaN          NaN
# 268  FOIA pending for retroactive PSDs. PN publishe...           CB
#
#     Facility Alias                               Facility Description  \
# 250            NaN                                                NaN
# 521            NaN                                                NaN
# 268            NaN  The Formosa Point Comfort Plant is an existing...
#
#     Initial Review State Facility ID Number(s) Previous Facility Name(s)  \
# 250            NaN                   051-00157                       NaN
# 521            NaN                      707367                       NaN
# 268            NaN                 RN100218973                       NaN
#
#                           Sector Primary NAICS Code Primary SIC Code  \
# 250                  Natural Gas                NaN              NaN
# 521  Petrochemicals and Plastics             211112              NaN
# 268  Petrochemicals and Plastics     325110, 325181       2812, 2821
#
#       Street Address           City ZIP Code County or Parish  \
# 250  5258 Fork Ridge    Moundsville    26041         Marshall
# 521  800 Western Ave     Washington    15301       Washington
# 268   201 Formosa Dr  Point Comfort    77978          Calhoun
#
#                                         Research Notes  \
# 250                                                NaN
# 521  https://www.ahs.dep.pa.gov/eFACTSWeb/searchRes...
# 268  https://www.fpcusa.com/about-formosa/our-opera...
#
#     Associated Facilities (ID)  \
# 250                        NaN
# 521                       1006
# 268                        NaN
#
#                                  Associated Facilities Pipelines (ID)  \
# 250                                                NaN            NaN
# 521  Shell Chemical Appalachia Petrochemicals Compl...           3691
# 268                                                NaN            NaN
#
#                                              Pipelines Air Operating (ID)  \
# 250                                                NaN                NaN
# 521  Appalachian to Texas Express (ATEX) Expansion[...                NaN
# 268                                                NaN                NaN
#
#     Air Operating CWA-NPDES (ID) CWA-NPDES  CWA Wetland (ID) CWA Wetland  \
# 250           NaN            NaN       NaN               NaN         NaN
# 521           NaN            NaN       NaN               NaN         NaN
# 268           NaN            NaN       NaN               NaN         NaN
#
#     Other Permits (ID)                           Other Permits  \
# 250                NaN                                     NaN
# 521                NaN                                     NaN
# 268               4248  Comptroller Application No. 1537[4248]
#
#      Congressional Representatives  \
# 250  David B. McKinley, Republican
# 521                            NaN
# 268      Michael Cloud, Republican
#
#                                Link to EJSCREEN Report  \
# 250  https://ejscreen.epa.gov/mapper/EJSCREEN_repor...
# 521                                                NaN
# 268  https://ejscreen.epa.gov/mapper/EJSCREEN_repor...
#
#      Estimated Population within 3 miles  \
# 250                               3282.0
# 521                               8642.0
# 268                                768.0
#
#      Percent People of Color within 3 miles  \
# 250                                     5.0
# 521                                     9.0
# 268                                    43.0
#
#      Percent Low-Income within 3 miles  \
# 250                               46.0
# 521                               25.0
# 268                               39.0
#
#      Percent under 5 Years Old within 3 miles  \
# 250                                      10.0
# 521                                       5.0
# 268                                      10.0
#
#      Percent People over 64 Years Old within 3 miles  \
# 250                                             14.0
# 521                                             24.0
# 268                                              8.0
#
#      Air Toxics Cancer Risk (NATA Cancer Risk)  Respiratory Hazard Index  \
# 250                                       25.0                      0.32
# 521                                       29.0                      0.39
# 268                                       24.0                      0.28
#
#      PM2.5 (ug/m3)  O3 (ppb)  Wastewater Discharge Indicator  \
# 250           8.33      43.1                        0.006800
# 521           9.42      45.5                        0.025000
# 268           8.47      32.6                        0.000005
#
#                   Location Facility Footprint EPA FRS ID Featured  \
# 250      -80.6959, 39.8758                NaN        NaN    False
# 521  -80.254988, 40.262146                NaN        NaN      NaN
# 268    -96.54722, 28.68889                NaN        NaN    False
#
#      Featured Facility Descriptors (ID) Featured Facility Descriptors  \
# 250                                 NaN                           NaN
# 521                                 NaN                           NaN
# 268                                 NaN                           NaN
#
#      Facility ID
# 250      10386.0
# 521          NaN
# 268      10169.0

# %% [markdown]
# Googling "Oak Grove Gas Plant" turns up the facility. [Street address](https://www.google.com/maps/place/Williams+Natural+Gas+Oak+Grove+Facility/@39.871189,-80.6944623,1177m/data=!3m1!1e3!4m13!1m7!3m6!1s0x0:0x6769abd010d373f9!2zMznCsDUyJzMyLjkiTiA4MMKwNDEnNDUuMiJX!3b1!8m2!3d39.8758!4d-80.6959!3m4!1s0x8835e69402fb74cd:0x94b44b7720f51c5!8m2!3d39.8690544!4d-80.693195) and coordinates match. Owner also matches.
#
# MarkWest Houston Complex location is also good. Google maps labels the [corporate office](https://www.google.com/maps/place/MarkWest+Houston+Plant/@40.262237,-80.2596898,1240m/data=!3m1!1e3!4m13!1m7!3m6!1s0x8834528cbcacb571:0xbd8b49797f3fdd4!2s800+Western+Ave,+Washington,+PA+15301!3b1!8m2!3d40.2584361!4d-80.2555021!3m4!1s0x8834539d500f0e45:0x248d758337e3de37!8m2!3d40.2585062!4d-80.254957) as across the street from the given address, which belongs to a different facility building. But that doesn't matter for our purposes -- we aren't sending them a letter. Owner also matches.
#
# Formosa Point Comfort plant street address matches [google maps](https://www.google.com/maps/place/Formosa+Plastics+Corporation,+Texas/@28.6804226,-96.5626898,13964m/data=!3m1!1e3!4m5!3m4!1s0x0:0x469e4fbb5f6d12a1!8m2!3d28.6975144!4d-96.5449333) and coordinates are inside the facility. Owner also matches.

# %% [markdown]
# ### Atomicity
# By inspection I see that all the ID and associated name fields can contain multiple values: company, project, pipelines, and permits. The location fields are mercifully single valued

# %%
# street address does not look multi-valued but has other problems. Thankfully lat lon is still available
# a little more digging suggests bad addresses are because these have not yet been built.
# Can't check for sure until I can join project status on to facilities
pd.options.display.max_colwidth = 0
fac.loc[fac['Street Address'].str.len().nlargest(10).index, ['id', 'name', 'Street Address', 'Location']]
# Out:
#        id                                                   name  \
# 461  3839  Rio Bravo Compressor Station 2
# 11   750   Annova LNG Brownsville
# 275  1022  Praxair Clear Lake Plant
# 398  3739  Shintech Addis Plant Expansion
# 357  1105  Turkey Creek Compressor Station
# 284  1031  El Paso Natural Gas - Red Mountain Compressor Station
# 522  4480  Lone Star Alkylate Production Facility
# 544  4676  Chickahominy Power Generating Station
# 89   829   Corpus Christi Polymer & Desalination Plant
# 375  1124  Willcox and Dragoon Compressor Stations
#
#                                                                              Street Address  \
# 461  From intersection of I69E N and US 77 N turn left onto Unnamed Rd. Go 1.5 mi site on R
# 11   USFWS Access Road (left from intersection of Boca Chica Blvd and Kingston Ave)
# 275  NW corner of Celanese Industrial Complex (N end of Bayport Blvd)
# 398  1 S (Southern portion of Addis Plant property), Addis, LA 70710
# 357  W on Onyx Rd (towards the intersection of Johnsons Landing Rd)
# 284  1.4 miles on Co Rd D0006 from the intersection with NM-418
# 522  Approx. 1.8 miles SW from FM 1942 and Hatcherville Rd
# 544  State Rd. 106 (Roxbury Rd.) and Chambers/Landfill Rd.
# 89   7001 Joe Fulton International Trade Corridor STE 200
# 375  Arzberger Rd (6 miles E of Kansas Settlement Rd)
#
#                    Location
# 461  -97.786294, 26.609886
# 11   -97.2675, 26.00556
# 275  -95.066606, 29.625159
# 398  -91.260466, 30.322319
# 357  -92.424444, 30.939722
# 284  -107.998849, 32.257081
# 522  -94.923882, 29.84787
# 544  -77.155, 37.436
# 89   -97.49595, 27.834238
# 375  -109.662345, 32.109089

# %%
# location is not multi-valued - only see two decimal points per coordinate pair
fac['Location'].str.count('\.').agg(['min', 'max'])
# Out:
# min    2.0
# max    2.0
# Name: Location, dtype: float64

# %%
# a shitload of missing facility IDs, but no multi-valued ones
fac['Facility ID'].describe()
# Out:
# count    384.000000
# mean     10195.119792
# std      113.430883
# min      10000.000000
# 25%      10096.750000
# 50%      10194.500000
# 75%      10293.250000
# max      10393.000000
# Name: Facility ID, dtype: float64

# %% [markdown]
# ### Completeness
# Notable missing values and lack of missing values:
# * 93/563 (16.5%) missing street address. Plus some addresses are not missing but look unusable.
# * 4/563 (0.7%) of facilities are missing linked Project IDs
# * 9/563 (1.6%) missing "Location" (coordinates)
# * 3/563 (tiny%) missing county (none missing state). But the true test is how successful `addfips` is with these pairs
# * 60 to 100 (10% to 18%) missing EJ Screen metrics, depending on which metric
#
# I don't know what `Facility ID` is (vs `id` of this facility table), but 179/563 (31.8%) rows are missing `Facility ID`. They have different numerical ranges and I see that the companies and project tables thankfully use the `id` numbers, which are 100% complete.
#
# Based on these nan counts, I should first try `addfips` on state/county pairs. If too many fail, the most complete option is to geocode via coordinates.

# %%
len(fac)
# Out:
# 563

# %%
fac.count().T
# Out:
# id                                                 563
# name                                               563
# created_by                                         563
# created_on                                         563
# modified_by                                        563
# modified_on                                        563
# private                                            563
# CCS/CCUS                                           17
# Company (ID)                                       563
# Company                                            563
# Project (ID)                                       559
# Project                                            559
# State                                              563
# Completeness Review Notes                          44
# Final Review                                       113
# Facility Alias                                     172
# Facility Description                               352
# Initial Review                                     56
# State Facility ID Number(s)                        455
# Previous Facility Name(s)                          35
# Sector                                             437
# Primary NAICS Code                                 214
# Primary SIC Code                                   207
# Street Address                                     470
# City                                               531
# ZIP Code                                           489
# County or Parish                                   560
# Research Notes                                     341
# Associated Facilities (ID)                         161
# Associated Facilities                              161
# Pipelines (ID)                                     207
# Pipelines                                          207
# Air Operating (ID)                                 38
# Air Operating                                      38
# CWA-NPDES (ID)                                     23
# CWA-NPDES                                          23
# CWA Wetland (ID)                                   5
# CWA Wetland                                        5
# Other Permits (ID)                                 21
# Other Permits                                      21
# Congressional Representatives                      403
# Link to EJSCREEN Report                            341
# Estimated Population within 3 miles                470
# Percent People of Color within 3 miles             504
# Percent Low-Income within 3 miles                  504
# Percent under 5 Years Old within 3 miles           504
# Percent People over 64 Years Old within 3 miles    504
# Air Toxics Cancer Risk (NATA Cancer Risk)          469
# Respiratory Hazard Index                           504
# PM2.5 (ug/m3)                                      469
# O3 (ppb)                                           469
# Wastewater Discharge Indicator                     469
# Location                                           554
# Facility Footprint                                 7
# EPA FRS ID                                         28
# Featured                                           509
# Featured Facility Descriptors (ID)                 4
# Featured Facility Descriptors                      4
# Facility ID                                        384
# dtype: int64

# %% [markdown]
# ### Consistency - defer
# Defer until I've cleaned the related datasets
# ### Uniformity
# Important columns to check consistent representation:
# * coordinates
# * ID fields (check consistent array delimiters)
#
# Secondary importance:
# * street address (this is a luxury field)
# * modified_on
#
# #### Coordinates

# %%
# "-XX.X, YY.Y" with 2 or 3 digits before the decimal and 2 to 7 digits after.
# Plus optional leading/trailing whitespace.
coord_pattern = r'\s*-\d{2,3}\.\d{2,7}, \d{2,3}\.\d{2,7}\s*'
fac['Location'].str.match(coord_pattern).sum()
# Out:
# 554

# %%
# matches count, so they all have the same formatting
fac['Location'].count()
# Out:
# 554

# %%
# tighten criteria to 3+ digits after decimal
# Reveals that only 2 facilities have poor precision (plus or minus about a km)
coord_pattern = r'\s*-\d{2,3}\.\d{3,7}, \d{2,3}\.\d{3,7}\s*'
fac['Location'].str.match(coord_pattern).sum()
# Out:
# 552

# %% [markdown]
# #### ID Fields
# Want to check for consistent array delimiters.

# %%
# exclude ID cols with numeric types (no arrays present)
id_cols = [col for col in fac.columns if '(ID)' in col and pd.api.types.is_object_dtype(fac[col])]
id_cols
# Out:
# ['Company (ID)',
#  'Project (ID)',
#  'Associated Facilities (ID)',
#  'Pipelines (ID)',
#  'Air Operating (ID)',
#  'CWA-NPDES (ID)',
#  'Other Permits (ID)']

# %%
# opening pattern, optional delimiter, optional repeating pattern, optional closing pattern, end of line
array_pattern = r'(?:\d{3,5})(?:, ?)?(?:\d{3,5}, ?)*(?:\d{3,5})?$'

# %%
test_case = pd.Series([
    '1234',
    '1234,567',
    '1234, 567',
    '12345, 678, 9012',
    '1234\t5678', # tab is bad, no comma
    '12, 3456', # too short
    '1234    5678', # too many spaces, no comma
])
pd.concat([test_case, test_case.str.match(array_pattern)], axis=1)
# Out:
#                   0      1
# 0  1234              True
# 1  1234,567          True
# 2  1234, 567         True
# 3  12345, 678, 9012  True
# 4  1234\t5678        False
# 5  12, 3456          False
# 6  1234    5678      False

# %%
# all pass the formatting test
for col in id_cols:
    assert fac[col].str.match(array_pattern).all()

# %% [markdown]
# #### Date Modified

# %%
# to_datetime works on all values present
timestamps = pd.to_datetime(fac['modified_on'])
timestamps.dtypes, timestamps.isna().sum()
# Out:
# (dtype('<M8[ns]'), 0)

# %% [markdown]
# #### Street Address - defer
# hard to test and I don't care that much if it's wrong. Best way to test is probably to outsource to a pre-built geocoder
