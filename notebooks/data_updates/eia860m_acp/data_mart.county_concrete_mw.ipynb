# %% [markdown]
# # ACP / EIA Combined table

# %%
import pandas as pd

# %%
from google.cloud import bigquery

def get_bigquery_table_version(dataset_id, table_name, project_id="dbcp-dev-350818"):
    """
    Get the data version of a BigQuery table.

    The dbcp.commands.publish script generates a version number for each data release
    and adds it as a label to the BQ tables.

    Args:
        dataset_id: the BQ dataset ID
        table_name: the name of the table
        project_id: the GCP project id

    Return:
        the current DBCP version number of the requested table
    """
    client = bigquery.Client()

    table_ref = f"{project_id}.{dataset_id}.{table_name}"
    table = client.get_table(table_ref)  # Fetch table metadata

    labels = table.labels  # Get the labels dictionary
    return labels["version"]

# %% [markdown]
# ## Get old data from published archives

# %%
from dbcp.extract.helpers import cache_gcs_archive_file_locally

table_name = "county_concrete_mw"
version = get_bigquery_table_version("data_mart_dev", table_name)
uri = f"gs://dgm-outputs/{version}/data_mart/{table_name}.parquet"
data_cache = "/app/data/gcp_outputs"

county_concrete_mw_path = cache_gcs_archive_file_locally(uri, data_cache)
county_concrete_mw_old = pd.read_parquet(county_concrete_mw_path)
# Out:
# /app/.local/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
county_concrete_mw_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   state_id_fips                    463 non-null    string
#  1   county_id_fips                   463 non-null    string
#  2   state                            463 non-null    string
#  3   county                           463 non-null    string
#  4   iso_region                       463 non-null    string
#  5   resource_clean                   463 non-null    string
#  6   capacity_under_construction_mw   280 non-null    float64
#  7   capacity_awaiting_permitting_mw  228 non-null    float64
#  8   capacity_total_proposed_mw       463 non-null    float64
# dtypes: float64(3), string(6)
# memory usage: 32.7 KB

# %% [markdown]
# ## Get new data from local parquet

# %%
county_concrete_mw_new = pd.read_parquet(
    "../../../data/output/data_mart/county_concrete_mw.parquet")
county_concrete_mw_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   state_id_fips                    427 non-null    string
#  1   county_id_fips                   427 non-null    string
#  2   state                            427 non-null    string
#  3   county                           427 non-null    string
#  4   iso_region                       427 non-null    string
#  5   resource_clean                   427 non-null    string
#  6   capacity_under_construction_mw   263 non-null    float64
#  7   capacity_awaiting_permitting_mw  204 non-null    float64
#  8   capacity_total_proposed_mw       427 non-null    float64
# dtypes: float64(3), string(6)
# memory usage: 30.1 KB

# %% [markdown]
# ## Sanity check: are old and new tables different

# %%
county_concrete_mw_new.equals(county_concrete_mw_old)
# Out:
# False

# %%
# pd.testing.assert_frame_equal(
#     capacity_by_iso_region_new,
#     capacity_by_iso_region_old
# )

# %% [markdown]
# ## Simplify ISO region

# %%
GS_REGIONS = ("MISO", "NYISO", "ISONE", "PJM", "ERCOT", "SPP", "CAISO")

# %%
county_concrete_mw_new["iso_region_clean"] = county_concrete_mw_new["iso_region"].mask(
    ~county_concrete_mw_new["iso_region"].isin(GS_REGIONS), other="NON-ISO")

county_concrete_mw_old["iso_region_clean"] = county_concrete_mw_old["iso_region"].mask(
    ~county_concrete_mw_old["iso_region"].isin(GS_REGIONS), other="NON-ISO")

# %% [markdown]
# ## % change in capacity by ISO region

# %%
capacity_by_iso_region_new = county_concrete_mw_new.groupby("iso_region_clean").sum()[
['capacity_under_construction_mw', 'capacity_awaiting_permitting_mw', 'capacity_total_proposed_mw']]

capacity_by_iso_region_old = county_concrete_mw_old.groupby("iso_region_clean").sum()[
['capacity_under_construction_mw', 'capacity_awaiting_permitting_mw', 'capacity_total_proposed_mw']]

# %%
capacity_by_iso_region_pct_change = (capacity_by_iso_region_new - capacity_by_iso_region_old) / capacity_by_iso_region_old

# %%
capacity_by_iso_region_pct_change.sort_values(by="capacity_total_proposed_mw")
# Out:
#                   capacity_under_construction_mw  \
# iso_region_clean
# ISONE                                   0.147670
# ERCOT                                  -0.260584
# MISO                                    0.266163
# CAISO                                   0.089109
# SPP                                     0.000000
# NYISO                                  -0.562084
# NON-ISO                                 0.307078
# PJM                                    -0.064461
#
#                   capacity_awaiting_permitting_mw  capacity_total_proposed_mw
# iso_region_clean
# ISONE                                   -0.666376                   -0.407696
# ERCOT                                   -0.320579                   -0.287065
# MISO                                    -0.460555                   -0.100948
# CAISO                                   -0.251107                   -0.077473
# SPP                                      0.000000                    0.000000
# NYISO                                    0.589992                    0.177722
# NON-ISO                                  0.500378                    0.423192
# PJM                                      0.907947                    0.544954

# %% [markdown]
# ## Drill down into individual projects
#
# In order to understand these numbers better, look at individual projects in the old and new data

# %%
# Note that this requires comparing old and new results of the query `eia860m_current.sql`
# Until this has been added as an intermediate table, it can be saved as a parquet manually and compared

eia_old = pd.read_parquet("eia860m_current_old.parquet")
eia_new = pd.read_parquet("eia860m_current_new.parquet")

# %%
eia_new.head()
# Out:
#   report_date  plant_id_eia                   plant_name_eia  utility_id_eia  \
# 0  2024-12-01           229                        Cow Creek           14328
# 1  2024-12-01           229                        Cow Creek           14328
# 2  2024-12-01           253                           Kilarc           14328
# 3  2024-12-01           594  Indian River Generating Station            9332
# 4  2024-12-01           645                         Big Bend           18454
#
#               utility_name_eia generator_id  capacity_mw state_id_fips  \
# 0   Pacific Gas & Electric Co.            1          0.7            06
# 1   Pacific Gas & Electric Co.            2          0.7            06
# 2   Pacific Gas & Electric Co.            1          1.5            06
# 3  Indian River Operations Inc            4        445.5            10
# 4            Tampa Electric Co          ST4        486.0            12
#
#   county_id_fips       state  ... operational_status_category  \
# 0          06089  California  ...                     retired
# 1          06089  California  ...                     retired
# 2          06089  California  ...                     retired
# 3          10005    Delaware  ...                    existing
# 4          12057     Florida  ...                    existing
#
#   raw_operational_status_code planned_derate_date  \
# 0                          RE                 NaT
# 1                          RE                 NaT
# 2                          RE                 NaT
# 3                          OP                 NaT
# 4                          OP                 NaT
#
#   planned_generator_retirement_date planned_net_summer_capacity_derate_mw  \
# 0                               NaT                                   NaN
# 1                               NaT                                   NaN
# 2                               NaT                                   NaN
# 3                        2025-02-01                                   NaN
# 4                               NaT                                  37.0
#
#    planned_net_summer_capacity_uprate_mw planned_uprate_date  \
# 0                                    NaN                 NaT
# 1                                    NaN                 NaT
# 2                                    NaN                 NaT
# 3                                    NaN                 NaT
# 4                                    NaN                 NaT
#
#        technology_description  raw_state    raw_county
# 0  Conventional Hydroelectric         CA        Shasta
# 1  Conventional Hydroelectric         CA        Shasta
# 2  Conventional Hydroelectric         CA        Shasta
# 3     Conventional Steam Coal         DE        Sussex
# 4     Conventional Steam Coal         FL  Hillsborough
#
# [5 rows x 31 columns]

# %%
eia_old['iso_region_clean'] = eia_old['iso_region'].mask(~eia_old["iso_region"].isin(GS_REGIONS), other="NON-ISO")
eia_new['iso_region_clean'] = eia_new['iso_region'].mask(~eia_new["iso_region"].isin(GS_REGIONS), other="NON-ISO")

# %%
eia_new.columns
# Out:
# Index(['report_date', 'plant_id_eia', 'plant_name_eia', 'utility_id_eia',
#        'utility_name_eia', 'generator_id', 'capacity_mw', 'state_id_fips',
#        'county_id_fips', 'state', 'county', 'iso_region',
#        'current_planned_generator_operating_date', 'energy_source_code_1',
#        'prime_mover_code', 'energy_storage_capacity_mwh',
#        'fuel_type_code_pudl', 'generator_retirement_date', 'latitude',
#        'longitude', 'operational_status_code', 'operational_status_category',
#        'raw_operational_status_code', 'planned_derate_date',
#        'planned_generator_retirement_date',
#        'planned_net_summer_capacity_derate_mw',
#        'planned_net_summer_capacity_uprate_mw', 'planned_uprate_date',
#        'technology_description', 'raw_state', 'raw_county',
#        'iso_region_clean'],
#       dtype='object')

# %%
eia_new.groupby(
    ["operational_status_code", "raw_operational_status_code", "operational_status_category"]
).plant_id_eia.count()
# Out:
# operational_status_code  raw_operational_status_code  operational_status_category
# 1                        P                            proposed                        75
# 2                        L                            proposed                        49
# 3                        T                            proposed                        31
# 4                        U                            proposed                       120
# 5                        V                            proposed                       133
# 6                        TS                           proposed                        81
# 7                        OA                           existing                        16
#                          OP                           existing                       600
#                          OS                           existing                         6
#                          SB                           existing                         3
# 8                        RE                           retired                         99
# Name: plant_id_eia, dtype: int64

# %%
# Combination of plant ID and generator ID is unique
eia_new.groupby(["plant_id_eia", "generator_id"]).count()["plant_name_eia"].max()
# Out:
# 1

# %%
eia_plant_region_status_capacity_new = eia_new.groupby(
    ['plant_id_eia', 'iso_region_clean', 'operational_status_category'], dropna=False
).agg({"capacity_mw": sum, "plant_id_eia": 'nunique'}).rename(columns={"plant_id_eia": "plant_count"}).unstack()
eia_plant_region_status_capacity_old = eia_old.groupby(
    ['plant_id_eia', 'iso_region_clean', 'operational_status_category'], dropna=False
).agg({"capacity_mw": sum, "plant_id_eia": 'nunique'}).rename(columns={"plant_id_eia": "plant_count"}).unstack()

# %%
eia_plant_region_status_capacity_combined = eia_plant_region_status_capacity_old.join(
    eia_plant_region_status_capacity_new, 
    how="outer",
    lsuffix="_old",
    rsuffix="_new",
)

# %%
# Step 1: Stack to reshape the columns
stacked = (eia_plant_region_status_capacity_combined
    .reset_index().groupby("iso_region_clean").sum().stack(level=1)
          )

# Step 2: Create percent change for each metric group
for metric in ['capacity_mw', 'plant_count']:
    old = f"{metric}_old"
    new = f"{metric}_new"
    pct_change = f"{metric}_pct_change"

    stacked[pct_change] = (stacked[new] - stacked[old]) / stacked[old] * 100

# Step 3: Unstack back to original column layout
result = stacked.unstack()
# Out:
# /tmp/ipykernel_76/1148254062.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   .reset_index().groupby("iso_region_clean").sum().stack(level=1)

# %%
result
# Out:
#                             capacity_mw_new                                 \
# operational_status_category        existing      proposed      retired
# iso_region_clean
# CAISO                           3925.500012   5949.900004     9.600000 NaN
# ERCOT                           4074.900002  19191.499981    19.400000 NaN
# ISONE                            216.599999    973.199999     0.000000 NaN
# MISO                           18904.099933   5205.100012  1582.699999 NaN
# NON-ISO                         9799.300017  14124.699980   586.099998 NaN
# NYISO                            724.699999   1472.500001     0.400000 NaN
# PJM                             6623.700007   3580.399997  2115.300000 NaN
#
#                             capacity_mw_old                               \
# operational_status_category        existing     proposed     retired
# iso_region_clean
# CAISO                            956.500000  2388.400002    0.000000 NaN
# ERCOT                           5840.900045  8317.899995  399.699997 NaN
# ISONE                            180.700000   925.800000    0.000000 NaN
# MISO                            1126.700004  6303.399992    0.000000 NaN
# NON-ISO                         6129.300010  8761.500015  272.000000 NaN
# NYISO                             49.100000   325.900000    1.800000 NaN
# PJM                              513.800001  5302.399998   37.900000 NaN
#
#                             plant_count_new           ... plant_id_eia  \
# operational_status_category        existing proposed  ...      retired
# iso_region_clean                                      ...
# CAISO                                  26.0     59.0  ...          NaN
# ERCOT                                  17.0     89.0  ...          NaN
# ISONE                                  50.0     22.0  ...          NaN
# MISO                                   84.0     61.0  ...          NaN
# NON-ISO                               135.0     98.0  ...          NaN
# NYISO                                  53.0     38.0  ...          NaN
# PJM                                    58.0     54.0  ...          NaN
#
#                                         capacity_mw_pct_change              \
# operational_status_category                           existing    proposed
# iso_region_clean
# CAISO                         8777289.0             310.402510  149.116563
# ERCOT                         9869606.0             -30.235067  130.725303
# ISONE                         7178116.0              19.867183    5.119896
# MISO                         10741019.0            1577.829047  -17.423930
# NON-ISO                      19001212.0              59.876332   61.213262
# NYISO                         7260420.0            1375.967408  351.825713
# PJM                          11105965.0            1189.159205  -32.475860
#
#                                              plant_count_pct_change  \
# operational_status_category      retired                   existing
# iso_region_clean
# CAISO                                inf NaN             -21.212121
# ERCOT                         -95.146360 NaN              13.333333
# ISONE                                NaN NaN              47.058824
# MISO                                 inf NaN             320.000000
# NON-ISO                       115.477940 NaN             206.818182
# NYISO                         -77.777777 NaN             231.250000
# PJM                          5481.266476 NaN             100.000000
#
#
# operational_status_category   proposed retired
# iso_region_clean
# CAISO                        84.375000     inf NaN
# ERCOT                        81.632653     0.0 NaN
# ISONE                         4.761905     NaN NaN
# MISO                         10.909091     inf NaN
# NON-ISO                       7.692308   400.0 NaN
# NYISO                        90.000000     0.0 NaN
# PJM                          -1.818182   350.0 NaN
#
# [7 rows x 28 columns]

# %%
# (
#     eia_plant_region_status_capacity_combined
#     .reset_index()
#     .groupby("iso_region_clean").sum()
#     .assign(
#         plant_count_pct_change=lambda df: (df.plant_count_new - df.plant_count_old) / df.plant_count_old,
#         capacity_mw_pct_change=lambda df: (df.capacity_mw_new - df.capacity_mw_old) / df.capacity_mw_old,
#     )
# )

# %%
eia_combined = pd.merge(
    eia_old, 
    eia_new[
        ['report_date', 
         'plant_id_eia',
         'plant_name_eia',
         'generator_id',
         'utility_id_eia',
         'utility_name_eia',
         'iso_region_clean',
         'capacity_mw', 
         'current_planned_generator_operating_date', 
         'operational_status_code',
         'operational_status_category',
         'raw_operational_status_code',
        ]
    ],
    on=["plant_id_eia", "plant_name_eia", "generator_id",'utility_id_eia', 'utility_name_eia' , "iso_region_clean"],
    how="outer",
    suffixes=("_old", "_new"),
)

# %% [markdown]
# #### Check that join did not cause a fan-out

# %%
eia_combined.shape
# Out:
# (1712, 38)

# %%
eia_new["unique_id"] = eia_new["plant_id_eia"].map(str) + "_" + eia_new["generator_id"].map(str)
eia_old["unique_id"] = eia_old["plant_id_eia"].map(str) + "_" + eia_old["generator_id"].map(str)

# %%
len(set(eia_new.unique_id.to_list() + eia_old.unique_id.to_list()))
# Out:
# 1698

# %%
eia_combined.query("report_date_old.isnull()").iso_region_clean.unique()
# Out:
# array(['CAISO', 'PJM', 'NON-ISO', 'MISO', 'NYISO', 'ISONE', 'ERCOT'],
#       dtype=object)

# %% [markdown]
# ### ERCOT

# %%
(
    eia_combined.query("iso_region_clean == 'ERCOT'")
    .groupby(
        ["raw_operational_status_code_old", 
         "operational_status_category_old", 
         "raw_operational_status_code_new",
         "operational_status_category_new",
        ],
        dropna=False
    )
    .agg({"plant_id_eia": "nunique", "capacity_mw_old": sum, "capacity_mw_new": sum})
    .rename(columns={"plant_id_eia": "plant_count"})
    .assign(capacity_pct_change=lambda df: (df.capacity_mw_new - df.capacity_mw_old) / df.capacity_mw_old)
).sort_values(by="capacity_pct_change")
# Out:
#                                                                                                                                  plant_count  \
# raw_operational_status_code_old operational_status_category_old raw_operational_status_code_new operational_status_category_new
# L                               proposed                        NaN                             NaN                                        6
# V                               proposed                        NaN                             NaN                                        5
# OP                              existing                        NaN                             NaN                                       14
# U                               proposed                        NaN                             NaN                                        7
# P                               proposed                        NaN                             NaN                                        5
# RE                              retired                         NaN                             NaN                                        2
# T                               proposed                        NaN                             NaN                                        1
# TS                              proposed                        NaN                             NaN                                        9
# V                               proposed                        V                               proposed                                   3
# U                               proposed                        V                               proposed                                   1
#                                                                 TS                              proposed                                   1
# P                               proposed                        U                               proposed                                   1
#                                                                 P                               proposed                                   4
# OP                              existing                        OP                              existing                                   1
# TS                              proposed                        TS                              proposed                                   4
#                                                                 OP                              existing                                   3
# NaN                             NaN                             U                               proposed                                  11
#                                                                 L                               proposed                                   3
#                                                                 OP                              existing                                  14
#                                                                 P                               proposed                                  35
#                                                                 RE                              retired                                    2
#                                                                 T                               proposed                                   2
#                                                                 TS                              proposed                                  16
#                                                                 V                               proposed                                   8
#
#                                                                                                                                  capacity_mw_old  \
# raw_operational_status_code_old operational_status_category_old raw_operational_status_code_new operational_status_category_new
# L                               proposed                        NaN                             NaN                                   360.900003
# V                               proposed                        NaN                             NaN                                   878.000000
# OP                              existing                        NaN                             NaN                                  5653.400045
# U                               proposed                        NaN                             NaN                                   876.499999
# P                               proposed                        NaN                             NaN                                   960.099998
# RE                              retired                         NaN                             NaN                                   399.699997
# T                               proposed                        NaN                             NaN                                   334.299988
# TS                              proposed                        NaN                             NaN                                  1546.300006
# V                               proposed                        V                               proposed                              925.000000
# U                               proposed                        V                               proposed                              200.000000
#                                                                 TS                              proposed                                2.300000
# P                               proposed                        U                               proposed                              200.000000
#                                                                 P                               proposed                              410.000000
# OP                              existing                        OP                              existing                              187.500000
# TS                              proposed                        TS                              proposed                              967.000000
#                                                                 OP                              existing                              657.500000
# NaN                             NaN                             U                               proposed                                0.000000
#                                                                 L                               proposed                                0.000000
#                                                                 OP                              existing                                0.000000
#                                                                 P                               proposed                                0.000000
#                                                                 RE                              retired                                 0.000000
#                                                                 T                               proposed                                0.000000
#                                                                 TS                              proposed                                0.000000
#                                                                 V                               proposed                                0.000000
#
#                                                                                                                                  capacity_mw_new  \
# raw_operational_status_code_old operational_status_category_old raw_operational_status_code_new operational_status_category_new
# L                               proposed                        NaN                             NaN                                     0.000000
# V                               proposed                        NaN                             NaN                                     0.000000
# OP                              existing                        NaN                             NaN                                     0.000000
# U                               proposed                        NaN                             NaN                                     0.000000
# P                               proposed                        NaN                             NaN                                     0.000000
# RE                              retired                         NaN                             NaN                                     0.000000
# T                               proposed                        NaN                             NaN                                     0.000000
# TS                              proposed                        NaN                             NaN                                     0.000000
# V                               proposed                        V                               proposed                              925.000000
# U                               proposed                        V                               proposed                              200.000000
#                                                                 TS                              proposed                                2.300000
# P                               proposed                        U                               proposed                              200.000000
#                                                                 P                               proposed                              410.000000
# OP                              existing                        OP                              existing                              187.500000
# TS                              proposed                        TS                              proposed                              967.000000
#                                                                 OP                              existing                              658.800003
# NaN                             NaN                             U                               proposed                             1971.599998
#                                                                 L                               proposed                              635.299995
#                                                                 OP                              existing                             3228.599998
#                                                                 P                               proposed                             7802.000000
#                                                                 RE                              retired                                19.400000
#                                                                 T                               proposed                              715.899994
#                                                                 TS                              proposed                             3128.499999
#                                                                 V                               proposed                             2233.899994
#
#                                                                                                                                  capacity_pct_change
# raw_operational_status_code_old operational_status_category_old raw_operational_status_code_new operational_status_category_new
# L                               proposed                        NaN                             NaN                                        -1.000000
# V                               proposed                        NaN                             NaN                                        -1.000000
# OP                              existing                        NaN                             NaN                                        -1.000000
# U                               proposed                        NaN                             NaN                                        -1.000000
# P                               proposed                        NaN                             NaN                                        -1.000000
# RE                              retired                         NaN                             NaN                                        -1.000000
# T                               proposed                        NaN                             NaN                                        -1.000000
# TS                              proposed                        NaN                             NaN                                        -1.000000
# V                               proposed                        V                               proposed                                    0.000000
# U                               proposed                        V                               proposed                                    0.000000
#                                                                 TS                              proposed                                    0.000000
# P                               proposed                        U                               proposed                                    0.000000
#                                                                 P                               proposed                                    0.000000
# OP                              existing                        OP                              existing                                    0.000000
# TS                              proposed                        TS                              proposed                                    0.000000
#                                                                 OP                              existing                                    0.001977
# NaN                             NaN                             U                               proposed                                         inf
#                                                                 L                               proposed                                         inf
#                                                                 OP                              existing                                         inf
#                                                                 P                               proposed                                         inf
#                                                                 RE                              retired                                          inf
#                                                                 T                               proposed                                         inf
#                                                                 TS                              proposed                                         inf
#                                                                 V                               proposed                                         inf

# %%
old_by_status_category = (
    eia_combined.query("iso_region_clean == 'ERCOT'")
    .groupby(
        [
         "operational_status_category_old", 
        ],
        dropna=False
    )
    .agg({"plant_id_eia": "nunique", "capacity_mw_old": sum})
    .rename(columns={"plant_id_eia": "plant_count"})
)
old_by_status_category
# Out:
#                                  plant_count  capacity_mw_old
# operational_status_category_old
# existing                                  15      5840.900045
# proposed                                  49      8317.899995
# retired                                    2       399.699997
# NaN                                       91         0.000000

# %% [markdown]
# ## Focus on ERCOT plants that disappeared

# %%
eia_ercot = eia_combined.query("iso_region_clean == 'ERCOT'")

# %% [markdown]
# #### % plants ERCOT disappearing

# %%
ercot_total_by_status_cat = (
    eia_ercot
    .groupby("operational_status_category_old")
    .agg({"capacity_mw_old": sum, "capacity_mw_new": sum})
)

ercot_disappeared_by_status_cat = (
    eia_ercot.query("operational_status_category_new.isnull()")
    .groupby("operational_status_category_old")
    .agg({"capacity_mw_old": sum, "capacity_mw_new": sum})
)

(ercot_disappeared_by_status_cat - ercot_total_by_status_cat) / ercot_total_by_status_cat
# Out:
#                                  capacity_mw_old  capacity_mw_new
# operational_status_category_old
# existing                               -0.032101             -1.0
# proposed                               -0.404165             -1.0
# retired                                 0.000000              NaN

# %%
(
    eia_combined.query("iso_region_clean == 'ERCOT' and operational_status_code_new.isnull()")
    .groupby(
        ["operational_status_code_old", "raw_operational_status_code_old", "operational_status_category_old"],
        dropna=False
    )
    .agg({"plant_id_eia": "nunique", "capacity_mw_old": sum})
).rename(columns={"plant_id_eia": "plant_count"})
# Out:
#                                                                                              plant_count  \
# operational_status_code_old raw_operational_status_code_old operational_status_category_old
# 1.0                         P                               proposed                                   5
# 2.0                         L                               proposed                                   6
# 3.0                         T                               proposed                                   1
# 4.0                         U                               proposed                                   7
# 5.0                         V                               proposed                                   5
# 6.0                         TS                              proposed                                   9
# 7.0                         OP                              existing                                  14
# 8.0                         RE                              retired                                    2
#
#                                                                                              capacity_mw_old
# operational_status_code_old raw_operational_status_code_old operational_status_category_old
# 1.0                         P                               proposed                              960.099998
# 2.0                         L                               proposed                              360.900003
# 3.0                         T                               proposed                              334.299988
# 4.0                         U                               proposed                              876.499999
# 5.0                         V                               proposed                              878.000000
# 6.0                         TS                              proposed                             1546.300006
# 7.0                         OP                              existing                             5653.400045
# 8.0                         RE                              retired                               399.699997

# %%
eia_combined.query(
    "iso_region_clean == 'ERCOT' " \
    "and operational_status_code_old.isnull() " \
    "and raw_operational_status_code_new == 'OP' " \
)
# Out:
#      report_date_old  plant_id_eia                    plant_name_eia  \
# 776              NaT          7512              Arthur Von Rosenberg
# 804              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 805              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 806              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 807              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 808              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 809              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 810              NaT         50815  Odyssey Energy Altura Cogen, LLC
# 861              NaT         55091        Midlothian Energy Facility
# 920              NaT         56754                      Goat Wind LP
# 921              NaT         56754                      Goat Wind LP
# 1071             NaT         62587                     Mesquite Star
# 1074             NaT         62809                     BMP Wind (TX)
# 1142             NaT         65373             Brotman Power Station
# 1143             NaT         65373             Brotman Power Station
# 1148             NaT         65489                           Dickens
# 1149             NaT         65490                             Hydra
# 1150             NaT         65491                             Paleo
# 1151             NaT         65492                              Pavo
# 1152             NaT         65493                          Tortolas
# 1432             NaT         67738     Citadel Battery Storage Plant
# 1446             NaT         67849                   BT Signal Ranch
#
#       utility_id_eia            utility_name_eia generator_id  \
# 776            16604  City of San Antonio - (TX)            2
# 804            55879  Odyssey Operating Services         GEN1
# 805            55879  Odyssey Operating Services         GEN2
# 806            55879  Odyssey Operating Services         GEN3
# 807            55879  Odyssey Operating Services         GEN4
# 808            55879  Odyssey Operating Services         GEN5
# 809            55879  Odyssey Operating Services         GEN6
# 810            55879  Odyssey Operating Services         GEN7
# 861            12501       Midlothian Energy LLC         STK1
# 920            64644               Goat Wind LLC            1
# 921            64644               Goat Wind LLC            2
# 1071           62085   Mesquite Star Special LLC         MESQ
# 1074           62659                BMP Wind LLC          BMP
# 1142           63082          ProEnergy Services        CTG-7
# 1143           63082          ProEnergy Services        CTG-8
# 1148           56201         Engie North America        DIKNS
# 1149           56201         Engie North America        HYDRA
# 1150           56201         Engie North America        PALEO
# 1151           56201         Engie North America         PAVO
# 1152           56201         Engie North America        TORTO
# 1432           66351            Citadel BESS LLC        CITDL
# 1446           66421        BT Signal Ranch, LLC          BTS
#
#       capacity_mw_old state_id_fips county_id_fips state  ...  \
# 776               NaN           NaN            NaN   NaN  ...
# 804               NaN           NaN            NaN   NaN  ...
# 805               NaN           NaN            NaN   NaN  ...
# 806               NaN           NaN            NaN   NaN  ...
# 807               NaN           NaN            NaN   NaN  ...
# 808               NaN           NaN            NaN   NaN  ...
# 809               NaN           NaN            NaN   NaN  ...
# 810               NaN           NaN            NaN   NaN  ...
# 861               NaN           NaN            NaN   NaN  ...
# 920               NaN           NaN            NaN   NaN  ...
# 921               NaN           NaN            NaN   NaN  ...
# 1071              NaN           NaN            NaN   NaN  ...
# 1074              NaN           NaN            NaN   NaN  ...
# 1142              NaN           NaN            NaN   NaN  ...
# 1143              NaN           NaN            NaN   NaN  ...
# 1148              NaN           NaN            NaN   NaN  ...
# 1149              NaN           NaN            NaN   NaN  ...
# 1150              NaN           NaN            NaN   NaN  ...
# 1151              NaN           NaN            NaN   NaN  ...
# 1152              NaN           NaN            NaN   NaN  ...
# 1432              NaN           NaN            NaN   NaN  ...
# 1446              NaN           NaN            NaN   NaN  ...
#
#      technology_description raw_state raw_county iso_region_clean  \
# 776                     NaN       NaN        NaN            ERCOT
# 804                     NaN       NaN        NaN            ERCOT
# 805                     NaN       NaN        NaN            ERCOT
# 806                     NaN       NaN        NaN            ERCOT
# 807                     NaN       NaN        NaN            ERCOT
# 808                     NaN       NaN        NaN            ERCOT
# 809                     NaN       NaN        NaN            ERCOT
# 810                     NaN       NaN        NaN            ERCOT
# 861                     NaN       NaN        NaN            ERCOT
# 920                     NaN       NaN        NaN            ERCOT
# 921                     NaN       NaN        NaN            ERCOT
# 1071                    NaN       NaN        NaN            ERCOT
# 1074                    NaN       NaN        NaN            ERCOT
# 1142                    NaN       NaN        NaN            ERCOT
# 1143                    NaN       NaN        NaN            ERCOT
# 1148                    NaN       NaN        NaN            ERCOT
# 1149                    NaN       NaN        NaN            ERCOT
# 1150                    NaN       NaN        NaN            ERCOT
# 1151                    NaN       NaN        NaN            ERCOT
# 1152                    NaN       NaN        NaN            ERCOT
# 1432                    NaN       NaN        NaN            ERCOT
# 1446                    NaN       NaN        NaN            ERCOT
#
#      report_date_new  capacity_mw_new  \
# 776       2024-12-01       187.500000
# 804       2024-12-01        84.900002
# 805       2024-12-01        84.900002
# 806       2024-12-01        84.900002
# 807       2024-12-01        84.900002
# 808       2024-12-01        84.900002
# 809       2024-12-01       129.199997
# 810       2024-12-01        89.900002
# 861       2024-12-01       289.000000
# 920       2024-12-01        80.000000
# 921       2024-12-01        69.599998
# 1071      2024-12-01       418.899994
# 1074      2024-12-01       340.000000
# 1142      2024-12-01        60.500000
# 1143      2024-12-01        60.500000
# 1148      2024-12-01       200.000000
# 1149      2024-12-01       200.000000
# 1150      2024-12-01       200.000000
# 1151      2024-12-01       175.000000
# 1152      2024-12-01        50.000000
# 1432      2024-12-01       204.000000
# 1446      2024-12-01        50.000000
#
#      current_planned_generator_operating_date_new operational_status_code_new  \
# 776                                           NaT                         7.0
# 804                                           NaT                         7.0
# 805                                           NaT                         7.0
# 806                                           NaT                         7.0
# 807                                           NaT                         7.0
# 808                                           NaT                         7.0
# 809                                           NaT                         7.0
# 810                                           NaT                         7.0
# 861                                           NaT                         7.0
# 920                                           NaT                         7.0
# 921                                           NaT                         7.0
# 1071                                          NaT                         7.0
# 1074                                          NaT                         7.0
# 1142                                          NaT                         7.0
# 1143                                          NaT                         7.0
# 1148                                          NaT                         7.0
# 1149                                          NaT                         7.0
# 1150                                          NaT                         7.0
# 1151                                          NaT                         7.0
# 1152                                          NaT                         7.0
# 1432                                          NaT                         7.0
# 1446                                          NaT                         7.0
#
#       operational_status_category_new  raw_operational_status_code_new
# 776                          existing                               OP
# 804                          existing                               OP
# 805                          existing                               OP
# 806                          existing                               OP
# 807                          existing                               OP
# 808                          existing                               OP
# 809                          existing                               OP
# 810                          existing                               OP
# 861                          existing                               OP
# 920                          existing                               OP
# 921                          existing                               OP
# 1071                         existing                               OP
# 1074                         existing                               OP
# 1142                         existing                               OP
# 1143                         existing                               OP
# 1148                         existing                               OP
# 1149                         existing                               OP
# 1150                         existing                               OP
# 1151                         existing                               OP
# 1152                         existing                               OP
# 1432                         existing                               OP
# 1446                         existing                               OP
#
# [22 rows x 38 columns]

# %%
eia_combined.query("iso_region_clean == 'ERCOT' and operational_status_code_new.isnull() and raw_operational_status_code_old == 'OP'")
# Out:
#     report_date_old  plant_id_eia                            plant_name_eia  \
# 16       2024-09-01          3439                                    Laredo
# 17       2024-09-01          3439                                    Laredo
# 20       2024-09-01          3441                                Nueces Bay
# 21       2024-09-01          3441                                Nueces Bay
# 22       2024-09-01          3441                                Nueces Bay
# 23       2024-09-01          4939                            Barney M Davis
# 24       2024-09-01          4939                            Barney M Davis
# 25       2024-09-01          4939                            Barney M Davis
# 26       2024-09-01          4939                            Barney M Davis
# 95       2024-09-01         55137                 Rio Nogales Power Project
# 116      2024-09-01         58001                      Temple Power Station
# 117      2024-09-01         58001                      Temple Power Station
# 118      2024-09-01         58001                      Temple Power Station
# 119      2024-09-01         58001                      Temple Power Station
# 120      2024-09-01         58001                      Temple Power Station
# 121      2024-09-01         58001                      Temple Power Station
# 125      2024-09-01         58471                Ector County Energy Center
# 126      2024-09-01         58471                Ector County Energy Center
# 309      2024-09-01         66046  Brazoria County Solar Project (Danciger)
# 315      2024-09-01         66157                 Red Tailed Hawk Solar LLC
# 319      2024-09-01         66262                          Cutlass Solar II
# 360      2024-09-01         66571                        BKV Ponder Solar 1
# 391      2024-09-01         66690                     Brazos Bend BESS, LLC
# 400      2024-09-01         66792                           Falfurrias BESS
# 403      2024-09-01         66801      Fence Post Solar Hybrid Project, LLC
# 404      2024-09-01         66801      Fence Post Solar Hybrid Project, LLC
# 442      2024-09-01         67019                     Copperhead Solar, LLC
# 443      2024-09-01         67019                     Copperhead Solar, LLC
#
#      utility_id_eia                    utility_name_eia generator_id  \
# 16            16604          City of San Antonio - (TX)            4
# 17            16604          City of San Antonio - (TX)            5
# 20            16604          City of San Antonio - (TX)            7
# 21            16604          City of San Antonio - (TX)            8
# 22            16604          City of San Antonio - (TX)            9
# 23            16604          City of San Antonio - (TX)            1
# 24            16604          City of San Antonio - (TX)            2
# 25            16604          City of San Antonio - (TX)            3
# 26            16604          City of San Antonio - (TX)            4
# 95            16604          City of San Antonio - (TX)         CTG3
# 116           57377      Temple Generation Holdings LLC        CTG-1
# 117           57377      Temple Generation Holdings LLC        CTG-2
# 118           57377      Temple Generation Holdings LLC        CTG-3
# 119           57377      Temple Generation Holdings LLC        CTG-4
# 120           57377      Temple Generation Holdings LLC        STG-1
# 121           57377      Temple Generation Holdings LLC        STG-2
# 125           65431        Ector County Generation, LLC         CTG1
# 126           65431        Ector County Generation, LLC         CTG2
# 309           65221  Brazoria County Solar Project, LLC        BRZ01
# 315           57416      Acciona Energy USA Global, LLC         GEN1
# 319           65361                Cutlass II Solar LLC        SAREN
# 360           64743                       PPM Solar LLC        BKVP1
# 391           65696               Brazos Bend BESS, LLC         BEND
# 400           65076          HEN Infrastructure, L.L.C.        FALFU
# 403           65774       Fence Post Solar Project, LLC        FNCBE
# 404           65774       Fence Post Solar Project, LLC        FNCPT
# 442           62759            National Grid Renewables        CHSLR
# 443           62759            National Grid Renewables        CHSTG
#
#      capacity_mw_old state_id_fips county_id_fips  state  ...  \
# 16        131.800003            48          48479  Texas  ...
# 17        131.800003            48          48479  Texas  ...
# 20        351.000000            48          48355  Texas  ...
# 21        189.600006            48          48355  Texas  ...
# 22        189.600006            48          48355  Texas  ...
# 23        352.000000            48          48355  Texas  ...
# 24        351.000000            48          48355  Texas  ...
# 25        189.600006            48          48355  Texas  ...
# 26        189.600006            48          48355  Texas  ...
# 95        189.000000            48          48187  Texas  ...
# 116       232.000000            48          48027  Texas  ...
# 117       232.000000            48          48027  Texas  ...
# 118       232.000000            48          48027  Texas  ...
# 119       232.000000            48          48027  Texas  ...
# 120       339.200012            48          48027  Texas  ...
# 121       339.200012            48          48027  Texas  ...
# 125       179.399994            48          48135  Texas  ...
# 126       179.399994            48          48135  Texas  ...
# 309       200.000000            48          48039  Texas  ...
# 315       350.000000            48          48481  Texas  ...
# 319       202.800003            48          48157  Texas  ...
# 360         2.500000            48          48121  Texas  ...
# 391       100.000000            48          48157  Texas  ...
# 400         9.900000            48          48047  Texas  ...
# 403        72.000000            48          48349  Texas  ...
# 404       236.000000            48          48349  Texas  ...
# 442       150.000000            48          48309  Texas  ...
# 443       100.000000            48          48309  Texas  ...
#
#                    technology_description raw_state raw_county  \
# 16   Natural Gas Fired Combustion Turbine        TX       Webb
# 17   Natural Gas Fired Combustion Turbine        TX       Webb
# 20       Natural Gas Fired Combined Cycle        TX     Nueces
# 21       Natural Gas Fired Combined Cycle        TX     Nueces
# 22       Natural Gas Fired Combined Cycle        TX     Nueces
# 23              Natural Gas Steam Turbine        TX     Nueces
# 24       Natural Gas Fired Combined Cycle        TX     Nueces
# 25       Natural Gas Fired Combined Cycle        TX     Nueces
# 26       Natural Gas Fired Combined Cycle        TX     Nueces
# 95       Natural Gas Fired Combined Cycle        TX  Guadalupe
# 116      Natural Gas Fired Combined Cycle        TX       Bell
# 117      Natural Gas Fired Combined Cycle        TX       Bell
# 118      Natural Gas Fired Combined Cycle        TX       Bell
# 119      Natural Gas Fired Combined Cycle        TX       Bell
# 120      Natural Gas Fired Combined Cycle        TX       Bell
# 121      Natural Gas Fired Combined Cycle        TX       Bell
# 125  Natural Gas Fired Combustion Turbine        TX      Ector
# 126  Natural Gas Fired Combustion Turbine        TX      Ector
# 309                    Solar Photovoltaic        TX   Brazoria
# 315                    Solar Photovoltaic        TX    Wharton
# 319                    Solar Photovoltaic        TX  Fort Bend
# 360                    Solar Photovoltaic        TX     Denton
# 391                             Batteries        TX  Fort Bend
# 400                             Batteries        TX     Brooks
# 403                             Batteries        TX    Navarro
# 404                    Solar Photovoltaic        TX    Navarro
# 442                    Solar Photovoltaic        TX   McLennan
# 443                             Batteries        TX   McLennan
#
#     iso_region_clean report_date_new  capacity_mw_new  \
# 16             ERCOT             NaT              NaN
# 17             ERCOT             NaT              NaN
# 20             ERCOT             NaT              NaN
# 21             ERCOT             NaT              NaN
# 22             ERCOT             NaT              NaN
# 23             ERCOT             NaT              NaN
# 24             ERCOT             NaT              NaN
# 25             ERCOT             NaT              NaN
# 26             ERCOT             NaT              NaN
# 95             ERCOT             NaT              NaN
# 116            ERCOT             NaT              NaN
# 117            ERCOT             NaT              NaN
# 118            ERCOT             NaT              NaN
# 119            ERCOT             NaT              NaN
# 120            ERCOT             NaT              NaN
# 121            ERCOT             NaT              NaN
# 125            ERCOT             NaT              NaN
# 126            ERCOT             NaT              NaN
# 309            ERCOT             NaT              NaN
# 315            ERCOT             NaT              NaN
# 319            ERCOT             NaT              NaN
# 360            ERCOT             NaT              NaN
# 391            ERCOT             NaT              NaN
# 400            ERCOT             NaT              NaN
# 403            ERCOT             NaT              NaN
# 404            ERCOT             NaT              NaN
# 442            ERCOT             NaT              NaN
# 443            ERCOT             NaT              NaN
#
#     current_planned_generator_operating_date_new operational_status_code_new  \
# 16                                           NaT                         NaN
# 17                                           NaT                         NaN
# 20                                           NaT                         NaN
# 21                                           NaT                         NaN
# 22                                           NaT                         NaN
# 23                                           NaT                         NaN
# 24                                           NaT                         NaN
# 25                                           NaT                         NaN
# 26                                           NaT                         NaN
# 95                                           NaT                         NaN
# 116                                          NaT                         NaN
# 117                                          NaT                         NaN
# 118                                          NaT                         NaN
# 119                                          NaT                         NaN
# 120                                          NaT                         NaN
# 121                                          NaT                         NaN
# 125                                          NaT                         NaN
# 126                                          NaT                         NaN
# 309                                          NaT                         NaN
# 315                                          NaT                         NaN
# 319                                          NaT                         NaN
# 360                                          NaT                         NaN
# 391                                          NaT                         NaN
# 400                                          NaT                         NaN
# 403                                          NaT                         NaN
# 404                                          NaT                         NaN
# 442                                          NaT                         NaN
# 443                                          NaT                         NaN
#
#      operational_status_category_new  raw_operational_status_code_new
# 16                               NaN                              NaN
# 17                               NaN                              NaN
# 20                               NaN                              NaN
# 21                               NaN                              NaN
# 22                               NaN                              NaN
# 23                               NaN                              NaN
# 24                               NaN                              NaN
# 25                               NaN                              NaN
# 26                               NaN                              NaN
# 95                               NaN                              NaN
# 116                              NaN                              NaN
# 117                              NaN                              NaN
# 118                              NaN                              NaN
# 119                              NaN                              NaN
# 120                              NaN                              NaN
# 121                              NaN                              NaN
# 125                              NaN                              NaN
# 126                              NaN                              NaN
# 309                              NaN                              NaN
# 315                              NaN                              NaN
# 319                              NaN                              NaN
# 360                              NaN                              NaN
# 391                              NaN                              NaN
# 400                              NaN                              NaN
# 403                              NaN                              NaN
# 404                              NaN                              NaN
# 442                              NaN                              NaN
# 443                              NaN                              NaN
#
# [28 rows x 38 columns]

# %% [markdown]
# - Compare % change for existing plants to % change in retirement (if existing decreases, expect retirement to increase)
# - For all plants make sure status change is sensible (join on table and ID)
# - For data integrity, compute % of plants that behave unexpectedly (i.e. disappear from data)
#     * On merged table, combine before and after state and group by these "paths" to see how common different changes are
#     * Check individual generator capacity changing
#     * Generate chart for previous quarterly updates to get historic context

# %% [markdown]
# ## By State

# %%
capacity_by_state_new = county_concrete_mw_new.groupby("state").sum()[
['capacity_under_construction_mw', 'capacity_awaiting_permitting_mw', 'capacity_total_proposed_mw']]

capacity_by_state_old = county_concrete_mw_old.groupby("state").sum()[
['capacity_under_construction_mw', 'capacity_awaiting_permitting_mw', 'capacity_total_proposed_mw']]

capacity_by_state_pct_change = (capacity_by_state_new - capacity_by_state_old) / capacity_by_state_old
capacity_by_state_pct_change.sort_values(by="capacity_total_proposed_mw")
# Out:
#                 capacity_under_construction_mw  \
# state
# Missouri                             -0.967333
# Montana                              -1.000000
# Hawaii                               -1.000000
# Maryland                             -0.716358
# Connecticut                           0.004589
# Wyoming                              -0.345279
# South Carolina                       -0.210526
# Mississippi                           1.000000
# New Jersey                           -0.968182
# Idaho                                -1.000000
# Utah                                  2.818182
# Florida                              -0.414710
# Nevada                               -0.993536
# Kentucky                              0.062814
# Illinois                              2.511775
# Wisconsin                            -0.007750
# Maine                                 0.502481
# Texas                                -0.247286
# Rhode Island                         -1.000000
# South Dakota                         -1.000000
# Oregon                               -0.037073
# Indiana                              -0.131540
# Delaware                                   NaN
# North Carolina                        0.318182
# West Virginia                              NaN
# Louisiana                             0.000000
# D.C.                                  0.000000
# Vermont                               0.000000
# Kansas                                0.082037
# California                            0.215620
# Massachusetts                         0.106602
# New York                             -0.683601
# Ohio                                  0.018240
# Oklahoma                              0.505516
# Georgia                              -0.650000
# Arkansas                              0.291985
# Michigan                              1.843575
# Nebraska                                   inf
# Arizona                               0.589852
# Virginia                             -0.168278
# Alabama                                    inf
# Colorado                             -0.132184
# Minnesota                            36.246269
# New Mexico                            3.500000
# Pennsylvania                         -0.830681
# Tennessee                             5.013843
# Iowa                                       NaN
# North Dakota                               NaN
# Washington                                 NaN
#
#                 capacity_awaiting_permitting_mw  capacity_total_proposed_mw
# state
# Missouri                                    NaN                   -0.967333
# Montana                               -0.950943                   -0.956347
# Hawaii                                      inf                   -0.938000
# Maryland                               0.060606                   -0.678708
# Connecticut                           -1.000000                   -0.665416
# Wyoming                               -0.998250                   -0.611689
# South Carolina                        -1.000000                   -0.582405
# Mississippi                           -0.659013                   -0.581103
# New Jersey                             0.000000                   -0.560526
# Idaho                                       inf                   -0.539171
# Utah                                  -1.000000                   -0.447368
# Florida                               -0.501995                   -0.444545
# Nevada                                 0.102976                   -0.362147
# Kentucky                              -0.624275                   -0.346537
# Illinois                              -0.942732                   -0.340278
# Wisconsin                             -0.554672                   -0.321363
# Maine                                 -0.474889                   -0.320494
# Texas                                 -0.372294                   -0.302781
# Rhode Island                           0.000000                   -0.200000
# South Dakota                           0.000000                   -0.196787
# Oregon                                -0.199199                   -0.188692
# Indiana                               -0.162325                   -0.146026
# Delaware                              -0.060172                   -0.060172
# North Carolina                        -0.036256                   -0.014165
# West Virginia                          0.000000                    0.000000
# Louisiana                              0.000000                    0.000000
# D.C.                                        NaN                    0.000000
# Vermont                                0.000000                    0.000000
# Kansas                                      NaN                    0.082037
# California                             0.006728                    0.125513
# Massachusetts                          1.200000                    0.135406
# New York                               0.589992                    0.136524
# Ohio                                   0.391172                    0.142285
# Oklahoma                              -0.040289                    0.149660
# Georgia                                1.010000                    0.180000
# Arkansas                                    NaN                    0.291985
# Michigan                              -0.480445                    0.305498
# Nebraska                              -0.691358                    0.382562
# Arizona                                0.150000                    0.407726
# Virginia                               1.000559                    0.436170
# Alabama                                0.963855                    1.445783
# Colorado                               2.927971                    1.542726
# Minnesota                              0.859939                    1.857786
# New Mexico                             4.018097                    3.860878
# Pennsylvania                          38.443478                   11.711747
# Tennessee                                   inf                   19.456811
# Iowa                                        NaN                         NaN
# North Dakota                                NaN                         NaN
# Washington                                  NaN                         NaN
