# %% [markdown]
# # Update interconnection FYI data and validate against LBNL + GridStatus data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import dbcp
from dbcp.extract.helpers import cache_gcs_archive_file_locally

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Raw Data

# %%
old_fyi = dbcp.extract.fyi_queue.extract("gs://dgm-archive/interconnection.fyi/interconnection_fyi_dataset_2025-09-01.csv")
old_fyi = old_fyi["fyi_queue"]

# %%
new_fyi = dbcp.extract.fyi_queue.extract("gs://dgm-archive/interconnection.fyi/interconnection_fyi_dataset_2025-10-01.csv")
new_fyi = new_fyi["fyi_queue"]

# %% [markdown]
# ## Compare max dates of raw data
# Print out the latest date a project entered a queue for each ISO in the old and new data. We should expect the latest project date in the new data to be larger than the that of the old data. Notable exceptions:
# * PJM: PJM [is working through a backlog of projects](https://www.utilitydive.com/news/pjm-fast-track-reliability-projects-interconnection-queue-invenergy/729311/) and isn't accepting new projects until mid 2026.

# %%
for power_market in old_fyi.power_market.unique():
    print(power_market)
    old_df = old_fyi[old_fyi.power_market == power_market]
    new_df = new_fyi[new_fyi.power_market == power_market]
    
    old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
    new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
    
    print(f" - Old max date {old_df['queue_date'].max()}")
    print(f" - New max date {new_df['queue_date'].max()}")
    print()
# Out:
# AESO
#  - Old max date 2025-06-26 00:00:00
#  - New max date 2025-08-05 00:00:00
#
# West
#  - Old max date 2025-08-26 00:00:00
#  - New max date 2025-09-10 00:00:00
#
# Southeast
#  - Old max date 2025-07-30 00:00:00
#  - New max date 2025-08-22 00:00:00
#
# CAISO
#  - Old max date 2025-02-12 00:00:00
#  - New max date 2025-02-12 00:00:00
#
# ERCOT
#  - Old max date 2025-07-29 00:00:00
#  - New max date 2025-08-26 00:00:00
#
# ISO-NE
#  - Old max date 2025-01-14 00:00:00
#  - New max date 2025-01-14 00:00:00
#
# MISO
#  - Old max date 2025-08-19 00:00:00
#  - New max date 2025-09-18 00:00:00
#
# NYISO
#  - Old max date 2025-06-03 00:00:00
#  - New max date 2025-06-03 00:00:00
#
# PJM
#  - Old max date 2023-07-08 00:00:00
#  - New max date 2023-07-08 00:00:00
#
# SPP
#  - Old max date 2025-07-01 00:00:00
#  - New max date 2025-09-15 00:00:00
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
# /tmp/ipykernel_368/306742154.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])

# %% [markdown]
# ## Compare data mart tables
# Compare the old and new total active capacity in regions.
#
# ### How to grab the new data
# To get the new data, replace the URI in `dbcp.etl.etl_fyi_queue` with the updated GCS URI. Then run `make all`. There might be some data validation errors due to small changes in the expected number of projects. If the changes seem reasonable, just update the expected value in the assertion. If they don't seem reason, do some digging!
#
# Once the ETL successfully finishes the new data is available in the databse.
#
# <!-- - download the `dev` data to compare to
# - load the relevent tables
#
# data warehouse
# - check the old and new iso have a similar n and capacity
# - plot total capacity
#
#
# data mart:
# - total capacity, n_projects and max date have all the same: caiso, ercot, pjm
# - total capacity, n_projects and max date have all increased: miso, pjm, spp, nyiso, isone
# - withdrawn and in service capacity have increased: miso, pjm, spp, nyiso, isone
#
# - active capacity has changed for isos in GS_REGIONS
# - how much has the active capacity changed by? -->

# %%
fyi_projects_long = pd.read_parquet("/app/data/output/data_mart/fyi_projects_long_format.parquet")

# %%
# filter for active projects
fyi_projects_long = fyi_projects_long[fyi_projects_long.queue_status.isin(["active"])]

# %% [markdown]
# ### How to grab the old data
# The following code grabs the latest version number for data in the development datasets then downloads the parquet file.

# %%
from google.cloud import bigquery

def get_bigquery_table_version(dataset_id, table_name, project_id="dbcp-dev-350818"):
    """
    Get the data version of a BigQuery table.

    The dbcp.commands.publish script generates a version number for each data release
    and adds it as a label to the BQ tables.

    Args:
        dataset_id: the BQ dataset ID
        table_name: the name of the table
        project_id: the GCP project id

    Return:
        the current DBCP version number of the requested table
    """
    client = bigquery.Client()

    table_ref = f"{project_id}.{dataset_id}.{table_name}"
    table = client.get_table(table_ref)  # Fetch table metadata

    labels = table.labels  # Get the labels dictionary
    return labels["version"]

# %% [markdown]
# # TODO: update this once we figure out where the long format table will land

# %%
from dbcp.extract.helpers import cache_gcs_archive_file_locally

table_name = "fyi_projects_long_format"
version = get_bigquery_table_version("data_mart", table_name)
uri = f"gs://dgm-outputs/{version}/data_mart/{table_name}.parquet"
data_cache = "/app/data/gcp_outputs"

fyi_projects_long_format_path = cache_gcs_archive_file_locally(uri, data_cache)
old_fyi_projects_long = pd.read_parquet(iso_projects_long_format_path)

# %% [markdown]
# ### Compare to LBNL + GridStatus ISO queue data

# %%
iso_projects_long = pd.read_parquet("/app/data/output/data_mart/iso_projects_long_format.parquet")

# %%
iso_projects_long.queue_status.value_counts()
# Out:
# active    11064
# Name: queue_status, dtype: Int64

# %%
iso_projects_long.resource_clean.value_counts()
# Out:
# Solar                    5213
# Battery Storage          3787
# Onshore Wind             1010
# Natural Gas               444
# Unknown                   289
# Offshore Wind              68
# Other                      52
# Hydro                      47
# Oil                        35
# Geothermal                 34
# Coal                       21
# Nuclear                    21
# Other Storage              15
# Biofuel                    11
# Pumped Storage              8
# Biomass                     4
# Municipal Solid Waste       3
# Hydrogen                    1
# Steam                       1
# Name: resource_clean, dtype: Int64

# %%
fyi_projects_long.resource_clean.value_counts()
# Out:
# Solar              4758
# Battery Storage    2968
# Onshore Wind        944
# Natural Gas         576
# Other               511
# Hydro                47
# Nuclear              42
# Geothermal           39
# Offshore Wind        24
# Oil                  23
# Coal                 21
# Biofuel              20
# Pumped Storage       16
# Biomass              12
# Other Storage        11
# Waste Heat            4
# Name: resource_clean, dtype: int64

# %%
fyi_projects_renewable = fyi_projects_long[fyi_projects_long.resource_class == "renewable"]
iso_projects_renewable = iso_projects_long[iso_projects_long.resource_class == "renewable"]

# %%
def agg_iso_projects_long_format(df, iso_col, id_col):
    """Calculate some aggregate metrics for each ISO"""
    agg = df.groupby(iso_col).agg({id_col: "count", "capacity_mw": "sum", "date_entered_queue": "max"})
    agg = agg.rename(columns={id_col: "n_projects", "capacity_mw": "total_capacity_mw", "date_entered_queue": "max_date_entered_queue"})
    return agg

fyi_project_agg = agg_iso_projects_long_format(fyi_projects_long, "power_market", "project_id")
iso_project_agg = agg_iso_projects_long_format(iso_projects_long, "iso_region", "surrogate_id")

# %%
fyi_project_agg.max_date_entered_queue
# Out:
# power_market
# AESO        2025-08-05
# CAISO       2025-02-12
# ERCOT       2025-08-26
# ISONE       2024-12-12
# MISO        2025-09-18
# NYISO       2025-06-03
# PJM         2023-06-30
# SPP         2025-09-15
# Southeast   2025-08-22
# West        2025-09-10
# Name: max_date_entered_queue, dtype: datetime64[ns]

# %%
both_project_aggs = fyi_project_agg.merge(iso_project_agg, how="outer", left_index=True, right_index=True, validate="1:1", suffixes=("_fyi", "_iso"))
both_project_aggs
# Out:
#            n_projects_fyi  total_capacity_mw_fyi max_date_entered_queue_fyi  \
# AESO                  226           47322.074000                 2025-08-05
# CAISO                 658          196593.869732                 2025-02-12
# ERCOT                1850          383975.980000                 2025-08-26
# ISONE                 157           38651.556822                 2024-12-12
# MISO                 1770          331486.430000                 2025-09-18
# NYISO                 176           28569.120000                 2025-06-03
# PJM                  1796          191922.112800                 2023-06-30
# SPP                   705          152335.537000                 2025-09-15
# Southeast             794          121365.093000                 2025-08-22
# West                 1884          460295.360900                 2025-09-10
#
#            n_projects_iso  total_capacity_mw_iso max_date_entered_queue_iso
# AESO                  NaN                    NaN                        NaT
# CAISO               900.0          269052.636325        2023-04-17 00:00:00
# ERCOT              1813.0          381547.570000        2025-06-19 00:00:00
# ISONE               184.0           47019.087800        2024-12-12 00:00:00
# MISO               2261.0          389585.190000        2025-02-19 05:00:00
# NYISO               366.0           53351.280000        2025-06-03 00:00:00
# PJM                1658.0          134888.563800        2023-06-30 00:00:00
# SPP                 858.0          190902.661000        2025-06-30 00:00:00
# Southeast           930.0          128113.102000        2024-12-19 00:00:00
# West               2026.0          383993.530000        2024-12-30 00:00:00

# %%
# Calculate the differences between the old and new
for col in iso_project_agg.columns:
    if pd.api.types.is_datetime64_any_dtype(iso_project_agg[col]):
        continue
    else:
        both_project_aggs[f"{col}_pct_diff"] = (both_project_aggs[f"{col}_fyi"] - both_project_aggs[f"{col}_iso"]) / both_project_aggs[f"{col}_iso"]

# %% [markdown]
# Ideally a less than 20% percent change in capacity for each region

# %%
iso_project_agg

both_project_aggs.sort_values(by="total_capacity_mw_iso", ascending=False)[["n_projects_pct_diff", "total_capacity_mw_pct_diff"]] * 100
# Out:
#            n_projects_pct_diff  total_capacity_mw_pct_diff
# MISO                -21.716055                  -14.912980
# West                 -7.008885                   19.870603
# ERCOT                 2.040816                    0.636463
# CAISO               -26.888889                  -26.931075
# SPP                 -17.832168                  -20.202507
# PJM                   8.323281                   42.281975
# Southeast           -14.623656                   -5.267228
# NYISO               -51.912568                  -46.450919
# ISONE               -14.673913                  -17.796030
# AESO                       NaN                         NaN

# %%
# dig deeper into PJM and NYISO
def agg_resource_long_format(df, id_col):
    """Calculate some aggregate metrics for each ISO"""
    agg = df.groupby("resource_clean").agg({id_col: "count", "capacity_mw": "sum", "date_entered_queue": "max"})
    agg = agg.rename(columns={id_col: "n_projects", "capacity_mw": "total_capacity_mw", "date_entered_queue": "max_date_entered_queue"})
    return agg
    
pjm_fyi = fyi_projects_long[fyi_projects_long["power_market"] == "PJM"]
pjm_iso = iso_projects_long[iso_projects_long["iso_region"] == "PJM"]
fyi_pjm_project_agg = agg_resource_long_format(pjm_fyi, "project_id")
iso_pjm_project_agg = agg_resource_long_format(pjm_iso, "surrogate_id")

# %%
both_pjm_project_aggs = fyi_pjm_project_agg.merge(iso_pjm_project_agg, how="outer", left_index=True, right_index=True, validate="1:1", suffixes=("_fyi", "_iso"))
both_pjm_project_aggs
# Out:
#                  n_projects_fyi  total_capacity_mw_fyi  \
# resource_clean
# Battery Storage           327.0             35142.9900
# Biomass                     3.0                40.0700
# Coal                        2.0                50.0000
# Hydro                       2.0                65.0000
# Natural Gas                72.0             15004.1760
# Nuclear                     6.0              1551.9000
# Offshore Wind              19.0             19366.0300
# Oil                         NaN                    NaN
# Onshore Wind              110.0             11620.7028
# Other                     119.0             24962.9540
# Solar                    1136.0             84118.2900
# Unknown                     NaN                    NaN
#
#                 max_date_entered_queue_fyi  n_projects_iso  \
# resource_clean
# Battery Storage                 2023-06-29           330.0
# Biomass                         2022-12-23             3.0
# Coal                            2015-10-26             1.0
# Hydro                           2021-03-31             2.0
# Natural Gas                     2023-06-30            57.0
# Nuclear                         2016-04-29             5.0
# Offshore Wind                   2023-06-02             NaN
# Oil                                    NaT             1.0
# Onshore Wind                    2023-03-11           100.0
# Other                           2023-02-15             3.0
# Solar                           2023-06-30          1112.0
# Unknown                                NaT            44.0
#
#                  total_capacity_mw_iso max_date_entered_queue_iso
# resource_clean
# Battery Storage             32474.9200                 2023-06-29
# Biomass                        20.0700                 2022-12-23
# Coal                            0.0000                        NaT
# Hydro                          65.0000                 2021-03-31
# Natural Gas                 13858.3330                 2023-06-30
# Nuclear                      1502.8000                        NaT
# Offshore Wind                      NaN                        NaT
# Oil                             6.6000                 2022-06-10
# Onshore Wind                 7196.6828                 2023-03-11
# Other                          27.9540                 2021-10-04
# Solar                       73968.2040                 2023-06-30
# Unknown                      5768.0000                 2023-02-15

# %%
# Calculate the differences between the old and new
for col in iso_pjm_project_agg.columns:
    if pd.api.types.is_datetime64_any_dtype(iso_pjm_project_agg[col]):
        continue
    else:
        both_pjm_project_aggs[f"{col}_pct_diff"] = (both_pjm_project_aggs[f"{col}_fyi"] - both_pjm_project_aggs[f"{col}_iso"]) / both_pjm_project_aggs[f"{col}_iso"]

# %%
both_pjm_project_aggs.sort_values(by="total_capacity_mw_iso", ascending=False)[["n_projects_pct_diff", "total_capacity_mw_pct_diff"]] * 100
# Out:
#                  n_projects_pct_diff  total_capacity_mw_pct_diff
# resource_clean
# Solar                       2.158273                1.372223e+01
# Battery Storage            -0.909091                8.215786e+00
# Natural Gas                26.315789                8.268260e+00
# Onshore Wind               10.000000                6.147304e+01
# Unknown                          NaN                         NaN
# Nuclear                    20.000000                3.267234e+00
# Hydro                       0.000000                0.000000e+00
# Other                    3866.666667                8.920011e+04
# Biomass                     0.000000                9.965122e+01
# Oil                              NaN                         NaN
# Coal                      100.000000                         inf
# Offshore Wind                    NaN                         NaN

# %%
iso_ng_queue_ids = iso_projects_long[(iso_projects_long.iso_region == "PJM") & (iso_projects_long.resource_clean == "Natural Gas")].queue_id.unique()

# %%
fyi_projects_long[
    (fyi_projects_long.power_market == "PJM") 
    & (fyi_projects_long.resource_clean == "Natural Gas")
    & (~fyi_projects_long.queue_id.isin(iso_ng_queue_ids))]
# Out:
#             state      county   project_id queue_id date_proposed_online  \
# 21979  New Jersey      Bergen  pjm-ab2-092  AB2-092           2027-06-30
# 22505    Illinois      Grundy  pjm-ad1-039  AD1-039           2025-02-28
# 22798    Illinois        Will  pjm-ad2-194  AD2-194           2027-01-01
# 25957    Virginia    Caroline  pjm-ah1-682  AH1-682           2027-11-30
# 25958    Virginia    Caroline  pjm-ah1-683  AH1-683           2027-10-15
# 25959    Virginia    Fauquier  pjm-ah1-684  AH1-684           2028-04-15
# 25960    Virginia    Fauquier  pjm-ah1-685  AH1-685           2028-05-31
# 25965    Virginia    Caroline  pjm-ah1-691  AH1-691           2029-05-31
# 25966    Virginia    Fauquier  pjm-ah1-693  AH1-693           2029-04-15
# 25967    Virginia    Caroline  pjm-ah1-694  AH1-694           2028-10-15
# 25972        Ohio  Columbiana  pjm-ah1-699  AH1-699           2025-03-03
# 26842    Virginia    Caroline  pjm-ai2-283  AI2-283           2023-02-27
# 26843    Virginia    Caroline  pjm-ai2-284  AI2-284           2023-03-01
# 26844    Virginia    Caroline  pjm-ai2-285  AI2-285           2023-02-27
# 26845    Virginia    Caroline  pjm-ai2-286  AI2-286           2023-02-27
# 26846    Virginia    Fauquier  pjm-ai2-287  AI2-287           2023-02-27
# 26847    Virginia    Fauquier  pjm-ai2-288  AI2-288           2023-02-27
#
#       developer power_market interconnection_status  \
# 21979      None          PJM            IA Executed
# 22505      None          PJM            IA Executed
# 22798      None          PJM            IA Executed
# 25957      None          PJM    System Impact Study
# 25958      None          PJM    System Impact Study
# 25959      None          PJM    System Impact Study
# 25960      None          PJM    System Impact Study
# 25965      None          PJM    System Impact Study
# 25966      None          PJM    System Impact Study
# 25967      None          PJM    System Impact Study
# 25972      None          PJM    System Impact Study
# 26842      None          PJM      Feasibility Study
# 26843      None          PJM      Feasibility Study
# 26844      None          PJM      Feasibility Study
# 26845      None          PJM      Feasibility Study
# 26846      None          PJM      Feasibility Study
# 26847      None          PJM      Feasibility Study
#
#                     point_of_interconnection                project_name  \
# 21979                           Bergen 138kV   Bergen Generating Station
# 22505  Kendall-Tazewell & Dresden-Mole Creek  Three Rivers Energy Center
# 22798                          Elwood 345 kV          Jackson Generation
# 25957                    Ladysmith CT 230 kV                        None
# 25958                    Ladysmith CT 230 kV                        None
# 25959                    Remington CT 230 kV                        None
# 25960                    Remington CT 230 kV                        None
# 25965                    Ladysmith CT 230 kV                        None
# 25966                    Remington CT 230 kV                        None
# 25967                    Ladysmith CT 230 kV                        None
# 25972                      Wellsville 345 kV                        None
# 26842                    Ladysmith CT 230 kV                        None
# 26843                    Ladysmith CT 230 kV                        None
# 26844                    Ladysmith CT 230 kV                        None
# 26845                    Ladysmith CT 230 kV                        None
# 26846                    Remington CT 230 kV                        None
# 26847                    Remington CT 230 kV                        None
#
#       date_entered_queue queue_status iso_region   utility is_actionable  \
# 21979         2016-04-26       active        pjm      PSEG         False
# 22505         2017-07-29       active        pjm     ComEd         False
# 22798         2018-03-31       active        pjm     ComEd         False
# 25957                NaT       active        pjm  Dominion          True
# 25958                NaT       active        pjm  Dominion          True
# 25959                NaT       active        pjm  Dominion          True
# 25960                NaT       active        pjm  Dominion          True
# 25965                NaT       active        pjm  Dominion          True
# 25966                NaT       active        pjm  Dominion          True
# 25967                NaT       active        pjm  Dominion          True
# 25972                NaT       active        pjm      ATSI          True
# 26842         2023-03-02       active        pjm  Dominion         False
# 26843         2023-03-02       active        pjm  Dominion         False
# 26844         2023-03-02       active        pjm  Dominion         False
# 26845         2023-03-02       active        pjm  Dominion         False
# 26846         2023-03-02       active        pjm  Dominion         False
# 26847         2023-03-02       active        pjm  Dominion         False
#
#       is_nearly_certain actual_completion_date withdrawn_date  capacity_mw  \
# 21979              True                    NaT            NaT         51.1
# 22505              True                    NaT            NaT        102.7
# 22798              True                    NaT            NaT        120.0
# 25957             False                    NaT            NaT         21.0
# 25958             False                    NaT            NaT         25.0
# 25959             False                    NaT            NaT         23.0
# 25960             False                    NaT            NaT         26.0
# 25965             False                    NaT            NaT         26.0
# 25966             False                    NaT            NaT         20.0
# 25967             False                    NaT            NaT         18.0
# 25972             False                    NaT            NaT         69.0
# 26842             False                    NaT            NaT         12.3
# 26843             False                    NaT            NaT         10.2
# 26844             False                    NaT            NaT          9.9
# 26845             False                    NaT            NaT          9.4
# 26846             False                    NaT            NaT         18.3
# 26847             False                    NaT            NaT         16.9
#
#       resource_clean state_id_fips county_id_fips  frac_locations_in_county  \
# 21979    Natural Gas            34          34003                       1.0
# 22505    Natural Gas            17          17063                       1.0
# 22798    Natural Gas            17          17197                       1.0
# 25957    Natural Gas            51          51033                       1.0
# 25958    Natural Gas            51          51033                       1.0
# 25959    Natural Gas            51          51061                       1.0
# 25960    Natural Gas            51          51061                       1.0
# 25965    Natural Gas            51          51033                       1.0
# 25966    Natural Gas            51          51061                       1.0
# 25967    Natural Gas            51          51033                       1.0
# 25972    Natural Gas            39          39029                       1.0
# 26842    Natural Gas            51          51033                       1.0
# 26843    Natural Gas            51          51033                       1.0
# 26844    Natural Gas            51          51033                       1.0
# 26845    Natural Gas            51          51033                       1.0
# 26846    Natural Gas            51          51061                       1.0
# 26847    Natural Gas            51          51061                       1.0
#
#       source state_permitting_type  co2e_tonnes_per_year  \
# 21979    fyi                 Local         159956.384360
# 22505    fyi                 Local         321477.899682
# 22798    fyi                 Local          66106.189334
# 25957    fyi                Hybrid          65735.500422
# 25958    fyi                Hybrid          78256.548121
# 25959    fyi                Hybrid          71996.024272
# 25960    fyi                Hybrid          81386.810046
# 25965    fyi                Hybrid          81386.810046
# 25966    fyi                Hybrid          62605.238497
# 25967    fyi                Hybrid          56344.714647
# 25972    fyi                Hybrid         215988.072815
# 26842    fyi                Hybrid          38502.221676
# 26843    fyi                Hybrid          31928.671633
# 26844    fyi                Hybrid          30989.593056
# 26845    fyi                Hybrid          29424.462094
# 26846    fyi                Hybrid          57283.793225
# 26847    fyi                Hybrid          52901.426530
#
#        ordinance_earliest_year_mentioned ordinance_jurisdiction_name  \
# 21979                                NaN                        None
# 22505                                NaN                        None
# 22798                                NaN                        None
# 25957                                NaN                        None
# 25958                                NaN                        None
# 25959                                NaN                        None
# 25960                                NaN                        None
# 25965                                NaN                        None
# 25966                                NaN                        None
# 25967                                NaN                        None
# 25972                             2023.0           Columbiana County
# 26842                                NaN                        None
# 26843                                NaN                        None
# 26844                                NaN                        None
# 26845                                NaN                        None
# 26846                                NaN                        None
# 26847                                NaN                        None
#
#       ordinance_jurisdiction_type  \
# 21979                        None
# 22505                        None
# 22798                        None
# 25957                        None
# 25958                        None
# 25959                        None
# 25960                        None
# 25965                        None
# 25966                        None
# 25967                        None
# 25972                      county
# 26842                        None
# 26843                        None
# 26844                        None
# 26845                        None
# 26846                        None
# 26847                        None
#
#                                           ordinance_text  ordinance_via_reldi  \
# 21979                                               None                False
# 22505                                               None                False
# 22798                                               None                False
# 25957                                               None                False
# 25958                                               None                False
# 25959                                               None                False
# 25960                                               None                False
# 25965                                               None                False
# 25966                                               None                False
# 25967                                               None                False
# 25972  On March 2, 2023, the Columbiana County Board ...                 True
# 26842                                               None                False
# 26843                                               None                False
# 26844                                               None                False
# 26845                                               None                False
# 26846                                               None                False
# 26847                                               None                False
#
#       ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 21979                     None                    None
# 22505                    False                   False
# 22798                    False                   False
# 25957                    False                   False
# 25958                    False                   False
# 25959                     None                    None
# 25960                     None                    None
# 25965                    False                   False
# 25966                     None                    None
# 25967                    False                   False
# 25972                     None                    None
# 26842                    False                   False
# 26843                    False                   False
# 26844                    False                   False
# 26845                    False                   False
# 26846                     None                    None
# 26847                     None                    None
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 21979                           None                          None
# 22505                          False                         False
# 22798                          False                         False
# 25957                          False                          True
# 25958                          False                          True
# 25959                           None                         False
# 25960                           None                         False
# 25965                          False                          True
# 25966                           None                         False
# 25967                          False                          True
# 25972                           None                          True
# 26842                          False                          True
# 26843                          False                          True
# 26844                          False                          True
# 26845                          False                          True
# 26846                           None                         False
# 26847                           None                         False
#
#        ordinance_is_restrictive  is_hybrid resource_class  surrogate_id
# 21979                     False      False         fossil         21979
# 22505                     False      False         fossil         22505
# 22798                     False      False         fossil         22798
# 25957                      True      False         fossil         25957
# 25958                      True      False         fossil         25958
# 25959                     False      False         fossil         25959
# 25960                     False      False         fossil         25960
# 25965                      True      False         fossil         25965
# 25966                     False      False         fossil         25966
# 25967                      True      False         fossil         25967
# 25972                      True      False         fossil         25972
# 26842                      True      False         fossil         26842
# 26843                      True      False         fossil         26843
# 26844                      True      False         fossil         26844
# 26845                      True      False         fossil         26845
# 26846                     False      False         fossil         26846
# 26847                     False      False         fossil         26847

# %%
# TODO: look into these projects and see what their resource is labeled as in raw data
fyi_projects_long[
    (fyi_projects_long.power_market == "PJM") 
    & (fyi_projects_long.resource_clean == "Other")]
# Out:
#       state county          project_id        queue_id date_proposed_online  \
# 270    None   None         pjm-1119633         1119633                  NaT
# 609    None   None         pjm-1119653         1119653                  NaT
# 886    None   None         pjm-1121578         1121578                  NaT
# 956    None   None         pjm-1132597         1132597                  NaT
# 1081   None   None         pjm-1132611         1132611                  NaT
# ...     ...    ...                 ...             ...                  ...
# 29562  None   None  pjm-y3-069-4549810  Y3-069 4549810                  NaT
# 29626  None   None  pjm-z1-027-4566961  Z1-027 4566961                  NaT
# 29640  None   None  pjm-z1-046-4586438  Z1-046 4586438                  NaT
# 29662  None   None  pjm-z1-067-4593370  Z1-067 4593370                  NaT
# 29666  None   None  pjm-z1-071-4598677  Z1-071 4598677                  NaT
#
#       developer power_market interconnection_status point_of_interconnection  \
# 270        None          PJM                   None                 OVEC-PJM
# 609        None          PJM                   None                 OVEC-PJM
# 886        None          PJM                   None                  PJM-WEC
# 956        None          PJM                   None                 PJM-MECS
# 1081       None          PJM                   None                   PJM-FE
# ...         ...          ...                    ...                      ...
# 29562      None          PJM    System Impact Study                 NIPS-PJM
# 29626      None          PJM    System Impact Study                 NIPS-PJM
# 29640      None          PJM    System Impact Study                  TVA-PJM
# 29662      None          PJM    System Impact Study                  DUK-PJM
# 29666      None          PJM    System Impact Study                  TVA-PJM
#
#       project_name date_entered_queue queue_status iso_region utility  \
# 270           None         2009-03-10       active        pjm    None
# 609           None         2009-03-10       active        pjm    None
# 886           None         2009-03-12       active        pjm    None
# 956           None         2009-03-25       active        pjm    None
# 1081          None         2009-03-25       active        pjm    None
# ...            ...                ...          ...        ...     ...
# 29562         None         2013-04-02       active        pjm    None
# 29626         None         2013-06-07       active        pjm    None
# 29640         None         2013-08-27       active        pjm    None
# 29662         None         2013-10-01       active        pjm    None
# 29666         None         2013-10-25       active        pjm    None
#
#       is_actionable is_nearly_certain actual_completion_date withdrawn_date  \
# 270           False             False                    NaT            NaT
# 609           False             False                    NaT            NaT
# 886           False             False                    NaT            NaT
# 956           False             False                    NaT            NaT
# 1081          False             False                    NaT            NaT
# ...             ...               ...                    ...            ...
# 29562          True             False                    NaT            NaT
# 29626          True             False                    NaT            NaT
# 29640          True             False                    NaT            NaT
# 29662          True             False                    NaT            NaT
# 29666          True             False                    NaT            NaT
#
#        capacity_mw resource_clean state_id_fips county_id_fips  \
# 270          142.0          Other          None           None
# 609          118.0          Other          None           None
# 886           10.0          Other          None           None
# 956           25.0          Other          None           None
# 1081          38.0          Other          None           None
# ...            ...            ...           ...            ...
# 29562        233.0          Other          None           None
# 29626        124.0          Other          None           None
# 29640        240.0          Other          None           None
# 29662         50.0          Other          None           None
# 29666         82.0          Other          None           None
#
#        frac_locations_in_county source state_permitting_type  \
# 270                         1.0    fyi                  None
# 609                         1.0    fyi                  None
# 886                         1.0    fyi                  None
# 956                         1.0    fyi                  None
# 1081                        1.0    fyi                  None
# ...                         ...    ...                   ...
# 29562                       1.0    fyi                  None
# 29626                       1.0    fyi                  None
# 29640                       1.0    fyi                  None
# 29662                       1.0    fyi                  None
# 29666                       1.0    fyi                  None
#
#        co2e_tonnes_per_year  ordinance_earliest_year_mentioned  \
# 270                     NaN                                NaN
# 609                     NaN                                NaN
# 886                     NaN                                NaN
# 956                     NaN                                NaN
# 1081                    NaN                                NaN
# ...                     ...                                ...
# 29562                   NaN                                NaN
# 29626                   NaN                                NaN
# 29640                   NaN                                NaN
# 29662                   NaN                                NaN
# 29666                   NaN                                NaN
#
#       ordinance_jurisdiction_name ordinance_jurisdiction_type ordinance_text  \
# 270                          None                        None           None
# 609                          None                        None           None
# 886                          None                        None           None
# 956                          None                        None           None
# 1081                         None                        None           None
# ...                           ...                         ...            ...
# 29562                        None                        None           None
# 29626                        None                        None           None
# 29640                        None                        None           None
# 29662                        None                        None           None
# 29666                        None                        None           None
#
#        ordinance_via_reldi ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 270                  False                    False                    True
# 609                  False                    False                    True
# 886                  False                    False                    True
# 956                  False                    False                    True
# 1081                 False                    False                    True
# ...                    ...                      ...                     ...
# 29562                False                    False                    True
# 29626                False                    False                    True
# 29640                False                    False                    True
# 29662                False                    False                    True
# 29666                False                    False                    True
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 270                             True                          None
# 609                             True                          None
# 886                             True                          None
# 956                             True                          None
# 1081                            True                          None
# ...                              ...                           ...
# 29562                           True                          None
# 29626                           True                          None
# 29640                           True                          None
# 29662                           True                          None
# 29666                           True                          None
#
#        ordinance_is_restrictive  is_hybrid resource_class  surrogate_id
# 270                        True      False         fossil           270
# 609                        True      False         fossil           609
# 886                        True      False         fossil           886
# 956                        True      False         fossil           956
# 1081                       True      False         fossil          1081
# ...                         ...        ...            ...           ...
# 29562                      True      False         fossil         29562
# 29626                      True      False         fossil         29626
# 29640                      True      False         fossil         29640
# 29662                      True      False         fossil         29662
# 29666                      True      False         fossil         29666
#
# [119 rows x 39 columns]

# %%
nyiso_fyi = fyi_projects_long[fyi_projects_long["power_market"] == "NYISO"]
nyiso_iso = iso_projects_long[iso_projects_long["iso_region"] == "NYISO"]
fyi_nyiso_project_agg = agg_resource_long_format(nyiso_fyi, "project_id")
iso_nyiso_project_agg = agg_resource_long_format(nyiso_iso, "surrogate_id")

# %%
both_nyiso_project_aggs = fyi_nyiso_project_agg.merge(iso_nyiso_project_agg, how="outer", left_index=True, right_index=True, validate="1:1", suffixes=("_fyi", "_iso"))
both_nyiso_project_aggs
# Out:
#                  n_projects_fyi  total_capacity_mw_fyi  \
# resource_clean
# Battery Storage             9.0                 629.60
# Natural Gas                 NaN                    NaN
# Offshore Wind               5.0                4371.00
# Onshore Wind               24.0                3972.30
# Other                      34.0                9355.10
# Solar                     104.0               10241.12
# Unknown                     NaN                    NaN
#
#                 max_date_entered_queue_fyi  n_projects_iso  \
# resource_clean
# Battery Storage                 2020-11-18           162.0
# Natural Gas                            NaT             2.0
# Offshore Wind                   2024-08-01             NaN
# Onshore Wind                    2024-10-15            31.0
# Other                           2025-06-03             NaN
# Solar                           2024-10-15           103.0
# Unknown                                NaT            68.0
#
#                  total_capacity_mw_iso max_date_entered_queue_iso
# resource_clean
# Battery Storage               21332.56                 2024-10-15
# Natural Gas                       0.00                 2024-10-04
# Offshore Wind                      NaN                        NaT
# Onshore Wind                   5612.10                 2024-10-15
# Other                              NaN                        NaT
# Solar                         10046.12                 2024-10-15
# Unknown                       16360.50                 2025-06-03

# %%
# Calculate the differences between the old and new
for col in iso_nyiso_project_agg.columns:
    if pd.api.types.is_datetime64_any_dtype(iso_nyiso_project_agg[col]):
        continue
    else:
        both_nyiso_project_aggs[f"{col}_pct_diff"] = (both_nyiso_project_aggs[f"{col}_fyi"] - both_nyiso_project_aggs[f"{col}_iso"]) / both_nyiso_project_aggs[f"{col}_iso"]

# %%
both_nyiso_project_aggs.sort_values(by="total_capacity_mw_iso", ascending=False)[["n_projects_pct_diff", "total_capacity_mw_pct_diff"]] * 100
# Out:
#                  n_projects_pct_diff  total_capacity_mw_pct_diff
# resource_clean
# Battery Storage           -94.444444                  -97.048643
# Unknown                          NaN                         NaN
# Solar                       0.970874                    1.941048
# Onshore Wind              -22.580645                  -29.219009
# Natural Gas                      NaN                         NaN
# Offshore Wind                    NaN                         NaN
# Other                            NaN                         NaN

# %%
fyi_projects_long[(fyi_projects_long.power_market == "NYISO") & (fyi_projects_long.resource_clean == "Battery Storage")]
# Out:
#           state      county  project_id queue_id date_proposed_online  \
# 18331  New York       Kings  nyiso-0522     0522           2027-06-01
# 18456  New York  Montgomery  nyiso-0683     0683           2027-06-01
# 18515  New York      Ulster  nyiso-0744     0744           2028-04-01
# 18556  New York        Erie  nyiso-0787     0787           2027-01-01
# 18576  New York       Kings  nyiso-0815     0815           2028-03-01
# 18585  New York    Richmond  nyiso-0827     0827                  NaT
# 18657  New York      Queens  nyiso-0907     0907           2028-01-01
# 18680  New York      Queens  nyiso-0930     0930           2027-03-01
# 18850  New York     Suffolk  nyiso-1113     1113           2027-12-01
#
#                 developer power_market interconnection_status  \
# 18331                None        NYISO         Facility Study
# 18456  Key Capture Energy        NYISO    System Impact Study
# 18515                None        NYISO         Facility Study
# 18556                None        NYISO    System Impact Study
# 18576                None        NYISO    System Impact Study
# 18585                None        NYISO         Facility Study
# 18657                None        NYISO    System Impact Study
# 18680                None        NYISO         Facility Study
# 18850    Caithness Energy        NYISO         Facility Study
#
#           point_of_interconnection                    project_name  \
# 18331     Hudson Avenue East 138kV                      NYC Energy
# 18456              Coldenham 115kV                        KCE NY 2
# 18515   East Walden - Modena 115kV                   Magruder BESS
# 18556  Gardenville Subsation 115kV                  Levy Grid, LLC
# 18576                Gowanus 345kV       Bayonne Energy Center III
# 18585           Fresh Kills 13.8kV    Arthur Kill Energy Storage 1
# 18657              Hell Gate 138kV               Harlem River Yard
# 18680            North Queens 27kV  Luyster Creek Energy Storage 3
# 18850            Sills Road 138 kV                     CLIES 20 MW
#
#       date_entered_queue queue_status iso_region utility is_actionable  \
# 18331         2015-12-16       active      nyiso   ConEd          True
# 18456         2018-01-18       active      nyiso   CHG&E          True
# 18515         2018-07-18       active      nyiso   CHG&E          True
# 18556         2018-12-20       active      nyiso   NM-NG          True
# 18576         2019-04-05       active      nyiso   ConEd          True
# 18585         2019-04-22       active      nyiso   ConEd          True
# 18657         2019-09-04       active      nyiso    NYPA          True
# 18680         2019-10-25       active      nyiso   ConEd          True
# 18850         2020-11-18       active      nyiso    LIPA          True
#
#       is_nearly_certain actual_completion_date withdrawn_date  capacity_mw  \
# 18331             False                    NaT            NaT         79.9
# 18456             False                    NaT            NaT        200.0
# 18515             False                    NaT            NaT         20.0
# 18556             False                    NaT            NaT        150.0
# 18576             False                    NaT            NaT         49.8
# 18585             False                    NaT            NaT         15.0
# 18657             False                    NaT            NaT         79.9
# 18680             False                    NaT            NaT         15.0
# 18850             False                    NaT            NaT         20.0
#
#         resource_clean state_id_fips county_id_fips  frac_locations_in_county  \
# 18331  Battery Storage            36          36047                       1.0
# 18456  Battery Storage            36          36057                       1.0
# 18515  Battery Storage            36          36111                       1.0
# 18556  Battery Storage            36          36029                       1.0
# 18576  Battery Storage            36          36047                       1.0
# 18585  Battery Storage            36          36085                       1.0
# 18657  Battery Storage            36          36081                       1.0
# 18680  Battery Storage            36          36081                       1.0
# 18850  Battery Storage            36          36103                       1.0
#
#       source state_permitting_type  co2e_tonnes_per_year  \
# 18331    fyi                Hybrid                   NaN
# 18456    fyi                Hybrid                   NaN
# 18515    fyi                Hybrid                   NaN
# 18556    fyi                Hybrid                   NaN
# 18576    fyi                Hybrid                   NaN
# 18585    fyi                Hybrid                   NaN
# 18657    fyi                Hybrid                   NaN
# 18680    fyi                Hybrid                   NaN
# 18850    fyi                Hybrid                   NaN
#
#        ordinance_earliest_year_mentioned ordinance_jurisdiction_name  \
# 18331                                NaN                        None
# 18456                                NaN                        None
# 18515                                NaN                        None
# 18556                                NaN                        None
# 18576                                NaN                        None
# 18585                                NaN                        None
# 18657                                NaN                        None
# 18680                                NaN                        None
# 18850                             2021.0                   Riverhead
#
#       ordinance_jurisdiction_type  \
# 18331                        None
# 18456                        None
# 18515                        None
# 18556                        None
# 18576                        None
# 18585                        None
# 18657                        None
# 18680                        None
# 18850                        city
#
#                                           ordinance_text  ordinance_via_reldi  \
# 18331                                               None                False
# 18456                                               None                False
# 18515                                               None                False
# 18556                                               None                False
# 18576                                               None                False
# 18585                                               None                False
# 18657                                               None                False
# 18680                                               None                False
# 18850  In October 2021, the Town of Riverhead adopted...                 True
#
#       ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 18331                     None                    None
# 18456                    False                   False
# 18515                     None                    None
# 18556                    False                   False
# 18576                     None                    None
# 18585                     None                    None
# 18657                     None                    None
# 18680                     None                    None
# 18850                     True                   False
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 18331                           None                          None
# 18456                          False                          True
# 18515                           None                          None
# 18556                          False                          True
# 18576                           None                          None
# 18585                           None                          None
# 18657                           None                          None
# 18680                           None                          None
# 18850                           True                          None
#
#        ordinance_is_restrictive  is_hybrid resource_class  surrogate_id
# 18331                     False      False        storage         18331
# 18456                      True      False        storage         18456
# 18515                     False      False        storage         18515
# 18556                      True      False        storage         18556
# 18576                     False      False        storage         18576
# 18585                     False      False        storage         18585
# 18657                     False      False        storage         18657
# 18680                     False      False        storage         18680
# 18850                      True      False        storage         18850

# %%
iso_projects_long[(iso_projects_long.iso_region == "NYISO") & (iso_projects_long.resource_clean == "Battery Storage")]
# Out:
#          state      county county_id_fips queue_id   resource_clean  \
# 552   New York     Suffolk          36103  C24-104  Battery Storage
# 562   New York     Suffolk          36103  C24-274  Battery Storage
# 567   New York      Ulster          36111  C24-173  Battery Storage
# 573   New York     Suffolk          36103  C24-218  Battery Storage
# 574   New York     Suffolk          36103  C24-164  Battery Storage
# ...        ...         ...            ...      ...              ...
# 7008  New York   Jefferson          36045     1237  Battery Storage
# 7014  New York     Niagara          36063  C24-129  Battery Storage
# 7037  New York      Orange          36071  C24-215  Battery Storage
# 7050  New York       Lewis          36049  C24-263  Battery Storage
# 7051  New York  Montgomery          36057  C24-248  Battery Storage
#
#       project_id date_proposed_online developer entity  \
# 552        38920           2028-06-01      <NA>  NYISO
# 562        38989           2028-12-01      <NA>  NYISO
# 567        39017           2029-12-01      <NA>  NYISO
# 573        39044           2029-02-01      <NA>  NYISO
# 574        39046           2029-12-01      <NA>  NYISO
# ...          ...                  ...       ...    ...
# 7008       56895           2026-12-01      <NA>  NYISO
# 7014       56905           2028-12-01      <NA>  NYISO
# 7037       56950           2029-03-01      <NA>  NYISO
# 7050       56976           2028-07-01      <NA>  NYISO
# 7051       56979           2028-12-01      <NA>  NYISO
#
#                        interconnection_status  \
# 552                          SRIS/SIS Pending
# 562                          SRIS/SIS Pending
# 567                          SRIS/SIS Pending
# 573                          SRIS/SIS Pending
# 574                          SRIS/SIS Pending
# ...                                       ...
# 7008  Accepted Cost Allocation/IA in Progress
# 7014                         SRIS/SIS Pending
# 7037                         SRIS/SIS Pending
# 7050                         SRIS/SIS Pending
# 7051                         SRIS/SIS Pending
#
#                                point_of_interconnection  \
# 552                        West Yaphank 69kV Substation
# 562                                    Southampton 69kV
# 567                                    Saugerties 69 kV
# 573                            Riverhead - Tuthill 69kV
# 574                            Riverhead - Tuthill 69kV
# ...                                                 ...
# 7008  North Carthage-Taylorville #8 and Black River-...
# 7014                 Dupont to Packard 115 kV Line #184
# 7037   Cuddebackville-Shoemaker stations 69 kV Line #13
# 7050                      Austin Rd. - Edic #11, 345 kV
# 7051  St. Johnsville - Marshville, Line id #11 (CLCP...
#
#                                            project_name date_entered_queue  \
# 552                           Horseblock Energy Storage         2024-08-27
# 562   Southampton Power Station Battery Energy Stora...         2024-09-24
# 567                                           KCE NY 34         2024-09-17
# 573                           Poplar Energy Center, LLC         2024-09-20
# 574                                           KCE NY 28         2024-09-16
# ...                                                 ...                ...
# 7008                         Sugar Maple Energy Storage         2021-08-24
# 7014                        Buffalo Road Energy Storage         2024-09-05
# 7037                                 Mount Hope Storage         2024-09-20
# 7050                           Jefferson Energy Storage         2024-09-23
# 7051                                Dove Energy Storage         2024-09-23
#
#      queue_status iso_region utility  capacity_mw state_id_fips  \
# 552        active      NYISO    LIPA       100.00            36
# 562        active      NYISO    LIPA        31.96            36
# 567        active      NYISO    CHGE       100.00            36
# 573        active      NYISO    LIPA        60.00            36
# 574        active      NYISO    LIPA        45.00            36
# ...           ...        ...     ...          ...           ...
# 7008       active      NYISO   NM-NG        20.00            36
# 7014       active      NYISO   NM-NG       100.00            36
# 7037       active      NYISO     O&R        50.00            36
# 7050       active      NYISO   NM-NG       100.00            36
# 7051       active      NYISO   NM-NG        79.90            36
#
#      state_permitting_type  co2e_tonnes_per_year  \
# 552                 Hybrid                   NaN
# 562                 Hybrid                   NaN
# 567                 Hybrid                   NaN
# 573                 Hybrid                   NaN
# 574                 Hybrid                   NaN
# ...                    ...                   ...
# 7008                Hybrid                   NaN
# 7014                Hybrid                   NaN
# 7037                Hybrid                   NaN
# 7050                Hybrid                   NaN
# 7051                Hybrid                   NaN
#
#       ordinance_earliest_year_mentioned ordinance_jurisdiction_name  \
# 552                              2021.0                   Riverhead
# 562                              2021.0                   Riverhead
# 567                                 NaN                        <NA>
# 573                              2021.0                   Riverhead
# 574                              2021.0                   Riverhead
# ...                                 ...                         ...
# 7008                             2019.0                       Worth
# 7014                             2018.0                    multiple
# 7037                                NaN                        <NA>
# 7050                                NaN                        <NA>
# 7051                                NaN                        <NA>
#
#      ordinance_jurisdiction_type  \
# 552                         city
# 562                         city
# 567                         <NA>
# 573                         city
# 574                         city
# ...                          ...
# 7008                        city
# 7014                    multiple
# 7037                        <NA>
# 7050                        <NA>
# 7051                        <NA>
#
#                                          ordinance_text  ordinance_via_reldi  \
# 552   In October 2021, the Town of Riverhead adopted...                 True
# 562   In October 2021, the Town of Riverhead adopted...                 True
# 567                                                <NA>                False
# 573   In October 2021, the Town of Riverhead adopted...                 True
# 574   In October 2021, the Town of Riverhead adopted...                 True
# ...                                                 ...                  ...
# 7008  In April 2019, the Worth town board adopted re...                 True
# 7014  Niagara County: In June 2021, Niagara County a...                 True
# 7037                                               <NA>                False
# 7050                                               <NA>                False
# 7051                                               <NA>                False
#
#       ordinance_via_solar_nrel  ordinance_via_wind_nrel  \
# 552                       True                    False
# 562                       True                    False
# 567                       <NA>                     <NA>
# 573                       True                    False
# 574                       True                    False
# ...                        ...                      ...
# 7008                      <NA>                     <NA>
# 7014                      <NA>                     <NA>
# 7037                     False                    False
# 7050                     False                    False
# 7051                     False                    False
#
#       ordinance_via_nrel_is_de_facto  ordinance_via_self_maintained  \
# 552                             True                           <NA>
# 562                             True                           <NA>
# 567                             <NA>                           <NA>
# 573                             True                           <NA>
# 574                             True                           <NA>
# ...                              ...                            ...
# 7008                            <NA>                           True
# 7014                            <NA>                           True
# 7037                           False                           <NA>
# 7050                           False                           <NA>
# 7051                           False                           True
#
#       ordinance_is_restrictive  is_hybrid  is_actionable  is_nearly_certain  \
# 552                       True      False          False              False
# 562                       True      False          False              False
# 567                      False      False          False              False
# 573                       True      False          False              False
# 574                       True      False          False              False
# ...                        ...        ...            ...                ...
# 7008                      True      False           True              False
# 7014                      True      False          False              False
# 7037                     False      False          False              False
# 7050                     False      False          False              False
# 7051                      True      False          False              False
#
#      resource_class  frac_locations_in_county      source  surrogate_id
# 552         storage                       1.0  gridstatus          2519
# 562         storage                       1.0  gridstatus          2588
# 567         storage                       1.0  gridstatus          2616
# 573         storage                       1.0  gridstatus          2643
# 574         storage                       1.0  gridstatus          2645
# ...             ...                       ...         ...           ...
# 7008        storage                       1.0  gridstatus         20327
# 7014        storage                       1.0  gridstatus         20337
# 7037        storage                       1.0  gridstatus         20382
# 7050        storage                       1.0  gridstatus         20408
# 7051        storage                       1.0  gridstatus         20411
#
# [162 rows x 37 columns]
