# %% [markdown]
# # Update interconnection FYI data and validate against LBNL + GridStatus data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import dbcp
from dbcp.extract.helpers import cache_gcs_archive_file_locally
from dbcp.helpers import get_sql_engine
# Out:
# /app/.local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Raw Data

# %%
old_fyi = dbcp.extract.fyi_queue.extract("gs://dgm-archive/interconnection.fyi/interconnection_fyi_dataset_2025-10-01.csv")
old_fyi = old_fyi["fyi_queue"]

# %%
new_fyi = dbcp.extract.fyi_queue.extract("gs://dgm-archive/interconnection.fyi/interconnection_fyi_dataset_2025-11-04.csv")
new_fyi = new_fyi["fyi_queue"]

# %% [markdown]
# ## Compare max dates of raw data
# Print out the latest date a project entered a queue for each ISO in the old and new data. We should expect the latest project date in the new data to be larger than the that of the old data. Notable exceptions:
# * PJM: PJM [is working through a backlog of projects](https://www.utilitydive.com/news/pjm-fast-track-reliability-projects-interconnection-queue-invenergy/729311/) and isn't accepting new projects until mid 2026.

# %%
for power_market in old_fyi.power_market.unique():
    print(power_market)
    old_df = old_fyi[old_fyi.power_market == power_market]
    new_df = new_fyi[new_fyi.power_market == power_market]
    
    old_df.loc[:, 'queue_date'] = pd.to_datetime(old_df.loc[:, 'queue_date'])
    new_df.loc[:, 'queue_date'] = pd.to_datetime(new_df.loc[:, 'queue_date'])
    
    print(f" - Old max date {old_df['queue_date'].max()}")
    print(f" - New max date {new_df['queue_date'].max()}")
    print()

# %% [markdown]
# ## Compare data warehouse tables to raw data

# %%
engine = get_sql_engine()
with engine.connect() as con:
    fyi_locations = pd.read_sql_table("fyi_locations", con, schema="private_data_warehouse")
    fyi_projects = pd.read_sql_table("fyi_projects", con, schema="private_data_warehouse")
    fyi_res_cap = pd.read_sql_table("fyi_resource_capacity", con, schema="private_data_warehouse")

# %% [markdown]
# # Offshore Wind

# %%
with engine.connect() as con:
    wind_cable = pd.read_sql_table("offshore_wind_cable_landing_association", con, schema="data_warehouse")
    wind_proj = pd.read_sql_table("offshore_wind_projects", con, schema="data_warehouse")

# %%
wind_cable
# Out:
#     location_id  project_id
# 0             8          32
# 1            84          32
# 2            51          20
# 3            52          20
# 4            41          11
# ..          ...         ...
# 56            3           3
# 57           62           3
# 58           45           7
# 59           43          47
# 60           49          28
#
# [61 rows x 2 columns]

# %% [markdown]
# We deduplicate the data so there are project IDs in the raw data that aren't in the data warehouse tables, but ensure that we're not losing an unexpectedly high number. During the creation of the data warehouse tables we log how many projects are dropped because they are found to be duplicates. Make sure that no table is missing many more than that number of IDs. The location table will have more missing IDs because there is more nullness in the location columns than in the capacity columns.

# %%
print(len(set(new_fyi.unique_id) - set(fyi_projects.project_id)))
print(len(set(new_fyi.unique_id) - set(fyi_locations.project_id)))
print(len(set(new_fyi.unique_id) - set(fyi_res_cap.project_id)))
# Out:
# 3358
# 4078
# 3358

# %% [markdown]
# ## Compare data mart tables
# Compare the old and new total active capacity in regions.
#
# ### How to grab the new data
# To get the new data, replace the URI in `dbcp.etl.etl_fyi_queue` with the updated GCS URI. Then run `make all`. There might be some data validation errors due to small changes in the expected number of projects. If the changes seem reasonable, just update the expected value in the assertion. If they don't seem reason, do some digging!
#
# Once the ETL successfully finishes the new data is available in the databse.
#
# <!-- - download the `dev` data to compare to
# - load the relevent tables
#
# data warehouse
# - check the old and new iso have a similar n and capacity
# - plot total capacity
#
#
# data mart:
# - total capacity, n_projects and max date have all the same: caiso, ercot, pjm
# - total capacity, n_projects and max date have all increased: miso, pjm, spp, nyiso, isone
# - withdrawn and in service capacity have increased: miso, pjm, spp, nyiso, isone
#
# - active capacity has changed for isos in GS_REGIONS
# - how much has the active capacity changed by? -->

# %%
engine = get_sql_engine()
with engine.connect() as con:
    fyi_projects_long_format = pd.read_sql_table("fyi_projects_long_format", con, schema="private_data_mart")

# %% [markdown]
# ### How to grab the old data
# The following code grabs the latest version number for data in the development datasets then downloads the parquet file.

# %%
from google.cloud import bigquery

def get_bigquery_table_version(dataset_id, table_name, project_id="dbcp-dev-350818"):
    """
    Get the data version of a BigQuery table.

    The dbcp.commands.publish script generates a version number for each data release
    and adds it as a label to the BQ tables.

    Args:
        dataset_id: the BQ dataset ID
        table_name: the name of the table
        project_id: the GCP project id

    Return:
        the current DBCP version number of the requested table
    """
    client = bigquery.Client()

    table_ref = f"{project_id}.{dataset_id}.{table_name}"
    table = client.get_table(table_ref)  # Fetch table metadata

    labels = table.labels  # Get the labels dictionary
    return labels["version"]

# %%
from dbcp.extract.helpers import cache_gcs_archive_file_locally

table_name = "fyi_projects_long_format"
version = get_bigquery_table_version("private_data_mart_dev", table_name)
uri = f"gs://dgm-outputs/{version}/data_mart/{table_name}.parquet"
data_cache = "/app/data/gcp_outputs"

fyi_projects_long_format_path = cache_gcs_archive_file_locally(uri, data_cache)
old_fyi_projects_long_format = pd.read_parquet(iso_projects_long_format_path)

# %% [markdown]
# ## Compare to LBNL + GridStatus ISO queue data

# %%
engine = get_sql_engine()
with engine.connect() as con:
    iso_projects_long_format = pd.read_sql_table("iso_projects_long_format", con, schema="data_mart")

# %%
iso_projects_long_format.queue_status.value_counts()
# Out:
# active    10350
# Name: queue_status, dtype: int64

# %%
iso_projects_long_format.resource_clean.value_counts()
# Out:
# Solar                    4753
# Battery Storage          3593
# Onshore Wind              936
# Natural Gas               469
# Unknown                   274
# Offshore Wind              68
# Other                      52
# Hydro                      46
# Geothermal                 34
# Oil                        30
# Nuclear                    28
# Coal                       22
# Other Storage              17
# Biofuel                    11
# Pumped Storage              8
# Municipal Solid Waste       4
# Biomass                     4
# Hydrogen                    1
# Name: resource_clean, dtype: int64

# %%
fyi_projects_long_format.resource_clean.value_counts()
# Out:
# Solar              4736
# Battery Storage    3024
# Onshore Wind        954
# Natural Gas         642
# Other               558
# Offshore Wind        68
# Hydro                47
# Nuclear              44
# Geothermal           42
# Coal                 23
# Biofuel              20
# Oil                  18
# Pumped Storage       15
# Biomass              12
# Other Storage        12
# Waste Heat            4
# Name: resource_clean, dtype: int64

# %% [markdown]
# Compare the county coverage of the datasets

# %%
len(fyi_projects_long_format.county_id_fips.unique()), len(iso_projects_long_format.county_id_fips.unique())
# Out:
# (1886, 1912)

# %%
from dbcp.constants import FYI_RESOURCE_DICT
clean_resources = [resource for resource, codes_dict in FYI_RESOURCE_DICT.items() if codes_dict["type"] == "Renewable"]

# %%
len(fyi_projects_long_format[fyi_projects_long_format.resource_clean.isin(clean_resources)].county_id_fips.unique())
# Out:
# 1812

# %%
len(iso_projects_long_format[iso_projects_long_format.resource_clean.isin(clean_resources)].county_id_fips.unique())
# Out:
# 1850

# %% [markdown]
# Compare metrics between datasets for each ISO.

# %%
def agg_iso_projects_long_format(df, iso_col, id_col):
    """Calculate some aggregate metrics for each ISO"""
    agg = df.groupby(iso_col).agg({id_col: "count", "capacity_mw": "sum", "date_entered_queue": "max"})
    agg = agg.rename(columns={id_col: "n_projects", "capacity_mw": "total_capacity_mw", "date_entered_queue": "max_date_entered_queue"})
    return agg

fyi_project_agg = agg_iso_projects_long_format(fyi_projects_long_format, "power_market", "project_id")
iso_project_agg = agg_iso_projects_long_format(iso_projects_long_format, "iso_region", "surrogate_id")

# %%
fyi_project_agg.max_date_entered_queue
# Out:
# power_market
# AESO        2025-08-07
# CAISO       2025-02-12
# ERCOT       2025-10-21
# ISONE       2024-12-12
# MISO        2025-10-27
# NYISO       2025-09-02
# PJM         2023-06-30
# SPP         2025-10-02
# Southeast   2025-09-30
# West        2025-10-23
# Name: max_date_entered_queue, dtype: datetime64[ns]

# %%
both_project_aggs = fyi_project_agg.merge(iso_project_agg, how="outer", left_index=True, right_index=True, validate="1:1", suffixes=("_fyi", "_iso"))
both_project_aggs
# Out:
#            n_projects_fyi  total_capacity_mw_fyi max_date_entered_queue_fyi  \
# AESO                  226           48848.974000                 2025-08-07
# CAISO                 654          196155.478732                 2025-02-12
# ERCOT                1807          384783.440000                 2025-10-21
# ISONE                  96           19253.402090                 2024-12-12
# MISO                 1776          352382.730000                 2025-10-27
# NYISO                 363           50489.580000                 2025-09-02
# PJM                  1715          165004.522800                 2023-06-30
# SPP                   729          161200.679000                 2025-10-02
# Southeast             857          126735.081000                 2025-09-30
# West                 1928          473389.462900                 2025-10-23
#
#            n_projects_iso  total_capacity_mw_iso max_date_entered_queue_iso
# AESO                  NaN                    NaN                        NaT
# CAISO               900.0          269052.636325        2023-04-17 00:00:00
# ERCOT              1793.0          386328.600000        2025-09-23 00:00:00
# ISONE                95.0           19560.330500        2024-12-12 00:00:00
# MISO               1813.0          337477.890000        2025-10-07 04:00:00
# NYISO               354.0           54695.380000        2025-09-02 00:00:00
# PJM                1608.0          131084.163800        2023-06-30 00:00:00
# SPP                 763.0          168384.879000        2025-10-02 00:00:00
# Southeast           930.0          128113.102000        2024-12-19 00:00:00
# West               2026.0          383993.530000        2024-12-30 00:00:00

# %%
# Calculate the differences between the old and new
for col in iso_project_agg.columns:
    if pd.api.types.is_datetime64_any_dtype(iso_project_agg[col]):
        continue
    else:
        both_project_aggs[f"{col}_pct_diff"] = (both_project_aggs[f"{col}_fyi"] - both_project_aggs[f"{col}_iso"]) / both_project_aggs[f"{col}_iso"]

# %% [markdown]
# Ideally a less than 20% percent change in capacity for each region. It's expected that there will be more capacity in FYI than in GS + LBNL because data from more utilities are included in the FYI data. It's not too worrying if the differences in this chart are positive, it's more worrying if they're negative.
#
# CAISO is updated by LBNL annually, not by quarterly GS updates, so this difference in update frequency can likely account for much of the difference in CAISO numbers.

# %%
iso_project_agg

both_project_aggs.sort_values(by="total_capacity_mw_iso", ascending=False)[["n_projects_pct_diff", "total_capacity_mw_pct_diff"]] * 100
# Out:
#            n_projects_pct_diff  total_capacity_mw_pct_diff
# ERCOT                 0.780814                   -0.399960
# West                 -4.837117                   23.280583
# MISO                 -2.040816                    4.416538
# CAISO               -27.333333                  -27.094013
# SPP                  -4.456094                   -4.266535
# PJM                   6.654229                   25.876779
# Southeast            -7.849462                   -1.075628
# NYISO                 2.542373                   -7.689498
# ISONE                 1.052632                   -1.569137
# AESO                       NaN                         NaN

# %% [markdown]
# ## Dig deeper into project level changes for regions with big differences in capacity

# %% [markdown]
# ### Start with ISOs where the FYI capacity is less than the GS capacity.
#
# * Were projects that are not active in FYI withdrawn recently? Vice versa?

# %%
from dbcp.data_mart.projects import create_long_format, create_fyi_long_format

# The dataframe this function returns includes all projects, active, withdrawn and operational. ERCOT only tracks active projects.
iso_all_projects_long_format = create_long_format(engine, active_projects_only=False)
fyi_all_projects_long_format = create_long_format(engine, active_projects_only=False)

# %%
iso_region = "SPP"

fyi_iso = fyi_all_projects_long_format.query("power_market == @iso_region")
gs_lbnl_iso = iso_all_projects_long_format.query("iso_region == @iso_region")

# %%
fyi_iso.queue_status.value_counts()
# Out:
# withdrawn      1610
# active          729
# operational     255
# suspended         7
# Name: queue_status, dtype: int64

# %%
gs_lbnl_iso.queue_status.value_counts()
# Out:
# withdrawn      1716
# active          763
# operational     277
# suspended         8
# Name: queue_status, dtype: int64

# %%
fyi_iso.queue_id.is_unique
# Out:
# True

# %%
fyi_iso[fyi_iso.queue_id.duplicated(keep=False)].head(5)
# Out:
# Empty DataFrame
# Columns: [state, county, project_id, queue_id, date_proposed_online, developer, power_market, interconnection_status, point_of_interconnection, project_name, date_entered_queue, queue_status, iso, utility, is_actionable, is_nearly_certain, actual_completion_date, withdrawn_date, capacity_mw, resource_clean, state_id_fips, county_id_fips, frac_locations_in_county, source, state_permitting_type, co2e_tonnes_per_year, ordinance_earliest_year_mentioned, ordinance_jurisdiction_name, ordinance_jurisdiction_type, ordinance_text, ordinance_via_reldi, ordinance_via_solar_nrel, ordinance_via_wind_nrel, ordinance_via_nrel_is_de_facto, ordinance_via_self_maintained, ordinance_is_restrictive, is_hybrid, resource_class]
# Index: []

# %%
len(gs_lbnl_iso[gs_lbnl_iso.queue_id.duplicated()])
# Out:
# 138

# %%
active_gs = gs_lbnl_iso[gs_lbnl_iso.queue_status == "active"]

# %%
not_active_fyi = fyi_iso[fyi_iso.queue_status != "active"]

# %%
# look at projects active in GS which are not active in FYI
not_active_fyi[not_active_fyi.queue_id.isin(active_gs.queue_id)].queue_status.value_counts()
# Out:
# Series([], Name: queue_status, dtype: int64)

# %%
# make sure projects were withdrawn recently
not_active_fyi[not_active_fyi.queue_id.isin(active_gs.queue_id)].withdrawn_date.value_counts()
# Out:
# Series([], Name: withdrawn_date, dtype: int64)

# %%
# does this missing capacity make up the difference in total capacity?
not_active_fyi[not_active_fyi.queue_id.isin(active_gs.queue_id)].capacity_mw.sum()/active_gs.capacity_mw.sum()
# Out:
# 0.0

# %%
# look at projects in GS which aren't in FYI
# it is likely that these projects were dropped during the deduplication cleaning
# step in the transform. You can spot check to make sure that a different project ID with the
# same interconnection point, capacity, resource etc. is in the data
active_gs[~active_gs.queue_id.isin(fyi_iso.queue_id)].sort_values(by="capacity_mw", ascending=False).head(5)
# Out:
#             state      county      queue_id is_nearly_certain  project_id  \
# 6454   New Mexico   Roosevelt  GEN-2024-304             False       42891
# 6644   New Mexico      Chaves  GEN-2024-199             False       43081
# 10130       Texas    Hansford  GEN-2024-046             False       46622
# 7808     Nebraska        Cass  GEN-2024-212             False       44273
# 9644        Texas  Hutchinson  GEN-2024-078             False       46113
#
#       project_name  capacity_mw developer entity iso_region utility  \
# 6454          None        500.0      None    SPP        SPP     SPS
# 6644          None        500.0      None    SPP        SPP     SPS
# 10130         None        345.0      None    SPP        SPP     SPS
# 7808          None        303.0      None    SPP        SPP    OPPD
# 9644          None        300.0      None    SPP        SPP     SPS
#
#       date_proposed_online              point_of_interconnection  \
# 6454   2029-12-31 00:00:00          Crossroads 345 kV Substation
# 6644   2028-12-04 00:00:00  Eddy County - Crossroads 345 kV Line
# 10130  2029-12-01 00:00:00           Hitchland-Moore 230 kV line
# 7808   2035-02-01 00:00:00                Substation 3740 345 kV
# 9644   2029-12-01 00:00:00             Pringle 230 kV Substation
#
#       is_actionable resource_clean queue_status date_entered_queue  \
# 6454           True          Solar       active         2025-03-01
# 6644           True   Onshore Wind       active         2025-03-01
# 10130          True          Solar       active         2024-10-30
# 7808           True    Natural Gas       active         2025-03-01
# 9644           True          Solar       active         2024-10-30
#
#       actual_completion_date withdrawn_date interconnection_status  \
# 6454                     NaT            NaT            DISIS STAGE
# 6644                     NaT            NaT            DISIS STAGE
# 10130                    NaT            NaT            DISIS STAGE
# 7808                     NaT            NaT            DISIS STAGE
# 9644                     NaT            NaT            DISIS STAGE
#
#       state_id_fips county_id_fips  frac_locations_in_county      source  \
# 6454             35          35041                       1.0  gridstatus
# 6644             35          35005                       1.0  gridstatus
# 10130            48          48195                       1.0  gridstatus
# 7808             31          31025                       1.0  gridstatus
# 9644             48          48233                       1.0  gridstatus
#
#       state_permitting_type  co2e_tonnes_per_year  \
# 6454                  Local                   NaN
# 6644                  Local                   NaN
# 10130                 Local                   NaN
# 7808                 Hybrid         166918.128068
# 9644                  Local                   NaN
#
#        ordinance_earliest_year_mentioned ordinance_jurisdiction_name  \
# 6454                                 NaN                         NaN
# 6644                                 NaN                         NaN
# 10130                                NaN                         NaN
# 7808                                 NaN                         NaN
# 9644                                 NaN                         NaN
#
#       ordinance_jurisdiction_type ordinance_text  ordinance_via_reldi  \
# 6454                          NaN            NaN                False
# 6644                          NaN            NaN                False
# 10130                         NaN            NaN                False
# 7808                          NaN            NaN                False
# 9644                          NaN            NaN                False
#
#       ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 6454                       NaN                     NaN
# 6644                       NaN                     NaN
# 10130                      NaN                     NaN
# 7808                     False                   False
# 9644                       NaN                     NaN
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 6454                             NaN                         False
# 6644                             NaN                         False
# 10130                            NaN                          None
# 7808                           False                          True
# 9644                             NaN                          None
#
#        ordinance_is_restrictive  is_hybrid resource_class  surrogate_id
# 6454                      False      False      renewable          6454
# 6644                      False      False      renewable          6644
# 10130                     False      False      renewable         10130
# 7808                       True      False         fossil          7808
# 9644                      False      False      renewable          9644

# %% [markdown]
# ### Now look at ISOs where there is more FYI capacity than in GS/LBNL

# %%
iso_region = "West"

fyi_iso = fyi_all_projects_long_format.query("power_market == @iso_region")
gs_lbnl_iso = iso_all_projects_long_format.query("iso_region == @iso_region")

# %%
active_fyi = fyi_iso[fyi_iso.queue_status == "active"]

# %%
non_active_gs = gs_lbnl_iso[gs_lbnl_iso.queue_status != "active"]

# %%
active_gs = gs_lbnl_iso[gs_lbnl_iso.queue_status == "active"]

# %%
# look at projects in FYI which are not active in GS
active_in_fyi_inactive_in_gs = active_fyi[active_fyi.queue_id.isin(non_active_gs.queue_id.unique())]

# %%
active_in_fyi_inactive_in_gs
# Out:
#               state    county                              project_id  \
# 482         Arizona  Maricopa             arizona-public-service-q288
# 1146        Wyoming   Laramie               black-hills-clpt-clpt-g11
# 1151        Wyoming    Platte               black-hills-clpt-clpt-g16
# 1153        Wyoming  Converse               black-hills-clpt-clpt-g18
# 1173       Colorado  Huerfano  black-hills-colorado-electric-bhct-g11
# ...             ...       ...                                     ...
# 37026       Arizona    Mohave    wapa-desert-southwest-region-2023-g6
# 37027       Arizona    La Paz    wapa-desert-southwest-region-2023-g8
# 37244  North Dakota     Burke                            wapa-gi-1103
# 37338          None      None      wapa-rocky-mountain-region-2017-g2
# 37379          None      None      wapa-rocky-mountain-region-2023-g3
#
#        queue_id date_proposed_online                   developer power_market  \
# 482        Q288           2021-12-31  RWE Solar Development, LLC         West
# 1146   CLPT G11           2023-12-31              NextEra Energy         West
# 1151   CLPT G16           2025-12-31              NextEra Energy         West
# 1153   CLPT G18           2024-12-15                        None         West
# 1173   BHCT-G11           2020-06-01          Black Hills Energy         West
# ...         ...                  ...                         ...          ...
# 37026   2023-G6           2027-01-15                        None         West
# 37027   2023-G8           2027-04-01                        None         West
# 37244   GI-1103                  NaT                        None         West
# 37338   2017-G2           2020-09-15                        None         West
# 37379   2023-G3           2026-12-01                        None         West
#
#             interconnection_status         point_of_interconnection  \
# 482    In Progress (unknown study)                      Panda 230kV
# 1146                   IA Executed                    Cheyenne West
# 1151                   IA Executed   Cheyenne - Windstar 230kV Line
# 1153                   IA Executed  Windstar - West Cheyenne 230 kV
# 1173                   IA Executed          Rattlesnake Butte 115kV
# ...                            ...                              ...
# 37026                         None      White Hills – Peacock 345kV
# 37027                         None           Bouse 230kV Substation
# 37244                  IA Executed                    Kenmare 115kV
# 37338  In Progress (unknown study)        Roundtop - Stegall 115-kV
# 37379  In Progress (unknown study)   Northpark - Terry Ranch 230-kV
#
#       project_name date_entered_queue queue_status   iso  \
# 482           None         2018-09-28       active  None
# 1146          None         2017-06-19       active  None
# 1151          None         2022-04-01       active  None
# 1153          None         2022-06-24       active  None
# 1173          None         2012-06-26       active  None
# ...            ...                ...          ...   ...
# 37026         None         2023-05-02       active  None
# 37027         None         2023-07-10       active  None
# 37244         None         2011-09-09       active  None
# 37338         None         2017-01-17       active  None
# 37379         None         2022-11-18       active  None
#
#                                                  utility is_actionable  \
# 482                               Arizona Public Service         False
# 1146   Black Hills Cheyenne Light Fuel and Power Tran...         False
# 1151   Black Hills Cheyenne Light Fuel and Power Tran...         False
# 1153   Black Hills Cheyenne Light Fuel and Power Tran...         False
# 1173                       Black Hills Colorado Electric         False
# ...                                                  ...           ...
# 37026                       WAPA Desert Southwest Region         False
# 37027                       WAPA Desert Southwest Region         False
# 37244                   WAPA/BEPC/HCPD Integrated System         False
# 37338                         WAPA Rocky Mountain Region         False
# 37379                         WAPA Rocky Mountain Region         False
#
#       is_nearly_certain actual_completion_date withdrawn_date  capacity_mw  \
# 482               False                    NaT            NaT        200.0
# 1146               True                    NaT            NaT        150.0
# 1151               True                    NaT            NaT        300.0
# 1153               True                    NaT            NaT        255.0
# 1173               True                    NaT            NaT         29.0
# ...                 ...                    ...            ...          ...
# 37026             False                    NaT            NaT        150.0
# 37027             False                    NaT            NaT        250.0
# 37244              True                    NaT            NaT          0.8
# 37338             False                    NaT            NaT        130.0
# 37379             False                    NaT            NaT        150.0
#
#       resource_clean state_id_fips county_id_fips  frac_locations_in_county  \
# 482            Solar            04          04013                       1.0
# 1146    Onshore Wind            56          56021                       1.0
# 1151    Onshore Wind            56          56031                       1.0
# 1153           Solar            56          56009                       1.0
# 1173    Onshore Wind            08          08055                       1.0
# ...              ...           ...            ...                       ...
# 37026          Solar            04          04015                       1.0
# 37027          Solar            04          04012                       1.0
# 37244    Natural Gas            38          38013                       1.0
# 37338   Onshore Wind          None           None                       1.0
# 37379          Solar          None           None                       1.0
#
#       source state_permitting_type  co2e_tonnes_per_year  \
# 482      fyi                Hybrid                   NaN
# 1146     fyi                Hybrid                   NaN
# 1151     fyi                Hybrid                   NaN
# 1153     fyi                Hybrid                   NaN
# 1173     fyi                Hybrid                   NaN
# ...      ...                   ...                   ...
# 37026    fyi                Hybrid                   NaN
# 37027    fyi                Hybrid                   NaN
# 37244    fyi                Hybrid            2504.20954
# 37338    fyi                  None                   NaN
# 37379    fyi                  None                   NaN
#
#        ordinance_earliest_year_mentioned ordinance_jurisdiction_name  \
# 482                                  NaN                        None
# 1146                                 NaN                        None
# 1151                                 NaN                        None
# 1153                                 NaN                        None
# 1173                                 NaN                        None
# ...                                  ...                         ...
# 37026                                NaN                        None
# 37027                                NaN                        None
# 37244                                NaN                        None
# 37338                                NaN                        None
# 37379                                NaN                        None
#
#       ordinance_jurisdiction_type ordinance_text  ordinance_via_reldi  \
# 482                          None           None                False
# 1146                         None           None                False
# 1151                         None           None                False
# 1153                         None           None                False
# 1173                         None           None                False
# ...                           ...            ...                  ...
# 37026                        None           None                False
# 37027                        None           None                False
# 37244                        None           None                False
# 37338                        None           None                False
# 37379                        None           None                False
#
#       ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 482                      False                   False
# 1146                     False                   False
# 1151                     False                   False
# 1153                     False                   False
# 1173                     False                   False
# ...                        ...                     ...
# 37026                     None                    None
# 37027                    False                   False
# 37244                     None                    None
# 37338                    False                    True
# 37379                    False                    True
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 482                            False                         False
# 1146                           False                         False
# 1151                           False                          None
# 1153                           False                          None
# 1173                           False                          None
# ...                              ...                           ...
# 37026                           None                          True
# 37027                          False                         False
# 37244                           None                          None
# 37338                           True                          None
# 37379                           True                          None
#
#        ordinance_is_restrictive  is_hybrid resource_class
# 482                       False      False      renewable
# 1146                      False      False      renewable
# 1151                      False      False      renewable
# 1153                      False      False      renewable
# 1173                      False      False      renewable
# ...                         ...        ...            ...
# 37026                      True      False      renewable
# 37027                     False      False      renewable
# 37244                     False      False         fossil
# 37338                      True      False      renewable
# 37379                      True      False      renewable
#
# [174 rows x 38 columns]

# %%
# check the status of these projects in GS/LBNL
non_active_gs[non_active_gs.queue_id.isin(active_in_fyi_inactive_in_gs.queue_id)].queue_status.value_counts()
# Out:
# withdrawn      115
# operational     54
# suspended       14
# Name: queue_status, dtype: int64

# %%
# look at projects that are active in FYI and not in GS
active_in_fyi_not_in_gs = active_fyi[
    ~(active_fyi.queue_id.isin(gs_lbnl_iso.queue_id)) &
    ~(active_fyi.capacity_mw.isnull())
]

# %%
active_in_fyi_not_in_gs.sort_values(by="capacity_mw", ascending=False)
# Out:
#             state      county                           project_id queue_id  \
# 31910     Arizona      Navajo  salt-river-project-cluster-24-q2409    Q2409
# 31925     Arizona       Pinal  salt-river-project-cluster-25-q2507    Q2507
# 2787       Oregon    Umatilla                            bpa-l0653    L0653
# 2695       Oregon  Washington                            bpa-l0561    L0561
# 2694       Oregon  Washington                            bpa-l0560    L0560
# ...           ...         ...                                  ...      ...
# 2635       Oregon      Marion                            bpa-l0501    L0501
# 2730       Oregon     Lincoln                            bpa-l0595    L0595
# 2696       Oregon      Morrow                            bpa-l0562    L0562
# 2629       Oregon        Lane                            bpa-l0495    L0495
# 2624   Washington    Thurston                            bpa-l0490    L0490
#
#       date_proposed_online developer power_market  \
# 31910           2028-12-31      None         West
# 31925           2027-12-31      None         West
# 2787            2028-06-03      None         West
# 2695            2032-12-31      None         West
# 2694            2028-12-31      None         West
# ...                    ...       ...          ...
# 2635            2023-08-23      None         West
# 2730            2027-03-19      None         West
# 2696            2026-05-22      None         West
# 2629            2023-07-10      None         West
# 2624            2025-09-02      None         West
#
#             interconnection_status  \
# 31910                         None
# 31925                         None
# 2787   In Progress (unknown study)
# 2695   In Progress (unknown study)
# 2694   In Progress (unknown study)
# ...                            ...
# 2635   In Progress (unknown study)
# 2730   In Progress (unknown study)
# 2696   In Progress (unknown study)
# 2629   In Progress (unknown study)
# 2624   In Progress (unknown study)
#
#                                 point_of_interconnection  \
# 31910                                   Sugarloaf 500 kV
# 31925                     Duke-Pinal Central 500 kV Line
# 2787              Longhorn Substation, McNary Substation
# 2695       Keeler-Forest Grove No. 1 & No. 2 115kV Lines
# 2694       Keeler-Forest Grove No. 1 & No. 2 115kV Lines
# ...                                                  ...
# 2635                                  Chemawa Substation
# 2730                                   Toledo Substation
# 2696       Keeler-Forest Grove No. 1 & No. 2 115kV Lines
# 2629   BPA-owned 2.92 miles section of Alvey-Martin C...
# 2624   BPA Cougar-Holden Creek No 1 115 kV line; BPA ...
#
#                                             project_name date_entered_queue  \
# 31910                                               None         2024-02-05
# 31925                                               None         2025-02-05
# 2787                         Longhorn-McNary 230 kV Loop         2025-06-02
# 2695   NW Hillsboro-North Plains Semiconductor Plants...         2023-05-12
# 2694        West Hillsboro Data Center Project (Phase 1)         2023-05-12
# ...                                                  ...                ...
# 2635                 Chemawa-Waconda 115 kV Line Project         2021-08-25
# 2730                          CLPUD-CPI Loop Tie Project         2024-03-20
# 2696            Keeler Horizon #1 & #2 Terminal Upgrades         2023-05-12
# 2629               Latham Substation Reliability Project         2021-07-12
# 2624    Upriver McKenzie Reliability Improvement Project         2021-05-30
#
#       queue_status   iso                                    utility  \
# 31910       active  None                         Salt River Project
# 31925       active  None                         Salt River Project
# 2787        active  None              Umatilla Electric Cooperative
# 2695        active  None          Portland General Electric Company
# 2694        active  None          Portland General Electric Company
# ...            ...   ...                                        ...
# 2635        active  None          Portland General Electric Company
# 2730        active  None  Central Lincoln People's Utility District
# 2696        active  None          Portland General Electric Company
# 2629        active  None          Emerald People's Utility District
# 2624        active  None              Eugene Water & Electric Board
#
#       is_actionable is_nearly_certain actual_completion_date withdrawn_date  \
# 31910         False             False                    NaT            NaT
# 31925         False             False                    NaT            NaT
# 2787          False             False                    NaT            NaT
# 2695          False             False                    NaT            NaT
# 2694          False             False                    NaT            NaT
# ...             ...               ...                    ...            ...
# 2635          False             False                    NaT            NaT
# 2730          False             False                    NaT            NaT
# 2696          False             False                    NaT            NaT
# 2629          False             False                    NaT            NaT
# 2624          False             False                    NaT            NaT
#
#        capacity_mw resource_clean state_id_fips county_id_fips  \
# 31910     2626.235          Solar            04          04017
# 31925     2538.000    Natural Gas            04          04021
# 2787      2225.000          Other            41          41059
# 2695      1800.000          Other            41          41067
# 2694      1400.000          Other            41          41067
# ...            ...            ...           ...            ...
# 2635         0.000          Other            41          41047
# 2730         0.000          Other            41          41041
# 2696         0.000          Other            41          41049
# 2629         0.000          Other            41          41039
# 2624         0.000          Other            53          53067
#
#        frac_locations_in_county source state_permitting_type  \
# 31910                       1.0    fyi                Hybrid
# 31925                       1.0    fyi                Hybrid
# 2787                        1.0    fyi                Hybrid
# 2695                        1.0    fyi                Hybrid
# 2694                        1.0    fyi                Hybrid
# ...                         ...    ...                   ...
# 2635                        1.0    fyi                Hybrid
# 2730                        1.0    fyi                Hybrid
# 2696                        1.0    fyi                Hybrid
# 2629                        1.0    fyi                Hybrid
# 2624                        1.0    fyi                Hybrid
#
#        co2e_tonnes_per_year  ordinance_earliest_year_mentioned  \
# 31910                   NaN                                NaN
# 31925          5.583324e+06                                NaN
# 2787                    NaN                                NaN
# 2695                    NaN                                NaN
# 2694                    NaN                                NaN
# ...                     ...                                ...
# 2635                    NaN                                NaN
# 2730                    NaN                                NaN
# 2696                    NaN                                NaN
# 2629                    NaN                                NaN
# 2624                    NaN                                NaN
#
#       ordinance_jurisdiction_name ordinance_jurisdiction_type  \
# 31910                        None                        None
# 31925                        None                        None
# 2787              Umatilla County                      county
# 2695                         None                        None
# 2694                         None                        None
# ...                           ...                         ...
# 2635                         None                        None
# 2730                         None                        None
# 2696                         None                        None
# 2629                         None                        None
# 2624                         None                        None
#
#                                           ordinance_text  ordinance_via_reldi  \
# 31910                                               None                False
# 31925                                               None                False
# 2787   Wind turbines must be set back 2 miles from th...                 True
# 2695                                                None                False
# 2694                                                None                False
# ...                                                  ...                  ...
# 2635                                                None                False
# 2730                                                None                False
# 2696                                                None                False
# 2629                                                None                False
# 2624                                                None                False
#
#       ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 31910                    False                   False
# 31925                     True                   False
# 2787                     False                    True
# 2695                     False                    True
# 2694                     False                    True
# ...                        ...                     ...
# 2635                      None                    None
# 2730                      None                    None
# 2696                      None                    None
# 2629                      None                    None
# 2624                      None                    None
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 31910                          False                         False
# 31925                          False                         False
# 2787                            True                          None
# 2695                            True                          True
# 2694                            True                          True
# ...                              ...                           ...
# 2635                            None                          True
# 2730                            None                          None
# 2696                            None                          None
# 2629                            None                          True
# 2624                            None                          None
#
#        ordinance_is_restrictive  is_hybrid resource_class
# 31910                     False      False      renewable
# 31925                     False      False         fossil
# 2787                       True      False         fossil
# 2695                       True      False         fossil
# 2694                       True      False         fossil
# ...                         ...        ...            ...
# 2635                       True      False         fossil
# 2730                      False      False         fossil
# 2696                      False      False         fossil
# 2629                       True      False         fossil
# 2624                      False      False         fossil
#
# [819 rows x 38 columns]

# %%
active_in_fyi_not_in_gs[active_in_fyi_not_in_gs.resource_clean != "Offshore Wind"].sort_values(by="capacity_mw", ascending=False).head(10)
# Out:
#                state     county          project_id        queue_id  \
# 26148  West Virginia  Doddridge         pjm-ag2-582         AG2-582
# 26922           Ohio      Lucas         pjm-ah1-690         AH1-690
# 26912           Ohio    Carroll         pjm-ah1-680         AH1-680
# 26908       Virginia     Orange         pjm-ah1-676         AH1-676
# 29067           None       None   pjm-u1-052-889837   U1-052 889837
# 27299       Kentucky       None         pjm-ah2-353         AH2-353
# 26926   Pennsylvania    Dauphin         pjm-ah1-695         AH1-695
# 26954       Kentucky       None         pjm-ah1-721         AH1-721
# 26944       Virginia   Fluvanna         pjm-ah1-712         AH1-712
# 30307           None       None  pjm-y1-004-3673272  Y1-004 3673272
#
#       date_proposed_online                              developer  \
# 26148           2026-07-01             Competitive Power Ventures
# 26922           2031-03-01             Competitive Power Ventures
# 26912           2030-05-01                         Advanced Power
# 26908           2031-05-31                                   None
# 29067                  NaT                                   None
# 27299           2028-12-31                                   None
# 26926           2027-10-01                          Constellation
# 26954           2030-12-31  East Kentucky Power Cooperative, Inc.
# 26944           2031-05-30                                Tenaska
# 30307                  NaT                                   None
#
#       power_market interconnection_status         point_of_interconnection  \
# 26148          PJM    System Impact Study                 Flint Run 500 kV
# 26922          PJM    System Impact Study    Bay Shore - Lallendorf 345 kV
# 26912          PJM    System Impact Study     Sammis - South Canton 345 kV
# 26908          PJM    System Impact Study              Gordonsville 230 kV
# 29067          PJM                   None                     Duquesne-PJM
# 27299          PJM      Feasibility Study  Jefferson - Hanging Rock 765 kV
# 26926          PJM    System Impact Study         Three Mile Island 230 kV
# 26954          PJM    System Impact Study             Laurel-Cooper 161 kV
# 26944          PJM    System Impact Study                Cunningham 500 kV
# 30307          PJM    System Impact Study                          TVA-PJM
#
#       project_name date_entered_queue queue_status  iso   utility  \
# 26148         None         2021-03-31       active  pjm       APS
# 26922         None                NaT       active  pjm      ATSI
# 26912         None                NaT       active  pjm      ATSI
# 26908         None                NaT       active  pjm  Dominion
# 29067         None         2008-03-26       active  pjm      None
# 27299         None         2022-03-10       active  pjm       AEP
# 26926         None                NaT       active  pjm        ME
# 26954         None                NaT       active  pjm      EKPC
# 26944         None                NaT       active  pjm  Dominion
# 30307         None         2012-02-07       active  pjm      None
#
#       is_actionable is_nearly_certain actual_completion_date withdrawn_date  \
# 26148          True             False                    NaT            NaT
# 26922          True             False                    NaT            NaT
# 26912          True             False                    NaT            NaT
# 26908          True             False                    NaT            NaT
# 29067         False             False                    NaT            NaT
# 27299         False             False                    NaT            NaT
# 26926          True             False                    NaT            NaT
# 26954          True             False                    NaT            NaT
# 26944          True             False                    NaT            NaT
# 30307          True             False                    NaT            NaT
#
#        capacity_mw resource_clean state_id_fips county_id_fips  \
# 26148       2100.0    Natural Gas            54          54017
# 26922       1475.0    Natural Gas            39          39095
# 26912       1300.0    Natural Gas            39          39019
# 26908       1294.6    Natural Gas            51          51137
# 29067       1188.0          Other          None           None
# 27299       1000.0          Solar            21           None
# 26926        859.0        Nuclear            42          42043
# 26954        786.0    Natural Gas            21           None
# 26944        776.0    Natural Gas            51          51065
# 30307        720.0          Other          None           None
#
#        frac_locations_in_county source state_permitting_type  \
# 26148                       1.0    fyi                 State
# 26922                       1.0    fyi                Hybrid
# 26912                       1.0    fyi                Hybrid
# 26908                       1.0    fyi                Hybrid
# 29067                       1.0    fyi                  None
# 27299                       1.0    fyi                Hybrid
# 26926                       1.0    fyi                 Local
# 26954                       1.0    fyi                Hybrid
# 26944                       1.0    fyi                Hybrid
# 30307                       1.0    fyi                  None
#
#        co2e_tonnes_per_year  ordinance_earliest_year_mentioned  \
# 26148          4.619772e+06                                NaN
# 26922          3.244840e+06                                NaN
# 26912          2.859859e+06                                NaN
# 26908          2.847979e+06                                NaN
# 29067                   NaN                                NaN
# 27299                   NaN                                NaN
# 26926                   NaN                                NaN
# 26954          1.729114e+06                                NaN
# 26944          1.707116e+06                                NaN
# 30307                   NaN                                NaN
#
#       ordinance_jurisdiction_name ordinance_jurisdiction_type ordinance_text  \
# 26148                        None                        None           None
# 26922                        None                        None           None
# 26912                        None                        None           None
# 26908                        None                        None           None
# 29067                        None                        None           None
# 27299                        None                        None           None
# 26926                        None                        None           None
# 26954                        None                        None           None
# 26944                        None                        None           None
# 30307                        None                        None           None
#
#        ordinance_via_reldi ordinance_via_solar_nrel ordinance_via_wind_nrel  \
# 26148                False                     None                    None
# 26922                False                     None                    None
# 26912                False                     None                    None
# 26908                False                     None                    None
# 29067                False                    False                    True
# 27299                False                    False                    True
# 26926                False                     None                    None
# 26954                False                    False                    True
# 26944                False                     None                    None
# 30307                False                    False                    True
#
#       ordinance_via_nrel_is_de_facto ordinance_via_self_maintained  \
# 26148                           None                          None
# 26922                           None                         False
# 26912                           None                         False
# 26908                           None                         False
# 29067                           True                          None
# 27299                           True                          None
# 26926                           None                         False
# 26954                           True                          None
# 26944                           None                          True
# 30307                           True                          None
#
#        ordinance_is_restrictive  is_hybrid resource_class
# 26148                     False      False         fossil
# 26922                     False      False         fossil
# 26912                     False      False         fossil
# 26908                     False      False         fossil
# 29067                      True      False         fossil
# 27299                      True      False      renewable
# 26926                     False      False          other
# 26954                      True      False         fossil
# 26944                      True      False         fossil
# 30307                      True      False         fossil

# %%
# it's worth checking the most recent raw data to see if these projects get dropped during deduplication
raw_gs = pd.read_parquet("/app/data/data_cache/gridstatus/interconnection_queues/parquet/pjm.parquet#1761671630863094")

# %%
# if they appear in the raw data, check if the location or resource / generation type
# would exclude the project from the data warehouse tables
raw_gs[raw_gs["Queue ID"] == "AH1-695"]
# Out:
# Empty DataFrame
# Columns: [Queue ID, Project Name, Interconnecting Entity, County, State, Interconnection Location, Transmission Owner, Generation Type, Capacity (MW), Summer Capacity (MW), Winter Capacity (MW), Queue Date, Status, Proposed Completion Date, Withdrawn Date, Withdrawal Comment, Actual Completion Date, MW In Service, Commercial Name, Initial Study, Feasibility Study, Feasibility Study Status, System Impact Study, System Impact Study Status, Facilities Study, Facilities Study Status, Interim/Interconnection Service/Generation Interconnection Agreement, Interim/Interconnection Service/Generation Interconnection Agreement Status, Wholesale Market Participation Agreement, Construction Service Agreement, Construction Service Agreement Status, Upgrade Construction Service Agreement, Upgrade Construction Service Agreement Status, Backfeed Date, Long-Term Firm Service Start Date, Long-Term Firm Service End Date, Test Energy Date]
# Index: []

# %%
# check the GS data warehouse tables
gs_proj = pd.read_parquet("/app/data/output/data_warehouse/gridstatus_projects.parquet")

# %%
active_in_fyi_not_in_gs.resource_clean.value_counts()
# Out:
# Other              3
# Solar              1
# Battery Storage    1
# Name: resource_clean, dtype: int64

# %%
# see if the capacity of these projects makes up the difference in GS
active_in_fyi_not_in_gs.capacity_mw.sum()/active_gs.capacity_mw.sum()
# Out:
# 0.06072956450154523

# %%
active_fyi.sort_values(by="capacity_mw", ascending=False).head(10)[["queue_id", "capacity_mw"]]
# Out:
#       queue_id  capacity_mw
# 20138  C24-152      4000.00
# 19243     0971      2383.60
# 19229     0956      2380.00
# 20066  C24-089      2064.15
# 20259  C24-266      1990.00
# 20117  C24-131      1800.00
# 20304  C24-309      1600.00
# 20224  C24-233      1600.00
# 20164  C24-178      1500.00
# 20213  C24-223      1400.00
