# %% [markdown]
# # Purpose
# This notebook contains an initial exploration and implementation of ballot ready data cleaning.

# %%
import dbcp
import pandas as pd

from pathlib import Path

from dbcp.transform.helpers import add_county_fips_with_backup_geocoding
# Out:
# /app/.local/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(
# /app/.local/lib/python3.10/site-packages/pudl/analysis/spatial.py:7: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
source_path = Path("ballot_ready/2023_04_05_climate_partners_upcoming_races_with_counties.csv")
raw_dfs = dbcp.extract.ballot_ready.extract(source_path)
transformed = dbcp.transform.ballot_ready.transform(raw_dfs)
# Out:
# 2023-08-11 00:44:00 [    INFO] catalystcoop.pudl.helpers:203 Assigned state FIPS codes for 100.00% of records.
# 2023-08-11 00:44:04 [    INFO] catalystcoop.pudl.helpers:219 Assigned county FIPS codes for 96.65% of records.

# %%
transformed["ballot_ready_counties"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221265 entries, 0 to 81681
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   county                    221265 non-null  string
#  1   election_id               221265 non-null  Int64
#  2   election_name             221265 non-null  string
#  3   election_day              221265 non-null  datetime64[ns]
#  4   race_id                   221265 non-null  Int64
#  5   is_primary                221265 non-null  boolean
#  6   is_runoff                 221265 non-null  boolean
#  7   is_unexpired              221265 non-null  boolean
#  8   position_id               221265 non-null  Int64
#  9   position_name             221265 non-null  string
#  10  sub_area_name             150748 non-null  string
#  11  sub_area_value            166573 non-null  string
#  12  sub_area_name_secondary   17438 non-null   string
#  13  sub_area_value_secondary  17896 non-null   string
#  14  state                     221265 non-null  string
#  15  level                     221265 non-null  string
#  16  tier                      221265 non-null  Int64
#  17  is_judicial               221265 non-null  boolean
#  18  is_retention              221265 non-null  boolean
#  19  number_of_seats           221265 non-null  Int64
#  20  normalized_position_id    221265 non-null  Int64
#  21  normalized_position_name  221265 non-null  string
#  22  position_description      221257 non-null  string
#  23  frequency                 221265 non-null  string
#  24  reference_year            221265 non-null  Int64
#  25  partisan_type             221240 non-null  string
#  26  race_created_at           221265 non-null  datetime64[ns]
#  27  race_updated_at           221265 non-null  datetime64[ns]
#  28  state_id_fips             221265 non-null  string
#  29  county_id_fips            213860 non-null  string
# dtypes: Int64(7), boolean(5), datetime64[ns](3), string(15)
# memory usage: 47.5 MB

# %%
transformed["ballot_ready_counties"].isna().sum()
# Out:
# county                           0
# election_id                      0
# election_name                    0
# election_day                     0
# race_id                          0
# is_primary                       0
# is_runoff                        0
# is_unexpired                     0
# position_id                      0
# position_name                    0
# sub_area_name                70517
# sub_area_value               54692
# sub_area_name_secondary     203827
# sub_area_value_secondary    203369
# state                            0
# level                            0
# tier                             0
# is_judicial                      0
# is_retention                     0
# number_of_seats                  0
# normalized_position_id           0
# normalized_position_name         0
# position_description             8
# frequency                        0
# reference_year                   0
# partisan_type                   25
# race_created_at                  0
# race_updated_at                  0
# state_id_fips                    0
# county_id_fips                7405
# dtype: int64

# %% [markdown]
# ## Transform implementation

# %%
source_path = Path("ballot_ready/2023_04_05_climate_partners_upcoming_races_with_counties.csv")
raw_dfs = dbcp.extract.ballot_ready.extract(source_path)

# %%
ballot_ready = raw_dfs["raw_ballot_ready"]

# %%
ballot_ready["counties"] = ballot_ready.counties.str[1:-1].str.split(",")

# %%
ballot_ready.counties
# Out:
# 0                          [Barrow County, Jackson County]
# 1            [Colquitt County, Cook County, Thomas County]
# 2        [Brooks County, Colquitt County, Cook County, ...
# 3        [Columbia County, Luzerne County, Montour Coun...
# 4                                       [Allegheny County]
#                                ...
# 81677                   [Travis County, Williamson County]
# 81678                      [Bastrop County, Travis County]
# 81679                                      [Travis County]
# 81680                   [Travis County, Williamson County]
# 81681                   [Travis County, Williamson County]
# Name: counties, Length: 81682, dtype: object

# %%
exp_ballot_ready = ballot_ready.explode("counties")
exp_ballot_ready = exp_ballot_ready.rename(columns={"counties": "county"})
exp_ballot_ready.shape
# Out:
# (221518, 28)

# %%
duplicate_race = exp_ballot_ready.duplicated(subset=["county", "race_id"], keep=False)
duplicate_race.value_counts()
# Out:
# False    221012
# True        506
# dtype: int64

# %%
duplicate_race.sum()
# Out:
# 506

# %%
ballot_ready = exp_ballot_ready.drop_duplicates(subset=["county", "race_id"])

# %%
assert ~ballot_ready.duplicated(subset=["county", "race_id"], keep=False).any()

# %%
from pudl.helpers import add_fips_ids

# %%
geo = add_fips_ids(ballot_ready)
# Out:
# 2023-08-11 00:33:04 [    INFO] catalystcoop.pudl.helpers:203 Assigned state FIPS codes for 100.00% of records.
# 2023-08-11 00:33:07 [    INFO] catalystcoop.pudl.helpers:219 Assigned county FIPS codes for 96.65% of records.

# %% [markdown]
# Counties that are in the wrong state.

# %%
geo[geo.county_id_fips.isna()][["county", "state"]]
# Out:
#                county state
# 29       Boone County    WI
# 29        Lake County    WI
# 29     McHenry County    WI
# 60     Houston County    WI
# 63     Houston County    WI
# ...               ...   ...
# 81620   Marion County    LA
# 81620   Miller County    LA
# 81620   Newton County    LA
# 81620   Panola County    LA
# 81620   Shelby County    LA
#
# [7405 rows x 2 columns]

# %%
DATETIME_COLUMNS = ["race_created_at", "race_updated_at", "election_day"]

geo = geo.convert_dtypes()
for col in DATETIME_COLUMNS:
    geo[col] = pd.to_datetime(geo[col])

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221265 entries, 0 to 81681
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   county                    221265 non-null  string
#  1   election_id               221265 non-null  Int64
#  2   election_name             221265 non-null  string
#  3   election_day              221265 non-null  datetime64[ns]
#  4   race_id                   221265 non-null  Int64
#  5   is_primary                221265 non-null  boolean
#  6   is_runoff                 221265 non-null  boolean
#  7   is_unexpired              221265 non-null  boolean
#  8   position_id               221265 non-null  Int64
#  9   position_name             221265 non-null  string
#  10  sub_area_name             150748 non-null  string
#  11  sub_area_value            166573 non-null  string
#  12  sub_area_name_secondary   17438 non-null   string
#  13  sub_area_value_secondary  17896 non-null   string
#  14  state                     221265 non-null  string
#  15  level                     221265 non-null  string
#  16  tier                      221265 non-null  Int64
#  17  is_judicial               221265 non-null  boolean
#  18  is_retention              221265 non-null  boolean
#  19  number_of_seats           221265 non-null  Int64
#  20  normalized_position_id    221265 non-null  Int64
#  21  normalized_position_name  221265 non-null  string
#  22  position_description      221257 non-null  string
#  23  frequency                 221265 non-null  string
#  24  reference_year            221265 non-null  Int64
#  25  partisan_type             221240 non-null  string
#  26  race_created_at           221265 non-null  datetime64[ns]
#  27  race_updated_at           221265 non-null  datetime64[ns]
#  28  state_id_fips             221265 non-null  string
#  29  county_id_fips            213860 non-null  string
# dtypes: Int64(7), boolean(5), datetime64[ns](3), string(15)
# memory usage: 55.5 MB

# %% [markdown]
# ## Initial Analysis

# %%
import pandas as pd

df = pd.read_csv("/app/data/raw/2023_04_05_climate_partners_upcoming_races_with_counties.csv")

# %%
df.election_id.is_unique
# Out:
# False

# %%
df.election_id.value_counts()
# Out:
# 4376    2634
# 5232    2583
# 5760    2581
# 4706    1742
# 5292    1741
#         ...
# 4865       1
# 5813       1
# 5963       1
# 4287       1
# 5850       1
# Name: election_id, Length: 291, dtype: int64

# %%
df.query("election_id == 4376").head()
# Out:
#                                                 counties  election_id  \
# 73962  {Anderson County,Andrews County,Angelina Count...         4376
# 73963  {Austin County,Bastrop County,Blanco County,Br...         4376
# 73964  {Andrews County,Bell County,Blanco County,Brow...         4376
# 73965  {Denton County,Jack County,Johnson County,Palo...         4376
# 73966  {Archer County,Armstrong County,Baylor County,...         4376
#
#                 election_name election_day  race_id  is_primary  is_runoff  \
# 73962  Texas General Election   2024-11-05  1521793       False      False
# 73963  Texas General Election   2024-11-05  1667754       False      False
# 73964  Texas General Election   2024-11-05  1667850       False      False
# 73965  Texas General Election   2024-11-05  1667733       False      False
# 73966  Texas General Election   2024-11-05  1667864       False      False
#
#        is_unexpired  position_id  \
# 73962         False           48
# 73963         False        46610
# 73964         False        46611
# 73965         False        46612
# 73966         False        46613
#
#                                            position_name  ... is_retention  \
# 73962                     President of the United States  ...        False
# 73963  U.S. House of Representatives - Texas 10th Con...  ...        False
# 73964  U.S. House of Representatives - Texas 11th Con...  ...        False
# 73965  U.S. House of Representatives - Texas 12th Con...  ...        False
# 73966  U.S. House of Representatives - Texas 13th Con...  ...        False
#
#       number_of_seats normalized_position_id  \
# 73962               1                     10
# 73963               1                     40
# 73964               1                     40
# 73965               1                     40
# 73966               1                     40
#
#                         normalized_position_name  \
# 73962  President of the United States of America
# 73963                        U.S. Representative
# 73964                        U.S. Representative
# 73965                        U.S. Representative
# 73966                        U.S. Representative
#
#                                     position_description frequency  \
# 73962  The President is the chief executive of the co...       {4}
# 73963  The U.S. House of Representatives is one of tw...       {2}
# 73964  The U.S. House of Representatives is one of tw...       {2}
# 73965  The U.S. House of Representatives is one of tw...       {2}
# 73966  The U.S. House of Representatives is one of tw...       {2}
#
#        reference_year  partisan_type      race_created_at      race_updated_at
# 73962            2024       partisan  2020-01-14 23:15:54  2020-01-14 23:15:54
# 73963            2022       partisan  2020-01-15 22:47:48  2020-01-15 22:47:48
# 73964            2022       partisan  2020-01-15 22:47:48  2020-01-15 22:47:48
# 73965            2022       partisan  2020-01-15 22:47:48  2020-01-15 22:47:48
# 73966            2022       partisan  2020-01-15 22:47:48  2020-01-15 22:47:48
#
# [5 rows x 28 columns]

# %%
df.query("race_id == 2002453").counties.iloc[0]
# Out:
# '{Abbeville County,Anderson County,Banks County,Clarke County,Elbert County,Franklin County,Greene County,Hart County,Jackson County,Lincoln County,Madison County,McCormick County,Oconee County,Oconee County,Oglethorpe County,Stephens County,Taliaferro County,Wilkes County}'

# %%
df.race_id.is_unique
# Out:
# True

# %%
df.position_id.is_unique
# Out:
# False

# %%
df.position_id.value_counts()
# Out:
# 49710     6
# 49666     5
# 49763     5
# 46998     5
# 277697    4
#          ..
# 228368    1
# 228367    1
# 228358    1
# 228350    1
# 218495    1
# Name: position_id, Length: 37179, dtype: int64

# %%
df.query("position_id == 49710")
# Out:
#                              counties  election_id  \
# 0      {Barrow County,Jackson County}         5954
# 144    {Barrow County,Jackson County}         6213
# 32104  {Barrow County,Jackson County}         5380
# 41433  {Barrow County,Jackson County}         5756
# 58215  {Barrow County,Jackson County}         4435
# 80158  {Barrow County,Jackson County}         5755
#
#                                 election_name election_day  race_id  \
# 0            Georgia Special General Election   2023-01-31  2020825
# 144    Georgia HD 119 General Runoff Election   2023-02-28  2256527
# 32104                Georgia Primary Election   2024-05-21  1688839
# 41433         Georgia Primary Runoff Election   2024-07-23  2002086
# 58215                Georgia General Election   2024-11-05  1671874
# 80158         Georgia General Runoff Election   2024-12-03  2002085
#
#        is_primary  is_runoff  is_unexpired  position_id  \
# 0           False      False          True        49710
# 144         False       True          True        49710
# 32104        True      False         False        49710
# 41433        True       True         False        49710
# 58215       False      False         False        49710
# 80158       False       True         False        49710
#
#                                          position_name  ... is_retention  \
# 0      Georgia House of Representatives - District 119  ...        False
# 144    Georgia House of Representatives - District 119  ...        False
# 32104  Georgia House of Representatives - District 119  ...        False
# 41433  Georgia House of Representatives - District 119  ...        False
# 58215  Georgia House of Representatives - District 119  ...        False
# 80158  Georgia House of Representatives - District 119  ...        False
#
#       number_of_seats normalized_position_id normalized_position_name  \
# 0                   1                    610     State Representative
# 144                 1                    610     State Representative
# 32104               1                    610     State Representative
# 41433               1                    610     State Representative
# 58215               1                    610     State Representative
# 80158               1                    610     State Representative
#
#                                     position_description frequency  \
# 0      State Representatives are members of the state...       {2}
# 144    State Representatives are members of the state...       {2}
# 32104  State Representatives are members of the state...       {2}
# 41433  State Representatives are members of the state...       {2}
# 58215  State Representatives are members of the state...       {2}
# 80158  State Representatives are members of the state...       {2}
#
#        reference_year  partisan_type      race_created_at      race_updated_at
# 0                2022       partisan  2023-01-31 18:22:55  2023-01-31 18:22:55
# 144              2022       partisan  2023-02-16 21:41:07  2023-02-16 21:41:07
# 32104            2022       partisan  2020-01-15 22:48:25  2020-01-15 22:48:25
# 41433            2022       partisan  2022-08-25 22:34:19  2022-08-25 22:34:19
# 58215            2022       partisan  2020-01-15 22:47:58  2020-01-15 22:47:58
# 80158            2022       partisan  2022-08-25 22:34:19  2022-08-25 22:34:19
#
# [6 rows x 28 columns]

# %%
df.query("election_id == 4435").position_id.nunique()
# Out:
# 1484

# %% [markdown]
# - `position` is the office / position someone is running for (president, Alaska House of Reps District 1). There can be multiple elections for a single position (special election, runoffs, general...)
# - `election` is the election / event that elects some one to a position (special election, runoffs, general...). There can be multiple positions for an election. For example, the 2024 Georgia General Election has ~1500 positions.
# - `race` is a unique combination of a position and an election. It is unique in the raw dataset.

# %% [markdown]
# ## Explode

# %%
toy = pd.DataFrame({'A': [[0, 1, 2], [1], [2,3], [3, 4]],
                   'B': [1,2,3,4,]})

# %%
toy.explode("A")
# Out:
#    A  B
# 0  0  1
# 0  1  1
# 0  2  1
# 1  1  2
# 2  2  3
# 2  3  3
# 3  3  4
# 3  4  4

# %%
df.shape
# Out:
# (81682, 28)

# %%
df.counties.iloc[0]
# Out:
# '{Barrow County,Jackson County}'

# %%
type(df.counties.str[1:-1].str.split(",").iloc[0])
# Out:
# list

# %%
df["counties"] = df.counties.str[1:-1].str.split(",")

# %%
exp_df = df.explode("counties")
exp_df = exp_df.rename(columns={"counties": "county"})
exp_df.shape
# Out:
# (221518, 28)

# %%
duplicate_race = exp_df.duplicated(subset=["county", "race_id"], keep=False)
duplicate_race.value_counts()
# Out:
# False    221012
# True        506
# dtype: int64

# %%
exp_df[duplicate_race].tail()
# Out:
#                 county  election_id                        election_name  \
# 78679       Lee County         5822  Mississippi General Runoff Election
# 80851  Cherokee County         5755      Georgia General Runoff Election
# 80851  Cherokee County         5755      Georgia General Runoff Election
# 80875    Oconee County         5755      Georgia General Runoff Election
# 80875    Oconee County         5755      Georgia General Runoff Election
#
#       election_day  race_id  is_primary  is_runoff  is_unexpired  position_id  \
# 78679   2024-11-26  2011451       False       True         False       377536
# 80851   2024-12-03  2002405       False       True         False       276402
# 80851   2024-12-03  2002405       False       True         False       276402
# 80875   2024-12-03  2002453       False       True         False       276425
# 80875   2024-12-03  2002453       False       True         False       276425
#
#                                            position_name  ... is_retention  \
# 78679  Mississippi Supreme Court Justice - District 3...  ...        False
# 80851    Georgia District Attorney - Appalachian Circuit  ...        False
# 80851    Georgia District Attorney - Appalachian Circuit  ...        False
# 80875       Georgia District Attorney - Northern Circuit  ...        False
# 80875       Georgia District Attorney - Northern Circuit  ...        False
#
#       number_of_seats normalized_position_id     normalized_position_name  \
# 78679               1                   4000  State Supreme Court Justice
# 80851               1                    750            District Attorney
# 80851               1                    750            District Attorney
# 80875               1                    750            District Attorney
# 80875               1                    750            District Attorney
#
#                                     position_description frequency  \
# 78679  The State Supreme Court is responsible for cor...       {8}
# 80851  The District Attorney is the chief legal repre...       {4}
# 80851  The District Attorney is the chief legal repre...       {4}
# 80875  The District Attorney is the chief legal repre...       {4}
# 80875  The District Attorney is the chief legal repre...       {4}
#
#        reference_year  partisan_type      race_created_at      race_updated_at
# 78679            2024    nonpartisan  2022-09-21 23:40:55  2022-09-21 23:40:55
# 80851            2024       partisan  2022-08-25 22:34:26  2022-08-25 22:34:26
# 80851            2024       partisan  2022-08-25 22:34:26  2022-08-25 22:34:26
# 80875            2024       partisan  2022-08-25 22:34:27  2022-08-25 22:34:27
# 80875            2024       partisan  2022-08-25 22:34:27  2022-08-25 22:34:27
#
# [5 rows x 28 columns]

# %%
df.query("race_id == 2002453").counties.iloc[0]
# Out:
# ['Abbeville County',
#  'Anderson County',
#  'Banks County',
#  'Clarke County',
#  'Elbert County',
#  'Franklin County',
#  'Greene County',
#  'Hart County',
#  'Jackson County',
#  'Lincoln County',
#  'Madison County',
#  'McCormick County',
#  'Oconee County',
#  'Oconee County',
#  'Oglethorpe County',
#  'Stephens County',
#  'Taliaferro County',
#  'Wilkes County']

# %%
df.query("race_id == 1658314").counties.iloc[0]
# Out:
# ['Alcorn County',
#  'Attala County',
#  'Benton County',
#  'Calhoun County',
#  'Carroll County',
#  'Chickasaw County',
#  'Choctaw County',
#  'Clay County',
#  'Coahoma County',
#  'Crittenden County',
#  'DeSoto County',
#  'Fayette County',
#  'Grenada County',
#  'Hardeman County',
#  'Itawamba County',
#  'Lafayette County',
#  'Lee County',
#  'Lee County',
#  'Leflore County',
#  'Lowndes County',
#  'Marshall County',
#  'McNairy County',
#  'Monroe County',
#  'Montgomery County',
#  'Noxubee County',
#  'Oktibbeha County',
#  'Panola County',
#  'Phillips County',
#  'Pontotoc County',
#  'Prentiss County',
#  'Quitman County',
#  'Shelby County',
#  'Tallahatchie County',
#  'Tate County',
#  'Tippah County',
#  'Tishomingo County',
#  'Tunica County',
#  'Union County',
#  'Webster County',
#  'Winston County',
#  'Yalobusha County']

# %%
exp_df = exp_df.drop_duplicates()

# %%
assert not exp_df.duplicated(subset=["county", "race_id"], keep=False).any()

# %% [markdown]
# ## Are there duplciates in the counties column
# Yup! Looks like ballot ready is doing something weird that produces duplicate counties for some of the races. I checked to make sure There aren't two Lee Counties in Mississipi ;)

# %%
def are_elements_unique(lst):
    unique_set = set(lst)
    return len(lst) == len(unique_set)

# %%
are_counties_not_unique = ~df.counties.apply(are_elements_unique)
counties_not_unique = df[are_counties_not_unique]

# %%
counties_not_unique
# Out:
#                                                 counties  election_id                        election_name election_day  race_id  is_primary  is_runoff  is_unexpired  position_id                                      position_name sub_area_name       sub_area_value sub_area_name_secondary sub_area_value_secondary state     level  tier  is_judicial  is_retention  number_of_seats  normalized_position_id                           normalized_position_name                               position_description frequency  reference_year partisan_type      race_created_at      race_updated_at
# 4196   [Alcorn County, Attala County, Benton County, ...         5378         Mississippi Primary Election   2023-08-08  1658314        True      False         False       232562  Mississippi Public Service Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     470  State Utilities Board//Public Services Board//...  State Utility or Public Service Boards are res...       {4}            2023      partisan  2020-01-14 23:20:37  2020-01-14 23:20:37
# 4252   [Alcorn County, Attala County, Benton County, ...         5378         Mississippi Primary Election   2023-08-08  1658145        True      False         False       232563  Mississippi Transportation Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     420                         State Transportation Board  The State Transportation Board is responsible ...       {4}            2023      partisan  2020-01-14 23:20:37  2020-01-14 23:20:37
# 5786   [Alcorn County, Attala County, Benton County, ...         5749  Mississippi Primary Runoff Election   2023-08-29  1990313        True       True         False       232562  Mississippi Public Service Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     470  State Utilities Board//Public Services Board//...  State Utility or Public Service Boards are res...       {4}            2023      partisan  2022-08-18 20:42:46  2022-11-02 16:30:23
# 5842   [Alcorn County, Attala County, Benton County, ...         5749  Mississippi Primary Runoff Election   2023-08-29  1990310        True       True         False       232563  Mississippi Transportation Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     420                         State Transportation Board  The State Transportation Board is responsible ...       {4}            2023      partisan  2022-08-18 20:42:46  2022-11-02 16:30:23
# 9799   [Alcorn County, Attala County, Benton County, ...         4225         Mississippi General Election   2023-11-07  1538252       False      False         False       232562  Mississippi Public Service Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     470  State Utilities Board//Public Services Board//...  State Utility or Public Service Boards are res...       {4}            2023      partisan  2020-01-14 23:16:30  2021-09-30 19:37:57
# ...                                                  ...          ...                                  ...          ...      ...         ...        ...           ...          ...                                                ...           ...                  ...                     ...                      ...   ...       ...   ...          ...           ...              ...                     ...                                                ...                                                ...       ...             ...           ...                  ...                  ...
# 78674  [Attala County, Carroll County, Chickasaw Coun...         5822  Mississippi General Runoff Election   2024-11-26  2010350       False       True         False       377520  Mississippi Appellate Court Judge - District 3...      District                    3                Position                        1    MS     state     2         True         False                1                    4010                      State Appellate Court Justice  The Court of Appeals hears cases assigned by t...       {8}            2024   nonpartisan  2022-09-21 22:46:18  2022-09-21 22:46:18
# 78678  [Alcorn County, Attala County, Benton County, ...         5822  Mississippi General Runoff Election   2024-11-26  2010696       False       True         False       377535  Mississippi Supreme Court Justice - District 3...      District                    3                Position                        1    MS     state     2         True         False                1                    4000                        State Supreme Court Justice  The State Supreme Court is responsible for cor...       {8}            2024   nonpartisan  2022-09-21 23:01:49  2022-09-21 23:01:49
# 78679  [Alcorn County, Attala County, Benton County, ...         5822  Mississippi General Runoff Election   2024-11-26  2011451       False       True         False       377536  Mississippi Supreme Court Justice - District 3...      District                    3                Position                        2    MS     state     2         True         False                1                    4000                        State Supreme Court Justice  The State Supreme Court is responsible for cor...       {8}            2024   nonpartisan  2022-09-21 23:40:55  2022-09-21 23:40:55
# 80851  [Cherokee County, Cherokee County, Dawson Coun...         5755      Georgia General Runoff Election   2024-12-03  2002405       False       True         False       276402    Georgia District Attorney - Appalachian Circuit           NaN  Appalachian Circuit                     NaN                      NaN    GA  regional     3        False         False                1                     750                                  District Attorney  The District Attorney is the chief legal repre...       {4}            2024      partisan  2022-08-25 22:34:26  2022-08-25 22:34:26
# 80875  [Abbeville County, Anderson County, Banks Coun...         5755      Georgia General Runoff Election   2024-12-03  2002453       False       True         False       276425       Georgia District Attorney - Northern Circuit           NaN     Northern Circuit                     NaN                      NaN    GA  regional     3        False         False                1                     750                                  District Attorney  The District Attorney is the chief legal repre...       {4}            2024      partisan  2022-08-25 22:34:27  2022-08-25 22:34:27
#
# [220 rows x 28 columns]

# %%
counties_not_unique.state.value_counts()
# Out:
# MN    62
# FL    44
# IL    22
# RI    14
# MS    12
# WI    10
# MO    10
# OH     8
# GA     8
# MT     8
# WY     7
# MI     4
# AL     3
# NY     2
# KY     2
# MA     2
# NH     2
# Name: state, dtype: int64

# %%
are_counties_not_unique.value_counts(normalize=True) * 100
# Out:
# False    99.730663
# True      0.269337
# Name: counties, dtype: float64

# %%
counties_not_unique
# Out:
#                                                 counties  election_id                        election_name election_day  race_id  is_primary  is_runoff  is_unexpired  position_id                                      position_name sub_area_name       sub_area_value sub_area_name_secondary sub_area_value_secondary state     level  tier  is_judicial  is_retention  number_of_seats  normalized_position_id                           normalized_position_name                               position_description frequency  reference_year partisan_type      race_created_at      race_updated_at
# 4196   [Alcorn County, Attala County, Benton County, ...         5378         Mississippi Primary Election   2023-08-08  1658314        True      False         False       232562  Mississippi Public Service Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     470  State Utilities Board//Public Services Board//...  State Utility or Public Service Boards are res...       {4}            2023      partisan  2020-01-14 23:20:37  2020-01-14 23:20:37
# 4252   [Alcorn County, Attala County, Benton County, ...         5378         Mississippi Primary Election   2023-08-08  1658145        True      False         False       232563  Mississippi Transportation Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     420                         State Transportation Board  The State Transportation Board is responsible ...       {4}            2023      partisan  2020-01-14 23:20:37  2020-01-14 23:20:37
# 5786   [Alcorn County, Attala County, Benton County, ...         5749  Mississippi Primary Runoff Election   2023-08-29  1990313        True       True         False       232562  Mississippi Public Service Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     470  State Utilities Board//Public Services Board//...  State Utility or Public Service Boards are res...       {4}            2023      partisan  2022-08-18 20:42:46  2022-11-02 16:30:23
# 5842   [Alcorn County, Attala County, Benton County, ...         5749  Mississippi Primary Runoff Election   2023-08-29  1990310        True       True         False       232563  Mississippi Transportation Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     420                         State Transportation Board  The State Transportation Board is responsible ...       {4}            2023      partisan  2022-08-18 20:42:46  2022-11-02 16:30:23
# 9799   [Alcorn County, Attala County, Benton County, ...         4225         Mississippi General Election   2023-11-07  1538252       False      False         False       232562  Mississippi Public Service Commission - Northe...           NaN    Northern District                     NaN                      NaN    MS     state     2        False         False                1                     470  State Utilities Board//Public Services Board//...  State Utility or Public Service Boards are res...       {4}            2023      partisan  2020-01-14 23:16:30  2021-09-30 19:37:57
# ...                                                  ...          ...                                  ...          ...      ...         ...        ...           ...          ...                                                ...           ...                  ...                     ...                      ...   ...       ...   ...          ...           ...              ...                     ...                                                ...                                                ...       ...             ...           ...                  ...                  ...
# 78674  [Attala County, Carroll County, Chickasaw Coun...         5822  Mississippi General Runoff Election   2024-11-26  2010350       False       True         False       377520  Mississippi Appellate Court Judge - District 3...      District                    3                Position                        1    MS     state     2         True         False                1                    4010                      State Appellate Court Justice  The Court of Appeals hears cases assigned by t...       {8}            2024   nonpartisan  2022-09-21 22:46:18  2022-09-21 22:46:18
# 78678  [Alcorn County, Attala County, Benton County, ...         5822  Mississippi General Runoff Election   2024-11-26  2010696       False       True         False       377535  Mississippi Supreme Court Justice - District 3...      District                    3                Position                        1    MS     state     2         True         False                1                    4000                        State Supreme Court Justice  The State Supreme Court is responsible for cor...       {8}            2024   nonpartisan  2022-09-21 23:01:49  2022-09-21 23:01:49
# 78679  [Alcorn County, Attala County, Benton County, ...         5822  Mississippi General Runoff Election   2024-11-26  2011451       False       True         False       377536  Mississippi Supreme Court Justice - District 3...      District                    3                Position                        2    MS     state     2         True         False                1                    4000                        State Supreme Court Justice  The State Supreme Court is responsible for cor...       {8}            2024   nonpartisan  2022-09-21 23:40:55  2022-09-21 23:40:55
# 80851  [Cherokee County, Cherokee County, Dawson Coun...         5755      Georgia General Runoff Election   2024-12-03  2002405       False       True         False       276402    Georgia District Attorney - Appalachian Circuit           NaN  Appalachian Circuit                     NaN                      NaN    GA  regional     3        False         False                1                     750                                  District Attorney  The District Attorney is the chief legal repre...       {4}            2024      partisan  2022-08-25 22:34:26  2022-08-25 22:34:26
# 80875  [Abbeville County, Anderson County, Banks Coun...         5755      Georgia General Runoff Election   2024-12-03  2002453       False       True         False       276425       Georgia District Attorney - Northern Circuit           NaN     Northern Circuit                     NaN                      NaN    GA  regional     3        False         False                1                     750                                  District Attorney  The District Attorney is the chief legal repre...       {4}            2024      partisan  2022-08-25 22:34:27  2022-08-25 22:34:27
#
# [220 rows x 28 columns]

# %%
counties_not_unique.to_csv("races_with_duplicate_counties.csv")

# %% [markdown]
# ## Missing fips codes

# %%
import dbcp

br = dbcp.etl.etl_ballot_ready()["br_election_data"]
# Out:
# /app/.local/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(
# /app/.local/lib/python3.10/site-packages/pudl/analysis/spatial.py:7: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# 2023-08-14 23:25:13 [    INFO] catalystcoop.pudl.helpers:203 Assigned state FIPS codes for 100.00% of records.
# 2023-08-14 23:25:17 [    INFO] catalystcoop.pudl.helpers:219 Assigned county FIPS codes for 96.65% of records.

# %%
br.state_id_fips.isna().value_counts()
# Out:
# False    221265
# Name: state_id_fips, dtype: int64

# %%
br.county_id_fips.isna().value_counts(normalize=True) * 100
# Out:
# False    96.653334
# True      3.346666
# Name: county_id_fips, dtype: float64

# %%
br[br.county_id_fips.isna()].iloc[2]
# Out:
# county                                                         McHenry County
# election_id                                                              5209
# election_name                                      Wisconsin Primary Election
# election_day                                              2023-02-21 00:00:00
# race_id                                                               1956520
# is_primary                                                               True
# is_runoff                                                               False
# is_unexpired                                                            False
# position_id                                                            384597
# position_name               Wisconsin Appeals Court Judge - District 4, Se...
# sub_area_name                                                        District
# sub_area_value                                                              4
# sub_area_name_secondary                                                  Seat
# sub_area_value_secondary                                                    3
# state                                                                      WI
# level                                                                   state
# tier                                                                        2
# is_judicial                                                              True
# is_retention                                                            False
# number_of_seats                                                             1
# normalized_position_id                                                   4010
# normalized_position_name                        State Appellate Court Justice
# frequency                                                                 {6}
# reference_year                                                           2023
# partisan_type                                                     nonpartisan
# race_created_at                                    2022-01-31 10:31:24.217909
# race_updated_at                                    2022-11-02 13:31:50.691409
# state_id_fips                                                              55
# county_id_fips                                                           <NA>
# Name: 29, dtype: object

# %%
br[br.county_id_fips.isna()].to_csv("exploded_counties_with_incorrect_state.csv")
