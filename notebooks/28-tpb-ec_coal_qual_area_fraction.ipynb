# %%
import pandas as pd
import dbcp
# Out:
# /app/.local/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
import numpy as np

# %%
engine = dbcp.helpers.get_sql_engine()

# %%
ec = pd.read_sql("select * from data_warehouse.energy_communities_by_county", engine)

# %%
ec.columns
# Out:
# Index(['county_id_fips', 'raw_county_id_fips', 'raw_county_name', 'raw_state_name', 'n_brownfields', 'brownfield_acreage', 'brownfield_acreage_mean_fill', 'brownfield_acreage_median_fill', 'n_coal_qualifying_tracts', 'coal_qualifying_area_fraction', 'qualifies_by_employment_criteria', 'geocoded_locality_name'], dtype='object')

# %%
ec['coal_qualifying_area_fraction'].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
ec['coal_qualifying_area_fraction'].replace(0, np.nan).hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
ec['coal_qualifying_area_fraction'].hist(bins=50, density=True, cumulative=True)
# Out:
# <AxesSubplot: >

# %%
ec['coal_qualifying_area_fraction'].eq(1.0).agg(['sum', 'mean'])
# Out:
# sum     253.000000
# mean      0.086437
# Name: coal_qualifying_area_fraction, dtype: float64
